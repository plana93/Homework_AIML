# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cd /content/drive/My\ Drive/
# %cd FPAR-Project-MLDL/
# Out:
# /content/drive/My Drive
# /content/drive/My Drive/FPAR-Project-MLDL

# %% [markdown]
# # SETUP
# The following blocks are to be executed first of anything else, to setup import, classes, functions and
# constants that are needed for all stages

# %%
import os
import logging

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader
from torch.backends import cudnn
import torchvision
from torchvision import transforms
from torchvision.models import resnet34

from PIL import Image
from tqdm import tqdm

from logs import Logger, generate_model_checkpoint_name, generate_log_filenames

from gtea_dataset import GTEA61, GTEA61_flow, GTEA61_2Stream
# from clean_dataset import adjust_flows
from AttentMS2 import attention_model_ms
from flow_resnet import flow_resnet34
from twoStreamModel import twoStreamAttentionModel
from spatial_transforms import (Compose, ToTensor, CenterCrop, Scale, Normalize, MultiScaleCornerCrop,
                                RandomHorizontalFlip, DownSampling, To1Dimension)

# %%
DEVICE = 'cuda' # 'cuda' or 'cpu'
NUM_CLASSES = 61 # 101 + 1: There is am extra Background class that should be removed 

BATCH_SIZE = 32     # Higher batch sizes allows for larger learning rates. An empirical heuristic suggests that, when changing
                     # the batch size, learning rate should change by the same factor to have comparable results

MMAP_LENGTH = 49
DATA_DIR = '../GTEA61'
model_folder = '../saved_models'

RUN = '_run01'

# %%
# Data loader
normalize = Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
default_transforms = [
    Scale(256),
    RandomHorizontalFlip(),
    MultiScaleCornerCrop([1, 0.875, 0.75, 0.65625], 224),
    ToTensor()
]

spatial_transform = Compose(default_transforms + [normalize])
spatial_transform_mmaps = Compose(default_transforms + [DownSampling(), To1Dimension()])
spatial_transform_val = Compose([Scale(256), CenterCrop(224), ToTensor(), normalize])

# %% [markdown]
# # Stage 1 specific setup

# %%
STAGE = 1

LR = 0.001                            # The initial Learning Rate
MOMENTUM = 0.9                        # Hyperparameter for SGD, keep this at 0.9 when using SGD
WEIGHT_DECAY = 4e-5                   # Regularization, you can keep this at the default

NUM_EPOCHS = 150                      # Total number of training epochs (iterations over dataset)
STEP_SIZE = [30, 80]             # How many epochs before decreasing learning rate (if using a step-down policy)
GAMMA = 0.1                           # Multiplicative factor for learning rate step-down
MEM_SIZE = 512
SEQ_LEN = 7

# this dictionary is needed for the logger class
parameters = {
    'DEVICE': DEVICE,
    'NUM_CLASSES': NUM_CLASSES,
    'BATCH_SIZE': BATCH_SIZE,
    'LR': LR,
    'MOMENTUM': MOMENTUM,
    'WEIGHT_DECAY': WEIGHT_DECAY,
    'NUM_EPOCHS': NUM_EPOCHS,
    'STEP_SIZE': STEP_SIZE,
    'GAMMA': GAMMA,
    'MEM_SIZE': MEM_SIZE,
    'SEQ_LEN': SEQ_LEN
}

# %%
# Prepare Pytorch train/test Datasets
train_dataset = GTEA61(DATA_DIR, split = 'train', transform = spatial_transform, seq_len = SEQ_LEN,
                       mmaps = True, mmaps_transform = spatial_transform_mmaps, static_frames = True)
test_dataset = GTEA61(DATA_DIR, split = 'test', transform = spatial_transform_val, seq_len = SEQ_LEN)

# Check dataset sizes
print('Train Dataset: {}'.format(len(train_dataset)))
print('Test Dataset: {}'.format(len(test_dataset)))
# Out:
# Train Dataset: 341
# Test Dataset: 116

# %%
# Dataloaders iterate over pytorch datasets and transparently provide useful functions (e.g. parallelization and shuffling)
train_loader = DataLoader(train_dataset, batch_size = BATCH_SIZE, shuffle = True, num_workers = 4, drop_last = True)
val_loader = DataLoader(test_dataset, batch_size = BATCH_SIZE, shuffle = False, num_workers = 4)

# %% [markdown]
# # Prepare Stage 1

# %%
validate = True

model = attention_model_ms(num_classes = NUM_CLASSES, mem_size = MEM_SIZE)
model.train(False)

for params in model.parameters():
    params.requires_grad = False

for params in model.lstm_cell.parameters():
    params.requires_grad = True

for params in model.classifier.parameters():
    params.requires_grad = True

model.lstm_cell.train(True)
model.classifier.train(True)
model.to(DEVICE)

trainable_params = [p for p in model.parameters() if p.requires_grad]

loss_fn = nn.CrossEntropyLoss()

optimizer_fn = optim.Adam(trainable_params, lr = LR, weight_decay = WEIGHT_DECAY, eps = 1e-4)

optim_scheduler = optim.lr_scheduler.MultiStepLR(optimizer_fn, milestones = STEP_SIZE, gamma = GAMMA)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# HBox(children=(FloatProgress(value=0.0, max=87306240.0), HTML(value='')))

# %% [markdown]
# # Stage 1

# %%
train_iter = 0
val_iter = 0
min_accuracy = 0

trainSamples = len(train_dataset) - (len(train_dataset) % BATCH_SIZE)
val_samples = len(test_dataset) 
iterPerEpoch = len(train_loader)
val_steps = len(val_loader)

cudnn.benchmark

train_log, val_log = generate_log_filenames(STAGE, SEQ_LEN, ms_block = True, \
                                            optional = '_2neur_DS_' + RUN)
model_checkpoint = generate_model_checkpoint_name(STAGE, SEQ_LEN, ms_block = True, \
                                                  optional = '_2neur_DS_' + RUN)

train_log_file = os.path.join(model_folder, train_log)
val_log_file = os.path.join(model_folder, val_log)

train_logger = Logger(**parameters)
val_logger = Logger(**parameters)

for epoch in range(NUM_EPOCHS):

    epoch_loss = 0
    numCorrTrain = 0
    
    model.lstm_cell.train(True)
    model.classifier.train(True)
        
    for i, (inputs, _, _, targets) in enumerate(train_loader):

        train_iter += 1

        optimizer_fn.zero_grad()

        inputVariable = inputs.permute(1, 0, 2, 3, 4).to(DEVICE)
        labelVariable = targets.to(DEVICE)
        output_label, _ = model(inputVariable)
        
        loss = loss_fn(output_label, labelVariable)
        loss.backward()
        optimizer_fn.step()
            
        _, predicted = torch.max(output_label.data, 1)
        numCorrTrain += torch.sum(predicted == labelVariable.data).data.item()

        step_loss = loss.data.item()
        epoch_loss += step_loss

        train_logger.add_step_data(train_iter, numCorrTrain, step_loss)
    
    avg_loss = epoch_loss/iterPerEpoch

    trainAccuracy = (numCorrTrain / trainSamples) * 100
    train_logger.add_epoch_data(epoch+1, trainAccuracy, avg_loss)
    print('Train: Epoch = {} | Loss = {:.3f} | Accuracy = {:.3f}'.format(epoch+1, avg_loss, trainAccuracy))

    if validate:

        if (epoch+1) % 1 == 0:

            model.train(False)

            val_loss_epoch = 0
            numCorr = 0

            for j, (inputs, targets) in enumerate(val_loader):

                val_iter += 1

                inputVariable = inputs.permute(1, 0, 2, 3, 4).to(DEVICE)
                labelVariable = targets.to(DEVICE)
                
                output_label, _ = model(inputVariable)

                val_loss = loss_fn(output_label, labelVariable)
                val_loss_step = val_loss.data.item()
                val_loss_epoch += val_loss_step
                
                _, predicted = torch.max(output_label.data, 1)
                numCorr += torch.sum(predicted == labelVariable.data).data.item()

                val_logger.add_step_data(val_iter, numCorr, val_loss_step)
                
            val_accuracy = (numCorr / val_samples) * 100
            avg_val_loss = val_loss_epoch / val_steps
            val_logger.add_epoch_data(epoch+1, val_accuracy, avg_val_loss)

            print('Val: Epoch = {} | Loss {:.3f} | Accuracy = {:.3f}'.format(epoch + 1, avg_val_loss, val_accuracy))

            if val_accuracy > min_accuracy:
                print("[||| NEW BEST on val||||]")
                save_path_model = os.path.join(model_folder, model_checkpoint)
                torch.save(model.state_dict(), save_path_model)
                min_accuracy = val_accuracy
        
    train_logger.save(train_log_file)
    val_logger.save(val_log_file)
    optim_scheduler.step()
# Out:
# Train: Epoch = 1 | Loss = 4.084 | Accuracy = 4.688
# Val: Epoch = 1 | Loss 3.914 | Accuracy = 6.897
# [||| NEW BEST on val||||]
# Train: Epoch = 2 | Loss = 4.056 | Accuracy = 3.750
# Val: Epoch = 2 | Loss 3.901 | Accuracy = 5.172
# Train: Epoch = 3 | Loss = 3.989 | Accuracy = 6.250
# Val: Epoch = 3 | Loss 3.874 | Accuracy = 5.172
# Train: Epoch = 4 | Loss = 3.907 | Accuracy = 7.187
# Val: Epoch = 4 | Loss 3.777 | Accuracy = 6.897
# Train: Epoch = 5 | Loss = 3.812 | Accuracy = 6.875
# Val: Epoch = 5 | Loss 3.665 | Accuracy = 10.345
# [||| NEW BEST on val||||]
# Train: Epoch = 6 | Loss = 3.647 | Accuracy = 12.500
# Val: Epoch = 6 | Loss 3.513 | Accuracy = 8.621
# Train: Epoch = 7 | Loss = 3.578 | Accuracy = 12.812
# Val: Epoch = 7 | Loss 3.546 | Accuracy = 12.931
# [||| NEW BEST on val||||]
# Train: Epoch = 8 | Loss = 3.513 | Accuracy = 11.875
# Val: Epoch = 8 | Loss 3.596 | Accuracy = 11.207
# Train: Epoch = 9 | Loss = 3.587 | Accuracy = 12.812
# Val: Epoch = 9 | Loss 3.506 | Accuracy = 8.621
# Train: Epoch = 10 | Loss = 3.495 | Accuracy = 12.188
# Val: Epoch = 10 | Loss 3.426 | Accuracy = 8.621
# Train: Epoch = 11 | Loss = 3.481 | Accuracy = 10.938
# Val: Epoch = 11 | Loss 3.242 | Accuracy = 15.517
# [||| NEW BEST on val||||]
# Train: Epoch = 12 | Loss = 3.371 | Accuracy = 13.438
# Val: Epoch = 12 | Loss 3.432 | Accuracy = 12.931
# Train: Epoch = 13 | Loss = 3.230 | Accuracy = 17.812
# Val: Epoch = 13 | Loss 3.365 | Accuracy = 12.069
# Train: Epoch = 14 | Loss = 3.216 | Accuracy = 18.438
# Val: Epoch = 14 | Loss 3.192 | Accuracy = 24.138
# [||| NEW BEST on val||||]
# Train: Epoch = 15 | Loss = 3.188 | Accuracy = 18.438
# Val: Epoch = 15 | Loss 3.152 | Accuracy = 21.552
# Train: Epoch = 16 | Loss = 3.114 | Accuracy = 19.688
# Val: Epoch = 16 | Loss 3.015 | Accuracy = 25.862
# [||| NEW BEST on val||||]
# Train: Epoch = 17 | Loss = 3.042 | Accuracy = 18.438
# Val: Epoch = 17 | Loss 3.023 | Accuracy = 25.000
# Train: Epoch = 18 | Loss = 3.052 | Accuracy = 18.438
# Val: Epoch = 18 | Loss 2.901 | Accuracy = 27.586
# [||| NEW BEST on val||||]
# Train: Epoch = 19 | Loss = 3.151 | Accuracy = 15.625
# Val: Epoch = 19 | Loss 3.000 | Accuracy = 19.828
# Train: Epoch = 20 | Loss = 3.009 | Accuracy = 19.688
# Val: Epoch = 20 | Loss 2.758 | Accuracy = 23.276
# Train: Epoch = 21 | Loss = 2.825 | Accuracy = 21.250
# Val: Epoch = 21 | Loss 2.813 | Accuracy = 24.138
# Train: Epoch = 22 | Loss = 2.801 | Accuracy = 23.438
# Val: Epoch = 22 | Loss 2.701 | Accuracy = 22.414
# Train: Epoch = 23 | Loss = 2.934 | Accuracy = 22.188
# Val: Epoch = 23 | Loss 3.159 | Accuracy = 14.655
# Train: Epoch = 24 | Loss = 2.911 | Accuracy = 23.125
# Val: Epoch = 24 | Loss 2.964 | Accuracy = 23.276
# Train: Epoch = 25 | Loss = 2.784 | Accuracy = 27.500
# Val: Epoch = 25 | Loss 2.653 | Accuracy = 29.310
# [||| NEW BEST on val||||]
# Train: Epoch = 26 | Loss = 2.704 | Accuracy = 25.000
# Val: Epoch = 26 | Loss 2.670 | Accuracy = 30.172
# [||| NEW BEST on val||||]
# Train: Epoch = 27 | Loss = 2.570 | Accuracy = 29.375
# Val: Epoch = 27 | Loss 2.785 | Accuracy = 25.862
# Train: Epoch = 28 | Loss = 2.787 | Accuracy = 22.812
# Val: Epoch = 28 | Loss 3.113 | Accuracy = 21.552
# Train: Epoch = 29 | Loss = 2.626 | Accuracy = 27.812
# Val: Epoch = 29 | Loss 2.847 | Accuracy = 21.552
# Train: Epoch = 30 | Loss = 2.545 | Accuracy = 29.375
# Val: Epoch = 30 | Loss 2.758 | Accuracy = 31.897
# [||| NEW BEST on val||||]
# Train: Epoch = 31 | Loss = 2.462 | Accuracy = 33.438
# Val: Epoch = 31 | Loss 2.572 | Accuracy = 31.897
# Train: Epoch = 32 | Loss = 2.383 | Accuracy = 34.062
# Val: Epoch = 32 | Loss 2.426 | Accuracy = 32.759
# [||| NEW BEST on val||||]
# Train: Epoch = 33 | Loss = 2.398 | Accuracy = 35.000
# Val: Epoch = 33 | Loss 2.446 | Accuracy = 31.034
# Train: Epoch = 34 | Loss = 2.389 | Accuracy = 35.938
# Val: Epoch = 34 | Loss 2.470 | Accuracy = 29.310
# Train: Epoch = 35 | Loss = 2.317 | Accuracy = 33.438
# Val: Epoch = 35 | Loss 2.485 | Accuracy = 31.034
# Train: Epoch = 36 | Loss = 2.291 | Accuracy = 36.562
# Val: Epoch = 36 | Loss 2.495 | Accuracy = 29.310
# Train: Epoch = 37 | Loss = 2.367 | Accuracy = 35.312
# Val: Epoch = 37 | Loss 2.554 | Accuracy = 29.310
# Train: Epoch = 38 | Loss = 2.299 | Accuracy = 36.875
# Val: Epoch = 38 | Loss 2.523 | Accuracy = 29.310
# Train: Epoch = 39 | Loss = 2.218 | Accuracy = 39.688
# Val: Epoch = 39 | Loss 2.505 | Accuracy = 31.897
# Train: Epoch = 40 | Loss = 2.122 | Accuracy = 41.562
# Val: Epoch = 40 | Loss 2.473 | Accuracy = 32.759
# Train: Epoch = 41 | Loss = 2.196 | Accuracy = 37.500
# Val: Epoch = 41 | Loss 2.502 | Accuracy = 32.759
# Train: Epoch = 42 | Loss = 2.078 | Accuracy = 40.625
# Val: Epoch = 42 | Loss 2.564 | Accuracy = 32.759
# Train: Epoch = 43 | Loss = 2.334 | Accuracy = 35.625
# Val: Epoch = 43 | Loss 2.513 | Accuracy = 31.897
# Train: Epoch = 44 | Loss = 2.169 | Accuracy = 40.312
# Val: Epoch = 44 | Loss 2.458 | Accuracy = 32.759
# Train: Epoch = 45 | Loss = 2.133 | Accuracy = 38.438
# Val: Epoch = 45 | Loss 2.512 | Accuracy = 37.931
# [||| NEW BEST on val||||]
# Train: Epoch = 46 | Loss = 2.138 | Accuracy = 39.062
# Val: Epoch = 46 | Loss 2.467 | Accuracy = 36.207
# Train: Epoch = 47 | Loss = 2.124 | Accuracy = 38.125
# Val: Epoch = 47 | Loss 2.515 | Accuracy = 34.483
# Train: Epoch = 48 | Loss = 2.133 | Accuracy = 41.562
# Val: Epoch = 48 | Loss 2.476 | Accuracy = 36.207
# Train: Epoch = 49 | Loss = 2.100 | Accuracy = 42.812
# Val: Epoch = 49 | Loss 2.502 | Accuracy = 32.759
# Train: Epoch = 50 | Loss = 2.045 | Accuracy = 40.938
# Val: Epoch = 50 | Loss 2.534 | Accuracy = 31.034
# Train: Epoch = 51 | Loss = 2.140 | Accuracy = 38.750
# Val: Epoch = 51 | Loss 2.518 | Accuracy = 35.345
# Train: Epoch = 52 | Loss = 2.136 | Accuracy = 38.750
# Val: Epoch = 52 | Loss 2.555 | Accuracy = 39.655
# [||| NEW BEST on val||||]
# Train: Epoch = 53 | Loss = 2.050 | Accuracy = 43.125
# Val: Epoch = 53 | Loss 2.514 | Accuracy = 37.069
# Train: Epoch = 54 | Loss = 2.210 | Accuracy = 39.062
# Val: Epoch = 54 | Loss 2.458 | Accuracy = 40.517
# [||| NEW BEST on val||||]
# Train: Epoch = 55 | Loss = 2.038 | Accuracy = 43.750
# Val: Epoch = 55 | Loss 2.461 | Accuracy = 38.793
# Train: Epoch = 56 | Loss = 2.036 | Accuracy = 40.312
# Val: Epoch = 56 | Loss 2.518 | Accuracy = 37.931
# Train: Epoch = 57 | Loss = 2.037 | Accuracy = 44.375
# Val: Epoch = 57 | Loss 2.435 | Accuracy = 37.069
# Train: Epoch = 58 | Loss = 2.044 | Accuracy = 45.312
# Val: Epoch = 58 | Loss 2.491 | Accuracy = 38.793
# Train: Epoch = 59 | Loss = 2.059 | Accuracy = 39.375
# Val: Epoch = 59 | Loss 2.567 | Accuracy = 37.931
# Train: Epoch = 60 | Loss = 1.941 | Accuracy = 45.312
# Val: Epoch = 60 | Loss 2.560 | Accuracy = 37.069
# Train: Epoch = 61 | Loss = 1.876 | Accuracy = 50.313
# Val: Epoch = 61 | Loss 2.479 | Accuracy = 37.931
# Train: Epoch = 62 | Loss = 2.066 | Accuracy = 44.375
# Val: Epoch = 62 | Loss 2.450 | Accuracy = 36.207
# Train: Epoch = 63 | Loss = 2.113 | Accuracy = 37.500
# Val: Epoch = 63 | Loss 2.410 | Accuracy = 39.655
# Train: Epoch = 64 | Loss = 2.066 | Accuracy = 42.812
# Val: Epoch = 64 | Loss 2.471 | Accuracy = 37.931
# Train: Epoch = 65 | Loss = 1.950 | Accuracy = 41.562
# Val: Epoch = 65 | Loss 2.496 | Accuracy = 39.655
# Train: Epoch = 66 | Loss = 1.839 | Accuracy = 45.312
# Val: Epoch = 66 | Loss 2.556 | Accuracy = 38.793
# Train: Epoch = 67 | Loss = 1.985 | Accuracy = 42.500
# Val: Epoch = 67 | Loss 2.503 | Accuracy = 37.931
# Train: Epoch = 68 | Loss = 1.854 | Accuracy = 48.438
# Val: Epoch = 68 | Loss 2.523 | Accuracy = 39.655
# Train: Epoch = 69 | Loss = 1.940 | Accuracy = 44.062
# Val: Epoch = 69 | Loss 2.499 | Accuracy = 36.207
# Train: Epoch = 70 | Loss = 2.094 | Accuracy = 41.250
# Val: Epoch = 70 | Loss 2.575 | Accuracy = 36.207
# Train: Epoch = 71 | Loss = 1.967 | Accuracy = 47.188
# Val: Epoch = 71 | Loss 2.510 | Accuracy = 36.207
# Train: Epoch = 72 | Loss = 1.909 | Accuracy = 45.625
# Val: Epoch = 72 | Loss 2.497 | Accuracy = 36.207
# Train: Epoch = 73 | Loss = 1.963 | Accuracy = 40.625
# Val: Epoch = 73 | Loss 2.572 | Accuracy = 36.207
# Train: Epoch = 74 | Loss = 1.952 | Accuracy = 44.688
# Val: Epoch = 74 | Loss 2.525 | Accuracy = 35.345
# Train: Epoch = 75 | Loss = 1.935 | Accuracy = 43.438
# Val: Epoch = 75 | Loss 2.483 | Accuracy = 39.655
# Train: Epoch = 76 | Loss = 1.897 | Accuracy = 43.125
# Val: Epoch = 76 | Loss 2.502 | Accuracy = 37.931
# Train: Epoch = 77 | Loss = 1.947 | Accuracy = 44.062
# Val: Epoch = 77 | Loss 2.539 | Accuracy = 36.207
# Train: Epoch = 78 | Loss = 1.743 | Accuracy = 49.688
# Val: Epoch = 78 | Loss 2.527 | Accuracy = 36.207
# Train: Epoch = 79 | Loss = 1.746 | Accuracy = 51.250
# Val: Epoch = 79 | Loss 2.548 | Accuracy = 36.207
# Train: Epoch = 80 | Loss = 1.695 | Accuracy = 52.188
# Val: Epoch = 80 | Loss 2.597 | Accuracy = 36.207
# Train: Epoch = 81 | Loss = 1.934 | Accuracy = 44.375
# Val: Epoch = 81 | Loss 2.594 | Accuracy = 35.345
# Train: Epoch = 82 | Loss = 1.936 | Accuracy = 43.750
# Val: Epoch = 82 | Loss 2.581 | Accuracy = 37.069
# Train: Epoch = 83 | Loss = 1.839 | Accuracy = 45.938
# Val: Epoch = 83 | Loss 2.578 | Accuracy = 37.069
# Train: Epoch = 84 | Loss = 1.967 | Accuracy = 46.875
# Val: Epoch = 84 | Loss 2.559 | Accuracy = 38.793
# Train: Epoch = 85 | Loss = 1.820 | Accuracy = 49.062
# Val: Epoch = 85 | Loss 2.544 | Accuracy = 39.655
# Train: Epoch = 86 | Loss = 1.762 | Accuracy = 47.812
# Val: Epoch = 86 | Loss 2.540 | Accuracy = 38.793
# Train: Epoch = 87 | Loss = 1.791 | Accuracy = 45.000
# Val: Epoch = 87 | Loss 2.543 | Accuracy = 39.655
# Train: Epoch = 88 | Loss = 1.896 | Accuracy = 46.875
# Val: Epoch = 88 | Loss 2.540 | Accuracy = 39.655
# Train: Epoch = 89 | Loss = 1.776 | Accuracy = 51.875
# Val: Epoch = 89 | Loss 2.535 | Accuracy = 39.655
# Train: Epoch = 90 | Loss = 1.753 | Accuracy = 50.313
# Val: Epoch = 90 | Loss 2.535 | Accuracy = 38.793
# Train: Epoch = 91 | Loss = 1.791 | Accuracy = 46.562
# Val: Epoch = 91 | Loss 2.529 | Accuracy = 38.793
# Train: Epoch = 92 | Loss = 1.731 | Accuracy = 50.313
# Val: Epoch = 92 | Loss 2.524 | Accuracy = 38.793
# Train: Epoch = 93 | Loss = 1.865 | Accuracy = 46.250
# Val: Epoch = 93 | Loss 2.525 | Accuracy = 38.793
# Train: Epoch = 94 | Loss = 1.707 | Accuracy = 48.438
# Val: Epoch = 94 | Loss 2.538 | Accuracy = 39.655
# Train: Epoch = 95 | Loss = 1.803 | Accuracy = 47.500
# Val: Epoch = 95 | Loss 2.540 | Accuracy = 39.655
# Train: Epoch = 96 | Loss = 1.720 | Accuracy = 48.438
# Val: Epoch = 96 | Loss 2.534 | Accuracy = 39.655
# Train: Epoch = 97 | Loss = 1.731 | Accuracy = 52.500
# Val: Epoch = 97 | Loss 2.530 | Accuracy = 38.793
# Train: Epoch = 98 | Loss = 1.731 | Accuracy = 50.000
# Val: Epoch = 98 | Loss 2.520 | Accuracy = 39.655
# Train: Epoch = 99 | Loss = 1.714 | Accuracy = 50.625
# Val: Epoch = 99 | Loss 2.511 | Accuracy = 39.655
# Train: Epoch = 100 | Loss = 1.722 | Accuracy = 50.938
# Val: Epoch = 100 | Loss 2.510 | Accuracy = 39.655
# Train: Epoch = 101 | Loss = 1.746 | Accuracy = 50.000
# Val: Epoch = 101 | Loss 2.519 | Accuracy = 39.655
# Train: Epoch = 102 | Loss = 1.650 | Accuracy = 54.688
# Val: Epoch = 102 | Loss 2.522 | Accuracy = 39.655
# Train: Epoch = 103 | Loss = 1.735 | Accuracy = 49.375
# Val: Epoch = 103 | Loss 2.523 | Accuracy = 40.517
# Train: Epoch = 104 | Loss = 1.784 | Accuracy = 48.438
# Val: Epoch = 104 | Loss 2.534 | Accuracy = 39.655
# Train: Epoch = 105 | Loss = 1.766 | Accuracy = 45.000
# Val: Epoch = 105 | Loss 2.535 | Accuracy = 39.655
# Train: Epoch = 106 | Loss = 1.809 | Accuracy = 45.000
# Val: Epoch = 106 | Loss 2.538 | Accuracy = 40.517
# Train: Epoch = 107 | Loss = 1.717 | Accuracy = 49.688
# Val: Epoch = 107 | Loss 2.543 | Accuracy = 39.655
# Train: Epoch = 108 | Loss = 1.725 | Accuracy = 51.562
# Val: Epoch = 108 | Loss 2.545 | Accuracy = 39.655
# Train: Epoch = 109 | Loss = 1.822 | Accuracy = 45.000
# Val: Epoch = 109 | Loss 2.550 | Accuracy = 39.655
# Train: Epoch = 110 | Loss = 1.693 | Accuracy = 53.438
# Val: Epoch = 110 | Loss 2.556 | Accuracy = 39.655
# Train: Epoch = 111 | Loss = 1.817 | Accuracy = 48.750
# Val: Epoch = 111 | Loss 2.552 | Accuracy = 39.655
# Train: Epoch = 112 | Loss = 1.767 | Accuracy = 47.812
# Val: Epoch = 112 | Loss 2.554 | Accuracy = 39.655
# Train: Epoch = 113 | Loss = 1.703 | Accuracy = 52.188
# Val: Epoch = 113 | Loss 2.542 | Accuracy = 40.517
# Train: Epoch = 114 | Loss = 1.726 | Accuracy = 50.000
# Val: Epoch = 114 | Loss 2.539 | Accuracy = 40.517
# Train: Epoch = 115 | Loss = 1.768 | Accuracy = 48.750
# Val: Epoch = 115 | Loss 2.540 | Accuracy = 40.517
# Train: Epoch = 116 | Loss = 1.754 | Accuracy = 49.062
# Val: Epoch = 116 | Loss 2.540 | Accuracy = 40.517
# Train: Epoch = 117 | Loss = 1.673 | Accuracy = 50.938
# Val: Epoch = 117 | Loss 2.544 | Accuracy = 40.517
# Train: Epoch = 118 | Loss = 1.650 | Accuracy = 52.500
# Val: Epoch = 118 | Loss 2.552 | Accuracy = 39.655
# Train: Epoch = 119 | Loss = 1.684 | Accuracy = 53.438
# Val: Epoch = 119 | Loss 2.562 | Accuracy = 39.655
# Train: Epoch = 120 | Loss = 1.764 | Accuracy = 50.938
# Val: Epoch = 120 | Loss 2.557 | Accuracy = 39.655
# Train: Epoch = 121 | Loss = 1.747 | Accuracy = 50.000
# Val: Epoch = 121 | Loss 2.547 | Accuracy = 39.655
# Train: Epoch = 122 | Loss = 1.647 | Accuracy = 54.062
# Val: Epoch = 122 | Loss 2.544 | Accuracy = 41.379
# [||| NEW BEST on val||||]
# Train: Epoch = 123 | Loss = 1.799 | Accuracy = 49.688
# Val: Epoch = 123 | Loss 2.548 | Accuracy = 40.517
# Train: Epoch = 124 | Loss = 1.653 | Accuracy = 51.562
# Val: Epoch = 124 | Loss 2.540 | Accuracy = 40.517
# Train: Epoch = 125 | Loss = 1.737 | Accuracy = 49.688
# Val: Epoch = 125 | Loss 2.539 | Accuracy = 40.517
# Train: Epoch = 126 | Loss = 1.807 | Accuracy = 46.562
# Val: Epoch = 126 | Loss 2.531 | Accuracy = 40.517
# Train: Epoch = 127 | Loss = 1.765 | Accuracy = 47.188
# Val: Epoch = 127 | Loss 2.531 | Accuracy = 40.517
# Train: Epoch = 128 | Loss = 1.778 | Accuracy = 51.250
# Val: Epoch = 128 | Loss 2.526 | Accuracy = 40.517
# Train: Epoch = 129 | Loss = 1.749 | Accuracy = 49.688
# Val: Epoch = 129 | Loss 2.514 | Accuracy = 40.517
# Train: Epoch = 130 | Loss = 1.779 | Accuracy = 47.188
# Val: Epoch = 130 | Loss 2.511 | Accuracy = 40.517
# Train: Epoch = 131 | Loss = 1.663 | Accuracy = 53.438
# Val: Epoch = 131 | Loss 2.500 | Accuracy = 40.517
# Train: Epoch = 132 | Loss = 1.732 | Accuracy = 52.500
# Val: Epoch = 132 | Loss 2.504 | Accuracy = 40.517
# Train: Epoch = 133 | Loss = 1.780 | Accuracy = 47.188
# Val: Epoch = 133 | Loss 2.505 | Accuracy = 40.517
# Train: Epoch = 134 | Loss = 1.838 | Accuracy = 45.625
# Val: Epoch = 134 | Loss 2.513 | Accuracy = 40.517
# Train: Epoch = 135 | Loss = 1.666 | Accuracy = 54.062
# Val: Epoch = 135 | Loss 2.526 | Accuracy = 40.517
# Train: Epoch = 136 | Loss = 1.709 | Accuracy = 53.438
# Val: Epoch = 136 | Loss 2.537 | Accuracy = 39.655
# Train: Epoch = 137 | Loss = 1.707 | Accuracy = 50.313
# Val: Epoch = 137 | Loss 2.546 | Accuracy = 40.517
# Train: Epoch = 138 | Loss = 1.649 | Accuracy = 50.938
# Val: Epoch = 138 | Loss 2.538 | Accuracy = 41.379
# Train: Epoch = 139 | Loss = 1.758 | Accuracy = 48.750
# Val: Epoch = 139 | Loss 2.530 | Accuracy = 41.379
# Train: Epoch = 140 | Loss = 1.751 | Accuracy = 48.438
# Val: Epoch = 140 | Loss 2.536 | Accuracy = 41.379
# Train: Epoch = 141 | Loss = 1.658 | Accuracy = 53.750
# Val: Epoch = 141 | Loss 2.530 | Accuracy = 41.379
# Train: Epoch = 142 | Loss = 1.869 | Accuracy = 48.125
# Val: Epoch = 142 | Loss 2.524 | Accuracy = 40.517
# Train: Epoch = 143 | Loss = 1.728 | Accuracy = 52.188
# Val: Epoch = 143 | Loss 2.522 | Accuracy = 40.517
# Train: Epoch = 144 | Loss = 1.765 | Accuracy = 50.313
# Val: Epoch = 144 | Loss 2.524 | Accuracy = 40.517
# Train: Epoch = 145 | Loss = 1.705 | Accuracy = 51.875
# Val: Epoch = 145 | Loss 2.530 | Accuracy = 40.517
# Train: Epoch = 146 | Loss = 1.660 | Accuracy = 53.125
# Val: Epoch = 146 | Loss 2.518 | Accuracy = 40.517
# Train: Epoch = 147 | Loss = 1.829 | Accuracy = 47.500
# Val: Epoch = 147 | Loss 2.511 | Accuracy = 40.517
# Train: Epoch = 148 | Loss = 1.723 | Accuracy = 49.688
# Val: Epoch = 148 | Loss 2.510 | Accuracy = 40.517
# Train: Epoch = 149 | Loss = 1.710 | Accuracy = 50.938
# Val: Epoch = 149 | Loss 2.506 | Accuracy = 40.517
# Train: Epoch = 150 | Loss = 1.707 | Accuracy = 52.812
# Val: Epoch = 150 | Loss 2.501 | Accuracy = 40.517

# %% [markdown]
# # Stage 2 specific setup

# %%
STAGE = 2

LR = 0.0001            # The initial Learning Rate
MOMENTUM = 0.9       # Hyperparameter for SGD, keep this at 0.9 when using SGD
WEIGHT_DECAY = 4e-5  # Regularization, you can keep this at the default

NUM_EPOCHS = 150      # Total number of training epochs (iterations over dataset)
STEP_SIZE = [30, 80] # How many epochs before decreasing learning rate (if using a step-down policy)
GAMMA = 0.2          # Multiplicative factor for learning rate step-down
MEM_SIZE = 512
SEQ_LEN = 7

parameters = {
    'DEVICE': DEVICE,
    'NUM_CLASSES': NUM_CLASSES,
    'BATCH_SIZE': BATCH_SIZE,
    'LR': LR,
    'MOMENTUM': MOMENTUM,
    'WEIGHT_DECAY': WEIGHT_DECAY,
    'NUM_EPOCHS': NUM_EPOCHS,
    'STEP_SIZE': STEP_SIZE,
    'GAMMA': GAMMA,
    'MEM_SIZE': MEM_SIZE,
    'SEQ_LEN': SEQ_LEN
}

# %%
# Prepare Pytorch train/test Datasets
train_dataset = GTEA61(DATA_DIR, split='train', transform=spatial_transform,
                       seq_len=SEQ_LEN, mmaps = True, mmaps_transform = spatial_transform_mmaps, static_frames = True)
test_dataset = GTEA61(DATA_DIR, split='test', transform=spatial_transform_val,
                      seq_len=SEQ_LEN)

# Check dataset sizes
print('Train Dataset: {}'.format(len(train_dataset)))
print('Test Dataset: {}'.format(len(test_dataset)))
# Out:
# Train Dataset: 341
# Test Dataset: 116

# %%
# Dataloaders iterate over pytorch datasets and transparently provide useful functions (e.g. parallelization and shuffling)
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=4, drop_last=True)
val_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=4)

# %% [markdown]
# # Prepare Stage 2

# %%
best_old_stage = generate_model_checkpoint_name(stage=1, n_frames=SEQ_LEN, ms_block = True, \
                                                optional = '_2neur_DS__run01')
stage1_dict = os.path.join(model_folder, best_old_stage)
validate = True

model = attention_model_ms(num_classes=NUM_CLASSES, mem_size=MEM_SIZE)
model.load_state_dict(torch.load(stage1_dict))

model.train(False)

for params in model.parameters():
    params.requires_grad = False

layers_on_off = [
    model.resNet.layer4[0].conv1,
    model.resNet.layer4[0].conv2,
    model.resNet.layer4[1].conv1,
    model.resNet.layer4[1].conv2,
    model.resNet.layer4[2].conv1,
    model.resNet.layer4[2].conv2,
    model.resNet.fc,
    model.msBlock
]

layers_to_train = layers_on_off + [
    model.lstm_cell,
    model.classifier,
    model.classifier_SD
]

for layer in layers_to_train:
    for params in layer.parameters():
        params.requires_grad = True

for layer in layers_to_train:
    layer.train(True)

model.to(DEVICE)

loss_fn = nn.CrossEntropyLoss()
loss_fn_sum = nn.CrossEntropyLoss(reduction = 'sum')

trainable_params = [p for p in model.parameters() if p.requires_grad]
optimizer_fn = torch.optim.Adam(trainable_params, lr=LR, weight_decay=WEIGHT_DECAY, eps=1e-4)

optim_scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer_fn, milestones=STEP_SIZE, gamma=GAMMA)

# %% [markdown]
# # Stage 2

# %%
RUN = "_run03"

train_iter = 0
val_iter = 0
min_accuracy = 0

trainSamples = len(train_dataset) - (len(train_dataset) % BATCH_SIZE)
val_samples = len(test_dataset)

iterPerEpoch = len(train_loader)
val_steps = len(val_loader)

cudnn.benchmark
torch.autograd.set_detect_anomaly(True)
train_log, val_log = generate_log_filenames(STAGE, SEQ_LEN, ms_block = True, \
                                            optional = '_2neur_DS_asymmetric_train_SDCtrained_' + RUN)
model_checkpoint = generate_model_checkpoint_name(STAGE, SEQ_LEN, ms_block = True, \
                                                  optional = '_2neur_DS_asymmetric_train_SDCtrained_' + RUN)

train_log_file = os.path.join(model_folder, train_log)
val_log_file = os.path.join(model_folder, val_log)
train_logger_2 = Logger(**parameters)
val_logger_2 = Logger(**parameters)

for epoch in range(NUM_EPOCHS):

    epoch_loss = 0
    epoch_loss2 = 0
    numCorrTrain = 0
    
    for layer in layers_to_train:
        layer.train(True)
    
    for i, (inputs, inputs_DS, mmaps, targets) in enumerate(train_loader):

        mmaps = mmaps.permute(1, 0, 2)

        train_iter += 1

        optimizer_fn.zero_grad()

        inputVariable = inputs.permute(1, 0, 2, 3, 4).to(DEVICE)
        inputVariable_DS = inputs_DS.permute(1, 0, 2, 3, 4).to(DEVICE)
        labelVariable = targets.to(DEVICE)

        output_label, _, output_label_mmaps = model(inputVariable, mmaps = True)

        output_label_mmaps = output_label_mmaps.view(SEQ_LEN*BATCH_SIZE*MMAP_LENGTH, 2).to(DEVICE)
        mmaps = torch.flatten(mmaps).long().to(DEVICE)

        loss = loss_fn_sum(output_label_mmaps, mmaps)/(BATCH_SIZE * SEQ_LEN) + loss_fn(output_label, labelVariable)
        loss.backward()

        for layer in layers_on_off:
            for params in layer.parameters():
                params.requires_grad = False

        output_label_ds1, _ = model(inputVariable, static_frames = True)
        output_label_ds2, _ = model(inputVariable_DS, static_frames = True)
        
        gt_ds1 = torch.zeros(BATCH_SIZE).long().to(DEVICE)
        gt_ds2 = torch.ones(BATCH_SIZE).long().to(DEVICE)

        loss2 = loss_fn(output_label_ds1, gt_ds1) + loss_fn(output_label_ds2, gt_ds2)

        loss2.backward()

        for layer in layers_on_off:
            for params in layer.parameters():
                params.requires_grad = True

        optimizer_fn.step()
        
        _, predicted = torch.max(output_label.data, 1)
        numCorrTrain += torch.sum(predicted == labelVariable.data).data.item()
        step_loss = loss.data.item()
        step_loss2 = loss2.data.item()
        epoch_loss += step_loss
        epoch_loss2 += step_loss2
        train_logger_2.add_step_data(train_iter, numCorrTrain, step_loss)

        
    avg_loss = epoch_loss/iterPerEpoch
    avg_loss2 = epoch_loss2/iterPerEpoch
    trainAccuracy = (numCorrTrain / trainSamples) * 100
    train_logger_2.add_epoch_data(epoch+1, trainAccuracy, avg_loss)
    
    print('Train: Epoch = {} | Loss = {:.3f} | Loss2 = {:.3f} | Accuracy = {:.3f}'.format(epoch+1, avg_loss, avg_loss2, trainAccuracy))

    if validate is not None:

        if (epoch+1) % 1 == 0:

            model.train(False)
            val_loss_epoch = 0
            numCorr = 0

            for j, (inputs, targets) in enumerate(val_loader):

                val_iter += 1

                inputVariable = inputs.permute(1, 0, 2, 3, 4).to(DEVICE)
                labelVariable = targets.to(DEVICE)
                
                output_label, _ = model(inputVariable)

                val_loss = loss_fn(output_label, labelVariable)
                val_loss_step = val_loss.data.item()
                val_loss_epoch += val_loss_step

                _, predicted = torch.max(output_label.data, 1)

                numCorr += torch.sum(predicted == labelVariable.data).data.item()
                val_logger_2.add_step_data(val_iter, numCorr, val_loss_step)

            val_accuracy = (numCorr / val_samples) * 100
            avg_val_loss = val_loss_epoch / val_steps

            print('Val: Epoch = {} | Loss {:.3f} | Accuracy = {:.3f}'.format(epoch + 1, avg_val_loss, val_accuracy))
            
            val_logger_2.add_epoch_data(epoch+1, val_accuracy, avg_val_loss)
            
            if val_accuracy > min_accuracy:
                print("[||| NEW BEST on val |||]")
                save_path_model = os.path.join(model_folder, model_checkpoint)
                torch.save(model.state_dict(), save_path_model)
                min_accuracy = val_accuracy
            
    optim_scheduler.step()

    train_logger_2.save(train_log_file)
    val_logger_2.save(val_log_file)
# Out:
# Train: Epoch = 1 | Loss = 35.652 | Loss2 = 1.480 | Accuracy = 39.375
# Val: Epoch = 1 | Loss 2.214 | Accuracy = 40.517
# [||| NEW BEST on val |||]
# Train: Epoch = 2 | Loss = 35.605 | Loss2 = 1.451 | Accuracy = 39.062
# Val: Epoch = 2 | Loss 2.334 | Accuracy = 38.793
# Train: Epoch = 3 | Loss = 35.473 | Loss2 = 1.407 | Accuracy = 40.938
# Val: Epoch = 3 | Loss 1.949 | Accuracy = 37.069
# Train: Epoch = 4 | Loss = 35.412 | Loss2 = 1.368 | Accuracy = 43.438
# Val: Epoch = 4 | Loss 1.972 | Accuracy = 47.414
# [||| NEW BEST on val |||]
# Train: Epoch = 5 | Loss = 35.372 | Loss2 = 1.400 | Accuracy = 47.188
# Val: Epoch = 5 | Loss 2.022 | Accuracy = 43.103
# Train: Epoch = 6 | Loss = 35.392 | Loss2 = 1.339 | Accuracy = 44.688
# Val: Epoch = 6 | Loss 2.096 | Accuracy = 43.966
# Train: Epoch = 7 | Loss = 35.341 | Loss2 = 1.292 | Accuracy = 50.000
# Val: Epoch = 7 | Loss 2.014 | Accuracy = 37.931
# Train: Epoch = 8 | Loss = 35.386 | Loss2 = 1.326 | Accuracy = 46.562
# Val: Epoch = 8 | Loss 1.855 | Accuracy = 44.828
# Train: Epoch = 9 | Loss = 35.324 | Loss2 = 1.261 | Accuracy = 48.750
# Val: Epoch = 9 | Loss 1.852 | Accuracy = 49.138
# [||| NEW BEST on val |||]
# Train: Epoch = 10 | Loss = 35.344 | Loss2 = 1.292 | Accuracy = 48.438
# Val: Epoch = 10 | Loss 1.722 | Accuracy = 47.414
# Train: Epoch = 11 | Loss = 35.153 | Loss2 = 1.269 | Accuracy = 53.125
# Val: Epoch = 11 | Loss 1.774 | Accuracy = 47.414
# Train: Epoch = 12 | Loss = 35.256 | Loss2 = 1.259 | Accuracy = 47.812
# Val: Epoch = 12 | Loss 1.945 | Accuracy = 50.000
# [||| NEW BEST on val |||]
# Train: Epoch = 13 | Loss = 35.247 | Loss2 = 1.171 | Accuracy = 49.688
# Val: Epoch = 13 | Loss 1.865 | Accuracy = 46.552
# Train: Epoch = 14 | Loss = 35.211 | Loss2 = 1.277 | Accuracy = 50.938
# Val: Epoch = 14 | Loss 1.687 | Accuracy = 54.310
# [||| NEW BEST on val |||]
# Train: Epoch = 15 | Loss = 35.236 | Loss2 = 1.169 | Accuracy = 49.688
# Val: Epoch = 15 | Loss 1.790 | Accuracy = 47.414
# Train: Epoch = 16 | Loss = 35.026 | Loss2 = 1.169 | Accuracy = 53.438
# Val: Epoch = 16 | Loss 1.881 | Accuracy = 46.552
# Train: Epoch = 17 | Loss = 35.329 | Loss2 = 1.131 | Accuracy = 45.625
# Val: Epoch = 17 | Loss 1.727 | Accuracy = 45.690
# Train: Epoch = 18 | Loss = 35.185 | Loss2 = 1.131 | Accuracy = 49.375
# Val: Epoch = 18 | Loss 1.650 | Accuracy = 46.552
# Train: Epoch = 19 | Loss = 35.150 | Loss2 = 1.047 | Accuracy = 47.812
# Val: Epoch = 19 | Loss 1.751 | Accuracy = 46.552
# Train: Epoch = 20 | Loss = 35.075 | Loss2 = 1.062 | Accuracy = 52.812
# Val: Epoch = 20 | Loss 1.687 | Accuracy = 46.552
# Train: Epoch = 21 | Loss = 35.077 | Loss2 = 1.102 | Accuracy = 55.312
# Val: Epoch = 21 | Loss 1.810 | Accuracy = 44.828
# Train: Epoch = 22 | Loss = 34.951 | Loss2 = 1.015 | Accuracy = 61.875
# Val: Epoch = 22 | Loss 1.760 | Accuracy = 50.862
# Train: Epoch = 23 | Loss = 35.007 | Loss2 = 1.049 | Accuracy = 56.875
# Val: Epoch = 23 | Loss 1.701 | Accuracy = 50.000
# Train: Epoch = 24 | Loss = 34.996 | Loss2 = 1.033 | Accuracy = 54.375
# Val: Epoch = 24 | Loss 1.691 | Accuracy = 51.724
# Train: Epoch = 25 | Loss = 35.111 | Loss2 = 1.028 | Accuracy = 52.188
# Val: Epoch = 25 | Loss 1.744 | Accuracy = 45.690
# Train: Epoch = 26 | Loss = 35.020 | Loss2 = 0.940 | Accuracy = 52.812
# Val: Epoch = 26 | Loss 1.769 | Accuracy = 46.552
# Train: Epoch = 27 | Loss = 35.006 | Loss2 = 0.897 | Accuracy = 55.625
# Val: Epoch = 27 | Loss 2.052 | Accuracy = 37.931
# Train: Epoch = 28 | Loss = 34.835 | Loss2 = 0.955 | Accuracy = 61.250
# Val: Epoch = 28 | Loss 1.657 | Accuracy = 46.552
# Train: Epoch = 29 | Loss = 35.022 | Loss2 = 0.939 | Accuracy = 56.875
# Val: Epoch = 29 | Loss 1.868 | Accuracy = 43.966
# Train: Epoch = 30 | Loss = 34.902 | Loss2 = 0.944 | Accuracy = 59.062
# Val: Epoch = 30 | Loss 1.936 | Accuracy = 45.690
# Train: Epoch = 31 | Loss = 35.045 | Loss2 = 0.936 | Accuracy = 54.375
# Val: Epoch = 31 | Loss 1.800 | Accuracy = 43.103
# Train: Epoch = 32 | Loss = 34.841 | Loss2 = 0.901 | Accuracy = 60.000
# Val: Epoch = 32 | Loss 1.709 | Accuracy = 50.000
# Train: Epoch = 33 | Loss = 34.818 | Loss2 = 0.894 | Accuracy = 60.625
# Val: Epoch = 33 | Loss 1.721 | Accuracy = 44.828
# Train: Epoch = 34 | Loss = 34.794 | Loss2 = 0.913 | Accuracy = 66.250
# Val: Epoch = 34 | Loss 1.675 | Accuracy = 47.414
# Train: Epoch = 35 | Loss = 34.751 | Loss2 = 0.961 | Accuracy = 64.375
# Val: Epoch = 35 | Loss 1.656 | Accuracy = 49.138
# Train: Epoch = 36 | Loss = 34.702 | Loss2 = 0.919 | Accuracy = 66.562
# Val: Epoch = 36 | Loss 1.605 | Accuracy = 52.586
# Train: Epoch = 37 | Loss = 34.775 | Loss2 = 0.943 | Accuracy = 63.750
# Val: Epoch = 37 | Loss 1.594 | Accuracy = 52.586
# Train: Epoch = 38 | Loss = 34.755 | Loss2 = 0.912 | Accuracy = 62.500
# Val: Epoch = 38 | Loss 1.547 | Accuracy = 49.138
# Train: Epoch = 39 | Loss = 34.604 | Loss2 = 0.885 | Accuracy = 65.938
# Val: Epoch = 39 | Loss 1.477 | Accuracy = 50.000
# Train: Epoch = 40 | Loss = 34.772 | Loss2 = 0.913 | Accuracy = 62.500
# Val: Epoch = 40 | Loss 1.502 | Accuracy = 50.862
# Train: Epoch = 41 | Loss = 34.716 | Loss2 = 0.940 | Accuracy = 61.875
# Val: Epoch = 41 | Loss 1.526 | Accuracy = 49.138
# Train: Epoch = 42 | Loss = 34.774 | Loss2 = 0.897 | Accuracy = 62.500
# Val: Epoch = 42 | Loss 1.557 | Accuracy = 51.724
# Train: Epoch = 43 | Loss = 34.686 | Loss2 = 0.904 | Accuracy = 66.250
# Val: Epoch = 43 | Loss 1.549 | Accuracy = 52.586
# Train: Epoch = 44 | Loss = 34.786 | Loss2 = 0.889 | Accuracy = 61.875
# Val: Epoch = 44 | Loss 1.567 | Accuracy = 50.000
# Train: Epoch = 45 | Loss = 34.780 | Loss2 = 0.914 | Accuracy = 61.250
# Val: Epoch = 45 | Loss 1.566 | Accuracy = 50.000
# Train: Epoch = 46 | Loss = 34.706 | Loss2 = 0.884 | Accuracy = 64.375
# Val: Epoch = 46 | Loss 1.572 | Accuracy = 50.000
# Train: Epoch = 47 | Loss = 34.645 | Loss2 = 0.858 | Accuracy = 66.562
# Val: Epoch = 47 | Loss 1.544 | Accuracy = 49.138
# Train: Epoch = 48 | Loss = 34.587 | Loss2 = 0.874 | Accuracy = 67.812
# Val: Epoch = 48 | Loss 1.501 | Accuracy = 52.586
# Train: Epoch = 49 | Loss = 34.691 | Loss2 = 0.879 | Accuracy = 62.187
# Val: Epoch = 49 | Loss 1.472 | Accuracy = 53.448
# Train: Epoch = 50 | Loss = 34.609 | Loss2 = 0.854 | Accuracy = 68.438
# Val: Epoch = 50 | Loss 1.609 | Accuracy = 51.724
# Train: Epoch = 51 | Loss = 34.638 | Loss2 = 0.865 | Accuracy = 68.125
# Val: Epoch = 51 | Loss 1.595 | Accuracy = 49.138
# Train: Epoch = 52 | Loss = 34.710 | Loss2 = 0.849 | Accuracy = 66.250
# Val: Epoch = 52 | Loss 1.524 | Accuracy = 53.448
# Train: Epoch = 53 | Loss = 34.646 | Loss2 = 0.860 | Accuracy = 64.375
# Val: Epoch = 53 | Loss 1.456 | Accuracy = 50.862
# Train: Epoch = 54 | Loss = 34.531 | Loss2 = 0.863 | Accuracy = 73.750
# Val: Epoch = 54 | Loss 1.471 | Accuracy = 50.000
# Train: Epoch = 55 | Loss = 34.586 | Loss2 = 0.807 | Accuracy = 66.875
# Val: Epoch = 55 | Loss 1.518 | Accuracy = 52.586
# Train: Epoch = 56 | Loss = 34.591 | Loss2 = 0.779 | Accuracy = 68.125
# Val: Epoch = 56 | Loss 1.546 | Accuracy = 50.000
# Train: Epoch = 57 | Loss = 34.633 | Loss2 = 0.856 | Accuracy = 66.250
# Val: Epoch = 57 | Loss 1.473 | Accuracy = 48.276
# Train: Epoch = 58 | Loss = 34.666 | Loss2 = 0.844 | Accuracy = 66.875
# Val: Epoch = 58 | Loss 1.534 | Accuracy = 50.000
# Train: Epoch = 59 | Loss = 34.642 | Loss2 = 0.879 | Accuracy = 65.625
# Val: Epoch = 59 | Loss 1.510 | Accuracy = 53.448
# Train: Epoch = 60 | Loss = 34.508 | Loss2 = 0.818 | Accuracy = 71.562
# Val: Epoch = 60 | Loss 1.485 | Accuracy = 52.586
# Train: Epoch = 61 | Loss = 34.552 | Loss2 = 0.846 | Accuracy = 65.000
# Val: Epoch = 61 | Loss 1.562 | Accuracy = 50.862
# Train: Epoch = 62 | Loss = 34.534 | Loss2 = 0.813 | Accuracy = 69.062
# Val: Epoch = 62 | Loss 1.496 | Accuracy = 51.724
# Train: Epoch = 63 | Loss = 34.466 | Loss2 = 0.806 | Accuracy = 69.688
# Val: Epoch = 63 | Loss 1.476 | Accuracy = 52.586
# Train: Epoch = 64 | Loss = 34.550 | Loss2 = 0.876 | Accuracy = 69.375
# Val: Epoch = 64 | Loss 1.523 | Accuracy = 50.862
# Train: Epoch = 65 | Loss = 34.586 | Loss2 = 0.867 | Accuracy = 68.438
# Val: Epoch = 65 | Loss 1.538 | Accuracy = 50.000
# Train: Epoch = 66 | Loss = 34.443 | Loss2 = 0.843 | Accuracy = 73.125
# Val: Epoch = 66 | Loss 1.604 | Accuracy = 50.862
# Train: Epoch = 67 | Loss = 34.534 | Loss2 = 0.800 | Accuracy = 67.812
# Val: Epoch = 67 | Loss 1.598 | Accuracy = 51.724
# Train: Epoch = 68 | Loss = 34.545 | Loss2 = 0.798 | Accuracy = 69.375
# Val: Epoch = 68 | Loss 1.639 | Accuracy = 50.000
# Train: Epoch = 69 | Loss = 34.482 | Loss2 = 0.785 | Accuracy = 70.625
# Val: Epoch = 69 | Loss 1.541 | Accuracy = 51.724
# Train: Epoch = 70 | Loss = 34.551 | Loss2 = 0.858 | Accuracy = 64.375
# Val: Epoch = 70 | Loss 1.619 | Accuracy = 52.586
# Train: Epoch = 71 | Loss = 34.553 | Loss2 = 0.808 | Accuracy = 70.938
# Val: Epoch = 71 | Loss 1.592 | Accuracy = 50.862
# Train: Epoch = 72 | Loss = 34.484 | Loss2 = 0.823 | Accuracy = 72.500
# Val: Epoch = 72 | Loss 1.498 | Accuracy = 51.724
# Train: Epoch = 73 | Loss = 34.562 | Loss2 = 0.879 | Accuracy = 69.062
# Val: Epoch = 73 | Loss 1.571 | Accuracy = 55.172
# [||| NEW BEST on val |||]
# Train: Epoch = 74 | Loss = 34.534 | Loss2 = 0.824 | Accuracy = 69.062
# Val: Epoch = 74 | Loss 1.567 | Accuracy = 51.724
# Train: Epoch = 75 | Loss = 34.488 | Loss2 = 0.801 | Accuracy = 71.875
# Val: Epoch = 75 | Loss 1.532 | Accuracy = 54.310
# Train: Epoch = 76 | Loss = 34.395 | Loss2 = 0.784 | Accuracy = 72.500
# Val: Epoch = 76 | Loss 1.540 | Accuracy = 51.724
# Train: Epoch = 77 | Loss = 34.497 | Loss2 = 0.900 | Accuracy = 71.250
# Val: Epoch = 77 | Loss 1.512 | Accuracy = 50.862
# Train: Epoch = 78 | Loss = 34.552 | Loss2 = 0.818 | Accuracy = 72.188
# Val: Epoch = 78 | Loss 1.554 | Accuracy = 56.897
# [||| NEW BEST on val |||]
# Train: Epoch = 79 | Loss = 34.447 | Loss2 = 0.722 | Accuracy = 70.625
# Val: Epoch = 79 | Loss 1.514 | Accuracy = 56.034
# Train: Epoch = 80 | Loss = 34.441 | Loss2 = 0.822 | Accuracy = 71.875
# Val: Epoch = 80 | Loss 1.630 | Accuracy = 50.000
# Train: Epoch = 81 | Loss = 34.461 | Loss2 = 0.775 | Accuracy = 71.250
# Val: Epoch = 81 | Loss 1.568 | Accuracy = 50.862
# Train: Epoch = 82 | Loss = 34.555 | Loss2 = 0.803 | Accuracy = 67.812
# Val: Epoch = 82 | Loss 1.550 | Accuracy = 50.862
# Train: Epoch = 83 | Loss = 34.512 | Loss2 = 0.792 | Accuracy = 68.438
# Val: Epoch = 83 | Loss 1.553 | Accuracy = 50.862
# Train: Epoch = 84 | Loss = 34.504 | Loss2 = 0.758 | Accuracy = 69.062
# Val: Epoch = 84 | Loss 1.565 | Accuracy = 52.586
# Train: Epoch = 85 | Loss = 34.446 | Loss2 = 0.794 | Accuracy = 72.500
# Val: Epoch = 85 | Loss 1.570 | Accuracy = 50.862
# Train: Epoch = 86 | Loss = 34.420 | Loss2 = 0.746 | Accuracy = 70.312
# Val: Epoch = 86 | Loss 1.564 | Accuracy = 51.724
# Train: Epoch = 87 | Loss = 34.449 | Loss2 = 0.792 | Accuracy = 72.812
# Val: Epoch = 87 | Loss 1.549 | Accuracy = 53.448
# Train: Epoch = 88 | Loss = 34.427 | Loss2 = 0.790 | Accuracy = 71.250
# Val: Epoch = 88 | Loss 1.580 | Accuracy = 51.724
# Train: Epoch = 89 | Loss = 34.382 | Loss2 = 0.792 | Accuracy = 72.812
# Val: Epoch = 89 | Loss 1.549 | Accuracy = 53.448
# Train: Epoch = 90 | Loss = 34.484 | Loss2 = 0.793 | Accuracy = 72.812
# Val: Epoch = 90 | Loss 1.532 | Accuracy = 52.586
# Train: Epoch = 91 | Loss = 34.419 | Loss2 = 0.807 | Accuracy = 75.312
# Val: Epoch = 91 | Loss 1.529 | Accuracy = 52.586
# Train: Epoch = 92 | Loss = 34.309 | Loss2 = 0.705 | Accuracy = 80.625
# Val: Epoch = 92 | Loss 1.512 | Accuracy = 52.586
# Train: Epoch = 93 | Loss = 34.396 | Loss2 = 0.846 | Accuracy = 72.188
# Val: Epoch = 93 | Loss 1.501 | Accuracy = 51.724
# Train: Epoch = 94 | Loss = 34.353 | Loss2 = 0.826 | Accuracy = 74.062
# Val: Epoch = 94 | Loss 1.521 | Accuracy = 53.448
# Train: Epoch = 95 | Loss = 34.445 | Loss2 = 0.808 | Accuracy = 73.125
# Val: Epoch = 95 | Loss 1.567 | Accuracy = 52.586
# Train: Epoch = 96 | Loss = 34.413 | Loss2 = 0.769 | Accuracy = 72.812
# Val: Epoch = 96 | Loss 1.593 | Accuracy = 51.724
# Train: Epoch = 97 | Loss = 34.331 | Loss2 = 0.795 | Accuracy = 77.188
# Val: Epoch = 97 | Loss 1.570 | Accuracy = 51.724
# Train: Epoch = 98 | Loss = 34.531 | Loss2 = 0.763 | Accuracy = 70.938
# Val: Epoch = 98 | Loss 1.544 | Accuracy = 53.448
# Train: Epoch = 99 | Loss = 34.398 | Loss2 = 0.773 | Accuracy = 70.938
# Val: Epoch = 99 | Loss 1.524 | Accuracy = 51.724
# Train: Epoch = 100 | Loss = 34.364 | Loss2 = 0.828 | Accuracy = 77.188
# Val: Epoch = 100 | Loss 1.540 | Accuracy = 51.724
# Train: Epoch = 101 | Loss = 34.358 | Loss2 = 0.791 | Accuracy = 73.750
# Val: Epoch = 101 | Loss 1.529 | Accuracy = 51.724
# Train: Epoch = 102 | Loss = 34.394 | Loss2 = 0.757 | Accuracy = 73.438
# Val: Epoch = 102 | Loss 1.523 | Accuracy = 53.448
# Train: Epoch = 103 | Loss = 34.333 | Loss2 = 0.784 | Accuracy = 77.188
# Val: Epoch = 103 | Loss 1.503 | Accuracy = 55.172
# Train: Epoch = 104 | Loss = 34.468 | Loss2 = 0.772 | Accuracy = 71.875
# Val: Epoch = 104 | Loss 1.524 | Accuracy = 53.448
# Train: Epoch = 105 | Loss = 34.388 | Loss2 = 0.759 | Accuracy = 73.125
# Val: Epoch = 105 | Loss 1.580 | Accuracy = 53.448
# Train: Epoch = 106 | Loss = 34.382 | Loss2 = 0.735 | Accuracy = 70.938
# Val: Epoch = 106 | Loss 1.568 | Accuracy = 52.586
# Train: Epoch = 107 | Loss = 34.368 | Loss2 = 0.765 | Accuracy = 75.312
# Val: Epoch = 107 | Loss 1.567 | Accuracy = 51.724
# Train: Epoch = 108 | Loss = 34.306 | Loss2 = 0.760 | Accuracy = 75.312
# Val: Epoch = 108 | Loss 1.559 | Accuracy = 53.448
# Train: Epoch = 109 | Loss = 34.323 | Loss2 = 0.730 | Accuracy = 79.062
# Val: Epoch = 109 | Loss 1.573 | Accuracy = 54.310
# Train: Epoch = 110 | Loss = 34.375 | Loss2 = 0.748 | Accuracy = 74.375
# Val: Epoch = 110 | Loss 1.589 | Accuracy = 55.172
# Train: Epoch = 111 | Loss = 34.420 | Loss2 = 0.726 | Accuracy = 74.688
# Val: Epoch = 111 | Loss 1.572 | Accuracy = 55.172
# Train: Epoch = 112 | Loss = 34.382 | Loss2 = 0.824 | Accuracy = 71.562
# Val: Epoch = 112 | Loss 1.547 | Accuracy = 54.310
# Train: Epoch = 113 | Loss = 34.476 | Loss2 = 0.738 | Accuracy = 70.000
# Val: Epoch = 113 | Loss 1.535 | Accuracy = 55.172
# Train: Epoch = 114 | Loss = 34.360 | Loss2 = 0.740 | Accuracy = 73.125
# Val: Epoch = 114 | Loss 1.527 | Accuracy = 54.310
# Train: Epoch = 115 | Loss = 34.411 | Loss2 = 0.773 | Accuracy = 71.562
# Val: Epoch = 115 | Loss 1.534 | Accuracy = 56.034
# Train: Epoch = 116 | Loss = 34.394 | Loss2 = 0.769 | Accuracy = 70.625
# Val: Epoch = 116 | Loss 1.555 | Accuracy = 54.310
# Train: Epoch = 117 | Loss = 34.333 | Loss2 = 0.802 | Accuracy = 76.875
# Val: Epoch = 117 | Loss 1.562 | Accuracy = 55.172
# Train: Epoch = 118 | Loss = 34.496 | Loss2 = 0.749 | Accuracy = 71.875
# Val: Epoch = 118 | Loss 1.545 | Accuracy = 53.448
# Train: Epoch = 119 | Loss = 34.287 | Loss2 = 0.790 | Accuracy = 79.375
# Val: Epoch = 119 | Loss 1.522 | Accuracy = 54.310
# Train: Epoch = 120 | Loss = 34.448 | Loss2 = 0.784 | Accuracy = 71.875
# Val: Epoch = 120 | Loss 1.531 | Accuracy = 54.310
# Train: Epoch = 121 | Loss = 34.348 | Loss2 = 0.827 | Accuracy = 76.250
# Val: Epoch = 121 | Loss 1.568 | Accuracy = 54.310
# Train: Epoch = 122 | Loss = 34.339 | Loss2 = 0.743 | Accuracy = 76.875
# Val: Epoch = 122 | Loss 1.573 | Accuracy = 55.172
# Train: Epoch = 123 | Loss = 34.268 | Loss2 = 0.853 | Accuracy = 80.000
# Val: Epoch = 123 | Loss 1.564 | Accuracy = 55.172
# Train: Epoch = 124 | Loss = 34.314 | Loss2 = 0.708 | Accuracy = 77.188
# Val: Epoch = 124 | Loss 1.577 | Accuracy = 54.310
# Train: Epoch = 125 | Loss = 34.408 | Loss2 = 0.741 | Accuracy = 71.562
# Val: Epoch = 125 | Loss 1.566 | Accuracy = 55.172
# Train: Epoch = 126 | Loss = 34.374 | Loss2 = 0.761 | Accuracy = 73.438
# Val: Epoch = 126 | Loss 1.544 | Accuracy = 54.310
# Train: Epoch = 127 | Loss = 34.472 | Loss2 = 0.801 | Accuracy = 71.875
# Val: Epoch = 127 | Loss 1.523 | Accuracy = 55.172
# Train: Epoch = 128 | Loss = 34.336 | Loss2 = 0.707 | Accuracy = 74.375
# Val: Epoch = 128 | Loss 1.532 | Accuracy = 53.448
# Train: Epoch = 129 | Loss = 34.242 | Loss2 = 0.706 | Accuracy = 78.125
# Val: Epoch = 129 | Loss 1.542 | Accuracy = 52.586
# Train: Epoch = 130 | Loss = 34.433 | Loss2 = 0.693 | Accuracy = 71.250
# Val: Epoch = 130 | Loss 1.573 | Accuracy = 51.724
# Train: Epoch = 131 | Loss = 34.257 | Loss2 = 0.749 | Accuracy = 76.562
# Val: Epoch = 131 | Loss 1.581 | Accuracy = 51.724
# Train: Epoch = 132 | Loss = 34.353 | Loss2 = 0.752 | Accuracy = 74.688
# Val: Epoch = 132 | Loss 1.604 | Accuracy = 53.448
# Train: Epoch = 133 | Loss = 34.370 | Loss2 = 0.759 | Accuracy = 72.188
# Val: Epoch = 133 | Loss 1.612 | Accuracy = 50.862
# Train: Epoch = 134 | Loss = 34.324 | Loss2 = 0.733 | Accuracy = 76.875
# Val: Epoch = 134 | Loss 1.604 | Accuracy = 53.448
# Train: Epoch = 135 | Loss = 34.317 | Loss2 = 0.689 | Accuracy = 75.625
# Val: Epoch = 135 | Loss 1.582 | Accuracy = 53.448
# Train: Epoch = 136 | Loss = 34.317 | Loss2 = 0.707 | Accuracy = 76.875
# Val: Epoch = 136 | Loss 1.572 | Accuracy = 51.724
# Train: Epoch = 137 | Loss = 34.360 | Loss2 = 0.773 | Accuracy = 75.625
# Val: Epoch = 137 | Loss 1.565 | Accuracy = 50.862
# Train: Epoch = 138 | Loss = 34.273 | Loss2 = 0.750 | Accuracy = 80.000
# Val: Epoch = 138 | Loss 1.570 | Accuracy = 50.862
# Train: Epoch = 139 | Loss = 34.327 | Loss2 = 0.729 | Accuracy = 75.938
# Val: Epoch = 139 | Loss 1.612 | Accuracy = 52.586
# Train: Epoch = 140 | Loss = 34.349 | Loss2 = 0.700 | Accuracy = 74.062
# Val: Epoch = 140 | Loss 1.630 | Accuracy = 52.586
# Train: Epoch = 141 | Loss = 34.331 | Loss2 = 0.694 | Accuracy = 76.250
# Val: Epoch = 141 | Loss 1.591 | Accuracy = 52.586
# Train: Epoch = 142 | Loss = 34.397 | Loss2 = 0.736 | Accuracy = 73.750
# Val: Epoch = 142 | Loss 1.557 | Accuracy = 51.724
# Train: Epoch = 143 | Loss = 34.358 | Loss2 = 0.694 | Accuracy = 75.312
# Val: Epoch = 143 | Loss 1.537 | Accuracy = 51.724
# Train: Epoch = 144 | Loss = 34.381 | Loss2 = 0.697 | Accuracy = 73.750
# Val: Epoch = 144 | Loss 1.526 | Accuracy = 51.724
# Train: Epoch = 145 | Loss = 34.516 | Loss2 = 0.767 | Accuracy = 69.062
# Val: Epoch = 145 | Loss 1.551 | Accuracy = 52.586
# Train: Epoch = 146 | Loss = 34.367 | Loss2 = 0.835 | Accuracy = 77.188
# Val: Epoch = 146 | Loss 1.591 | Accuracy = 50.000
# Train: Epoch = 147 | Loss = 34.353 | Loss2 = 0.756 | Accuracy = 75.625
# Val: Epoch = 147 | Loss 1.540 | Accuracy = 52.586
# Train: Epoch = 148 | Loss = 34.329 | Loss2 = 0.745 | Accuracy = 75.625
# Val: Epoch = 148 | Loss 1.527 | Accuracy = 52.586
# Train: Epoch = 149 | Loss = 34.385 | Loss2 = 0.798 | Accuracy = 73.125
# Val: Epoch = 149 | Loss 1.526 | Accuracy = 52.586
# Train: Epoch = 150 | Loss = 34.385 | Loss2 = 0.688 | Accuracy = 73.750
# Val: Epoch = 150 | Loss 1.516 | Accuracy = 53.448

# %% [markdown]
# # Stage 2 specific setup

# %%
STAGE = 2

LR = 0.0001            # The initial Learning Rate
MOMENTUM = 0.9       # Hyperparameter for SGD, keep this at 0.9 when using SGD
WEIGHT_DECAY = 4e-5  # Regularization, you can keep this at the default

NUM_EPOCHS = 150      # Total number of training epochs (iterations over dataset)
STEP_SIZE = [30, 80] # How many epochs before decreasing learning rate (if using a step-down policy)
GAMMA = 0.2          # Multiplicative factor for learning rate step-down
MEM_SIZE = 512
SEQ_LEN = 7
ALPHA = 0.5

parameters = {
    'DEVICE': DEVICE,
    'NUM_CLASSES': NUM_CLASSES,
    'BATCH_SIZE': BATCH_SIZE,
    'LR': LR,
    'MOMENTUM': MOMENTUM,
    'WEIGHT_DECAY': WEIGHT_DECAY,
    'NUM_EPOCHS': NUM_EPOCHS,
    'STEP_SIZE': STEP_SIZE,
    'GAMMA': GAMMA,
    'MEM_SIZE': MEM_SIZE,
    'SEQ_LEN': SEQ_LEN
}

# %%
# Prepare Pytorch train/test Datasets
train_dataset = GTEA61(DATA_DIR, split='train', transform=spatial_transform,
                       seq_len=SEQ_LEN, mmaps = True, mmaps_transform = spatial_transform_mmaps, static_frames = True)
test_dataset = GTEA61(DATA_DIR, split='test', transform=spatial_transform_val,
                      seq_len=SEQ_LEN)

# Check dataset sizes
print('Train Dataset: {}'.format(len(train_dataset)))
print('Test Dataset: {}'.format(len(test_dataset)))
# Out:
# Train Dataset: 341
# Test Dataset: 116

# %%
# Dataloaders iterate over pytorch datasets and transparently provide useful functions (e.g. parallelization and shuffling)
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=4, drop_last=True)
val_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=4)

# %% [markdown]
# # Prepare Stage 2

# %%
best_old_stage = generate_model_checkpoint_name(stage=1, n_frames=SEQ_LEN, ms_block = True, \
                                                optional = '_2neur_DS__run01')
stage1_dict = os.path.join(model_folder, best_old_stage)
validate = True

model = attention_model_ms(num_classes=NUM_CLASSES, mem_size=MEM_SIZE)
model.load_state_dict(torch.load(stage1_dict))

model.train(False)

for params in model.parameters():
    params.requires_grad = False

layers_on_off = [
    model.resNet.layer4[0].conv1,
    model.resNet.layer4[0].conv2,
    model.resNet.layer4[1].conv1,
    model.resNet.layer4[1].conv2,
    model.resNet.layer4[2].conv1,
    model.resNet.layer4[2].conv2,
    model.resNet.fc,
    model.msBlock
]

layers_to_train = layers_on_off + [
    model.lstm_cell,
    model.classifier,
    model.classifier_SD
]

for layer in layers_to_train:
    for params in layer.parameters():
        params.requires_grad = True

for layer in layers_to_train:
    layer.train(True)

model.to(DEVICE)

loss_fn = nn.CrossEntropyLoss()
loss_fn_sum = nn.CrossEntropyLoss(reduction = 'sum')

trainable_params = [p for p in model.parameters() if p.requires_grad]
optimizer_fn = torch.optim.Adam(trainable_params, lr=LR, weight_decay=WEIGHT_DECAY, eps=1e-4)

optim_scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer_fn, milestones=STEP_SIZE, gamma=GAMMA)

# %% [markdown]
# # Stage 2

# %%
RUN = "_run01"

train_iter = 0
val_iter = 0
min_accuracy = 0

trainSamples = len(train_dataset) - (len(train_dataset) % BATCH_SIZE)
val_samples = len(test_dataset)

iterPerEpoch = len(train_loader)
val_steps = len(val_loader)

cudnn.benchmark
torch.autograd.set_detect_anomaly(True)
train_log, val_log = generate_log_filenames(STAGE, SEQ_LEN, ms_block = True, \
                                            optional = '_2neur_DS_alpha_' + RUN)
model_checkpoint = generate_model_checkpoint_name(STAGE, SEQ_LEN, ms_block = True, \
                                                  optional = '_2neur_DS_alpha_' + RUN)

train_log_file = os.path.join(model_folder, train_log)
val_log_file = os.path.join(model_folder, val_log)
train_logger_2 = Logger(**parameters)
val_logger_2 = Logger(**parameters)

for epoch in range(NUM_EPOCHS):

    epoch_loss = 0
    epoch_loss2 = 0
    numCorrTrain = 0
    
    for layer in layers_to_train:
        layer.train(True)
    
    for i, (inputs, inputs_DS, mmaps, targets) in enumerate(train_loader):

        mmaps = mmaps.permute(1, 0, 2)

        train_iter += 1

        optimizer_fn.zero_grad()

        inputVariable = inputs.permute(1, 0, 2, 3, 4).to(DEVICE)
        inputVariable_DS = inputs_DS.permute(1, 0, 2, 3, 4).to(DEVICE)
        labelVariable = targets.to(DEVICE)

        output_label, _, output_label_mmaps = model(inputVariable, mmaps = True)

        output_label_mmaps = output_label_mmaps.view(SEQ_LEN*BATCH_SIZE*MMAP_LENGTH, 2).to(DEVICE)
        mmaps = torch.flatten(mmaps).long().to(DEVICE)

        loss = loss_fn_sum(output_label_mmaps, mmaps)/(BATCH_SIZE * SEQ_LEN) + loss_fn(output_label, labelVariable)
        loss.backward()

        for layer in layers_on_off:
            for params in layer.parameters():
                params.requires_grad = False

        output_label_ds1, _ = model(inputVariable, static_frames = True)
        output_label_ds2, _ = model(inputVariable_DS, static_frames = True)
        
        gt_ds1 = torch.zeros(BATCH_SIZE).long().to(DEVICE)
        gt_ds2 = torch.ones(BATCH_SIZE).long().to(DEVICE)

        loss2 = ALPHA * (loss_fn(output_label_ds1, gt_ds1) + loss_fn(output_label_ds2, gt_ds2))

        loss2.backward()

        for layer in layers_on_off:
            for params in layer.parameters():
                params.requires_grad = True

        optimizer_fn.step()
        
        _, predicted = torch.max(output_label.data, 1)
        numCorrTrain += torch.sum(predicted == labelVariable.data).data.item()
        step_loss = loss.data.item()
        step_loss2 = loss2.data.item()
        epoch_loss += step_loss
        epoch_loss2 += step_loss2
        train_logger_2.add_step_data(train_iter, numCorrTrain, step_loss)

        
    avg_loss = epoch_loss/iterPerEpoch
    avg_loss2 = epoch_loss2/iterPerEpoch
    trainAccuracy = (numCorrTrain / trainSamples) * 100
    train_logger_2.add_epoch_data(epoch+1, trainAccuracy, avg_loss)
    
    print('Train: Epoch = {} | Loss = {:.3f} | Loss2 = {:.3f} | Accuracy = {:.3f}'.format(epoch+1, avg_loss, avg_loss2, trainAccuracy))

    if validate is not None:

        if (epoch+1) % 1 == 0:

            model.train(False)
            val_loss_epoch = 0
            numCorr = 0

            for j, (inputs, targets) in enumerate(val_loader):

                val_iter += 1

                inputVariable = inputs.permute(1, 0, 2, 3, 4).to(DEVICE)
                labelVariable = targets.to(DEVICE)
                
                output_label, _ = model(inputVariable)

                val_loss = loss_fn(output_label, labelVariable)
                val_loss_step = val_loss.data.item()
                val_loss_epoch += val_loss_step

                _, predicted = torch.max(output_label.data, 1)

                numCorr += torch.sum(predicted == labelVariable.data).data.item()
                val_logger_2.add_step_data(val_iter, numCorr, val_loss_step)

            val_accuracy = (numCorr / val_samples) * 100
            avg_val_loss = val_loss_epoch / val_steps

            print('Val: Epoch = {} | Loss {:.3f} | Accuracy = {:.3f}'.format(epoch + 1, avg_val_loss, val_accuracy))
            
            val_logger_2.add_epoch_data(epoch+1, val_accuracy, avg_val_loss)
            
            if val_accuracy > min_accuracy:
                print("[||| NEW BEST on val |||]")
                save_path_model = os.path.join(model_folder, model_checkpoint)
                torch.save(model.state_dict(), save_path_model)
                min_accuracy = val_accuracy
            
    optim_scheduler.step()

    train_logger_2.save(train_log_file)
    val_logger_2.save(val_log_file)
# Out:
# Train: Epoch = 1 | Loss = 36.228 | Loss2 = 0.746 | Accuracy = 33.750
# Val: Epoch = 1 | Loss 2.457 | Accuracy = 32.759
# [||| NEW BEST on val |||]
# Train: Epoch = 2 | Loss = 35.774 | Loss2 = 0.769 | Accuracy = 38.125
# Val: Epoch = 2 | Loss 2.180 | Accuracy = 41.379
# [||| NEW BEST on val |||]
# Train: Epoch = 3 | Loss = 35.584 | Loss2 = 0.776 | Accuracy = 39.062
# Val: Epoch = 3 | Loss 2.091 | Accuracy = 43.966
# [||| NEW BEST on val |||]
# Train: Epoch = 4 | Loss = 35.316 | Loss2 = 0.753 | Accuracy = 50.000
# Val: Epoch = 4 | Loss 2.031 | Accuracy = 40.517
# Train: Epoch = 5 | Loss = 35.466 | Loss2 = 0.725 | Accuracy = 47.500
# Val: Epoch = 5 | Loss 1.925 | Accuracy = 48.276
# [||| NEW BEST on val |||]
# Train: Epoch = 6 | Loss = 35.349 | Loss2 = 0.758 | Accuracy = 46.562
# Val: Epoch = 6 | Loss 1.931 | Accuracy = 51.724
# [||| NEW BEST on val |||]
# Train: Epoch = 7 | Loss = 35.332 | Loss2 = 0.704 | Accuracy = 49.688
# Val: Epoch = 7 | Loss 1.973 | Accuracy = 46.552
# Train: Epoch = 8 | Loss = 35.183 | Loss2 = 0.711 | Accuracy = 48.125
# Val: Epoch = 8 | Loss 1.997 | Accuracy = 43.966
# Train: Epoch = 9 | Loss = 35.356 | Loss2 = 0.717 | Accuracy = 45.625
# Val: Epoch = 9 | Loss 1.978 | Accuracy = 37.931
# Train: Epoch = 10 | Loss = 35.417 | Loss2 = 0.678 | Accuracy = 45.625
# Val: Epoch = 10 | Loss 1.882 | Accuracy = 44.828
# Train: Epoch = 11 | Loss = 35.354 | Loss2 = 0.686 | Accuracy = 46.562
# Val: Epoch = 11 | Loss 1.798 | Accuracy = 46.552
# Train: Epoch = 12 | Loss = 35.332 | Loss2 = 0.655 | Accuracy = 45.312
# Val: Epoch = 12 | Loss 1.973 | Accuracy = 50.862
# Train: Epoch = 13 | Loss = 35.197 | Loss2 = 0.673 | Accuracy = 50.625
# Val: Epoch = 13 | Loss 1.756 | Accuracy = 56.034
# [||| NEW BEST on val |||]
# Train: Epoch = 14 | Loss = 35.194 | Loss2 = 0.654 | Accuracy = 51.875
# Val: Epoch = 14 | Loss 1.780 | Accuracy = 52.586
# Train: Epoch = 15 | Loss = 35.184 | Loss2 = 0.653 | Accuracy = 52.188
# Val: Epoch = 15 | Loss 1.736 | Accuracy = 51.724
# Train: Epoch = 16 | Loss = 35.096 | Loss2 = 0.674 | Accuracy = 54.688
# Val: Epoch = 16 | Loss 1.782 | Accuracy = 48.276
# Train: Epoch = 17 | Loss = 35.162 | Loss2 = 0.657 | Accuracy = 50.938
# Val: Epoch = 17 | Loss 1.859 | Accuracy = 46.552
# Train: Epoch = 18 | Loss = 35.156 | Loss2 = 0.646 | Accuracy = 50.938
# Val: Epoch = 18 | Loss 1.705 | Accuracy = 53.448
# Train: Epoch = 19 | Loss = 35.148 | Loss2 = 0.661 | Accuracy = 54.062
# Val: Epoch = 19 | Loss 1.715 | Accuracy = 50.000
# Train: Epoch = 20 | Loss = 35.190 | Loss2 = 0.654 | Accuracy = 49.375
# Val: Epoch = 20 | Loss 1.731 | Accuracy = 48.276
# Train: Epoch = 21 | Loss = 35.054 | Loss2 = 0.643 | Accuracy = 53.125
# Val: Epoch = 21 | Loss 1.628 | Accuracy = 51.724
# Train: Epoch = 22 | Loss = 35.157 | Loss2 = 0.610 | Accuracy = 51.250
# Val: Epoch = 22 | Loss 1.770 | Accuracy = 48.276
# Train: Epoch = 23 | Loss = 35.042 | Loss2 = 0.628 | Accuracy = 53.750
# Val: Epoch = 23 | Loss 1.681 | Accuracy = 52.586
# Train: Epoch = 24 | Loss = 35.050 | Loss2 = 0.609 | Accuracy = 50.625
# Val: Epoch = 24 | Loss 1.681 | Accuracy = 50.862
# Train: Epoch = 25 | Loss = 35.004 | Loss2 = 0.643 | Accuracy = 59.375
# Val: Epoch = 25 | Loss 1.691 | Accuracy = 49.138
# Train: Epoch = 26 | Loss = 34.931 | Loss2 = 0.638 | Accuracy = 57.188
# Val: Epoch = 26 | Loss 1.890 | Accuracy = 44.828
# Train: Epoch = 27 | Loss = 34.998 | Loss2 = 0.610 | Accuracy = 57.500
# Val: Epoch = 27 | Loss 1.710 | Accuracy = 50.000
# Train: Epoch = 28 | Loss = 34.821 | Loss2 = 0.616 | Accuracy = 60.000
# Val: Epoch = 28 | Loss 1.530 | Accuracy = 53.448
# Train: Epoch = 29 | Loss = 34.832 | Loss2 = 0.637 | Accuracy = 62.813
# Val: Epoch = 29 | Loss 1.728 | Accuracy = 49.138
# Train: Epoch = 30 | Loss = 34.819 | Loss2 = 0.563 | Accuracy = 62.500
# Val: Epoch = 30 | Loss 1.545 | Accuracy = 51.724
# Train: Epoch = 31 | Loss = 34.868 | Loss2 = 0.594 | Accuracy = 59.062
# Val: Epoch = 31 | Loss 1.593 | Accuracy = 53.448
# Train: Epoch = 32 | Loss = 34.716 | Loss2 = 0.623 | Accuracy = 63.125
# Val: Epoch = 32 | Loss 1.628 | Accuracy = 52.586
# Train: Epoch = 33 | Loss = 34.669 | Loss2 = 0.609 | Accuracy = 65.625
# Val: Epoch = 33 | Loss 1.507 | Accuracy = 52.586
# Train: Epoch = 34 | Loss = 34.797 | Loss2 = 0.585 | Accuracy = 61.875
# Val: Epoch = 34 | Loss 1.519 | Accuracy = 50.000
# Train: Epoch = 35 | Loss = 34.829 | Loss2 = 0.626 | Accuracy = 62.500
# Val: Epoch = 35 | Loss 1.603 | Accuracy = 52.586
# Train: Epoch = 36 | Loss = 34.585 | Loss2 = 0.598 | Accuracy = 67.500
# Val: Epoch = 36 | Loss 1.616 | Accuracy = 52.586
# Train: Epoch = 37 | Loss = 34.696 | Loss2 = 0.617 | Accuracy = 63.438
# Val: Epoch = 37 | Loss 1.599 | Accuracy = 53.448
# Train: Epoch = 38 | Loss = 34.642 | Loss2 = 0.606 | Accuracy = 64.688
# Val: Epoch = 38 | Loss 1.585 | Accuracy = 51.724
# Train: Epoch = 39 | Loss = 34.708 | Loss2 = 0.620 | Accuracy = 66.875
# Val: Epoch = 39 | Loss 1.550 | Accuracy = 51.724
# Train: Epoch = 40 | Loss = 34.657 | Loss2 = 0.609 | Accuracy = 62.813
# Val: Epoch = 40 | Loss 1.520 | Accuracy = 55.172
# Train: Epoch = 41 | Loss = 34.554 | Loss2 = 0.598 | Accuracy = 67.812
# Val: Epoch = 41 | Loss 1.518 | Accuracy = 50.862
# Train: Epoch = 42 | Loss = 34.669 | Loss2 = 0.614 | Accuracy = 66.250
# Val: Epoch = 42 | Loss 1.624 | Accuracy = 54.310
# Train: Epoch = 43 | Loss = 34.614 | Loss2 = 0.623 | Accuracy = 68.750
# Val: Epoch = 43 | Loss 1.510 | Accuracy = 51.724
# Train: Epoch = 44 | Loss = 34.458 | Loss2 = 0.594 | Accuracy = 73.750
# Val: Epoch = 44 | Loss 1.599 | Accuracy = 50.000
# Train: Epoch = 45 | Loss = 34.752 | Loss2 = 0.627 | Accuracy = 65.312
# Val: Epoch = 45 | Loss 1.566 | Accuracy = 51.724
# Train: Epoch = 46 | Loss = 34.601 | Loss2 = 0.586 | Accuracy = 64.062
# Val: Epoch = 46 | Loss 1.594 | Accuracy = 51.724
# Train: Epoch = 47 | Loss = 34.638 | Loss2 = 0.622 | Accuracy = 66.875
# Val: Epoch = 47 | Loss 1.597 | Accuracy = 52.586
# Train: Epoch = 48 | Loss = 34.615 | Loss2 = 0.587 | Accuracy = 66.875
# Val: Epoch = 48 | Loss 1.508 | Accuracy = 52.586
# Train: Epoch = 49 | Loss = 34.564 | Loss2 = 0.553 | Accuracy = 65.625
# Val: Epoch = 49 | Loss 1.536 | Accuracy = 52.586
# Train: Epoch = 50 | Loss = 34.571 | Loss2 = 0.579 | Accuracy = 66.875
# Val: Epoch = 50 | Loss 1.527 | Accuracy = 52.586
# Train: Epoch = 51 | Loss = 34.549 | Loss2 = 0.596 | Accuracy = 69.062
# Val: Epoch = 51 | Loss 1.461 | Accuracy = 56.034
# Train: Epoch = 52 | Loss = 34.583 | Loss2 = 0.560 | Accuracy = 67.500
# Val: Epoch = 52 | Loss 1.612 | Accuracy = 50.000
# Train: Epoch = 53 | Loss = 34.580 | Loss2 = 0.586 | Accuracy = 67.188
# Val: Epoch = 53 | Loss 1.467 | Accuracy = 52.586
# Train: Epoch = 54 | Loss = 34.486 | Loss2 = 0.605 | Accuracy = 73.125
# Val: Epoch = 54 | Loss 1.508 | Accuracy = 56.897
# [||| NEW BEST on val |||]
# Train: Epoch = 55 | Loss = 34.589 | Loss2 = 0.595 | Accuracy = 66.250
# Val: Epoch = 55 | Loss 1.474 | Accuracy = 56.897
# Train: Epoch = 56 | Loss = 34.515 | Loss2 = 0.594 | Accuracy = 69.062
# Val: Epoch = 56 | Loss 1.497 | Accuracy = 56.897
# Train: Epoch = 57 | Loss = 34.722 | Loss2 = 0.572 | Accuracy = 61.562
# Val: Epoch = 57 | Loss 1.422 | Accuracy = 54.310
# Train: Epoch = 58 | Loss = 34.643 | Loss2 = 0.576 | Accuracy = 64.688
# Val: Epoch = 58 | Loss 1.494 | Accuracy = 51.724
# Train: Epoch = 59 | Loss = 34.531 | Loss2 = 0.592 | Accuracy = 70.000
# Val: Epoch = 59 | Loss 1.465 | Accuracy = 55.172
# Train: Epoch = 60 | Loss = 34.570 | Loss2 = 0.543 | Accuracy = 69.062
# Val: Epoch = 60 | Loss 1.461 | Accuracy = 57.759
# [||| NEW BEST on val |||]
# Train: Epoch = 61 | Loss = 34.518 | Loss2 = 0.575 | Accuracy = 72.812
# Val: Epoch = 61 | Loss 1.454 | Accuracy = 51.724
# Train: Epoch = 62 | Loss = 34.489 | Loss2 = 0.549 | Accuracy = 70.625
# Val: Epoch = 62 | Loss 1.472 | Accuracy = 56.897
# Train: Epoch = 63 | Loss = 34.443 | Loss2 = 0.589 | Accuracy = 70.625
# Val: Epoch = 63 | Loss 1.441 | Accuracy = 55.172
# Train: Epoch = 64 | Loss = 34.489 | Loss2 = 0.584 | Accuracy = 69.688
# Val: Epoch = 64 | Loss 1.544 | Accuracy = 54.310
# Train: Epoch = 65 | Loss = 34.634 | Loss2 = 0.597 | Accuracy = 65.625
# Val: Epoch = 65 | Loss 1.582 | Accuracy = 56.034
# Train: Epoch = 66 | Loss = 34.419 | Loss2 = 0.546 | Accuracy = 72.812
# Val: Epoch = 66 | Loss 1.506 | Accuracy = 57.759
# Train: Epoch = 67 | Loss = 34.431 | Loss2 = 0.571 | Accuracy = 73.438
# Val: Epoch = 67 | Loss 1.481 | Accuracy = 53.448
# Train: Epoch = 68 | Loss = 34.508 | Loss2 = 0.575 | Accuracy = 71.250
# Val: Epoch = 68 | Loss 1.528 | Accuracy = 55.172
# Train: Epoch = 69 | Loss = 34.354 | Loss2 = 0.585 | Accuracy = 73.750
# Val: Epoch = 69 | Loss 1.439 | Accuracy = 54.310
# Train: Epoch = 70 | Loss = 34.444 | Loss2 = 0.544 | Accuracy = 69.375
# Val: Epoch = 70 | Loss 1.426 | Accuracy = 56.897
# Train: Epoch = 71 | Loss = 34.403 | Loss2 = 0.586 | Accuracy = 73.750
# Val: Epoch = 71 | Loss 1.465 | Accuracy = 53.448
# Train: Epoch = 72 | Loss = 34.576 | Loss2 = 0.550 | Accuracy = 68.438
# Val: Epoch = 72 | Loss 1.514 | Accuracy = 52.586
# Train: Epoch = 73 | Loss = 34.450 | Loss2 = 0.583 | Accuracy = 72.812
# Val: Epoch = 73 | Loss 1.581 | Accuracy = 53.448
# Train: Epoch = 74 | Loss = 34.493 | Loss2 = 0.573 | Accuracy = 68.125
# Val: Epoch = 74 | Loss 1.473 | Accuracy = 55.172
# Train: Epoch = 75 | Loss = 34.392 | Loss2 = 0.574 | Accuracy = 76.250
# Val: Epoch = 75 | Loss 1.648 | Accuracy = 55.172
# Train: Epoch = 76 | Loss = 34.360 | Loss2 = 0.556 | Accuracy = 72.812
# Val: Epoch = 76 | Loss 1.596 | Accuracy = 53.448
# Train: Epoch = 77 | Loss = 34.381 | Loss2 = 0.548 | Accuracy = 74.375
# Val: Epoch = 77 | Loss 1.541 | Accuracy = 53.448
# Train: Epoch = 78 | Loss = 34.388 | Loss2 = 0.613 | Accuracy = 74.688
# Val: Epoch = 78 | Loss 1.589 | Accuracy = 55.172
# Train: Epoch = 79 | Loss = 34.495 | Loss2 = 0.545 | Accuracy = 72.500
# Val: Epoch = 79 | Loss 1.485 | Accuracy = 52.586
# Train: Epoch = 80 | Loss = 34.362 | Loss2 = 0.572 | Accuracy = 75.938
# Val: Epoch = 80 | Loss 1.570 | Accuracy = 55.172
# Train: Epoch = 81 | Loss = 34.335 | Loss2 = 0.565 | Accuracy = 77.188
# Val: Epoch = 81 | Loss 1.561 | Accuracy = 54.310
# Train: Epoch = 82 | Loss = 34.362 | Loss2 = 0.545 | Accuracy = 75.938
# Val: Epoch = 82 | Loss 1.561 | Accuracy = 54.310
# Train: Epoch = 83 | Loss = 34.464 | Loss2 = 0.568 | Accuracy = 71.562
# Val: Epoch = 83 | Loss 1.625 | Accuracy = 52.586
# Train: Epoch = 84 | Loss = 34.393 | Loss2 = 0.587 | Accuracy = 74.062
# Val: Epoch = 84 | Loss 1.672 | Accuracy = 51.724
# Train: Epoch = 85 | Loss = 34.324 | Loss2 = 0.572 | Accuracy = 78.750
# Val: Epoch = 85 | Loss 1.639 | Accuracy = 51.724
# Train: Epoch = 86 | Loss = 34.475 | Loss2 = 0.565 | Accuracy = 71.562
# Val: Epoch = 86 | Loss 1.607 | Accuracy = 53.448
# Train: Epoch = 87 | Loss = 34.448 | Loss2 = 0.548 | Accuracy = 75.312
# Val: Epoch = 87 | Loss 1.592 | Accuracy = 52.586
# Train: Epoch = 88 | Loss = 34.394 | Loss2 = 0.545 | Accuracy = 74.062
# Val: Epoch = 88 | Loss 1.590 | Accuracy = 52.586
# Train: Epoch = 89 | Loss = 34.409 | Loss2 = 0.570 | Accuracy = 73.750
# Val: Epoch = 89 | Loss 1.610 | Accuracy = 54.310
# Train: Epoch = 90 | Loss = 34.338 | Loss2 = 0.577 | Accuracy = 75.625
# Val: Epoch = 90 | Loss 1.599 | Accuracy = 51.724
# Train: Epoch = 91 | Loss = 34.376 | Loss2 = 0.537 | Accuracy = 73.438
# Val: Epoch = 91 | Loss 1.558 | Accuracy = 53.448
# Train: Epoch = 92 | Loss = 34.352 | Loss2 = 0.547 | Accuracy = 75.625
# Val: Epoch = 92 | Loss 1.532 | Accuracy = 53.448
# Train: Epoch = 93 | Loss = 34.400 | Loss2 = 0.584 | Accuracy = 71.562
# Val: Epoch = 93 | Loss 1.547 | Accuracy = 53.448
# Train: Epoch = 94 | Loss = 34.411 | Loss2 = 0.571 | Accuracy = 73.750
# Val: Epoch = 94 | Loss 1.572 | Accuracy = 52.586
# Train: Epoch = 95 | Loss = 34.387 | Loss2 = 0.539 | Accuracy = 78.125
# Val: Epoch = 95 | Loss 1.593 | Accuracy = 53.448
# Train: Epoch = 96 | Loss = 34.329 | Loss2 = 0.555 | Accuracy = 75.938
# Val: Epoch = 96 | Loss 1.587 | Accuracy = 54.310
# Train: Epoch = 97 | Loss = 34.392 | Loss2 = 0.546 | Accuracy = 72.500
# Val: Epoch = 97 | Loss 1.579 | Accuracy = 54.310
# Train: Epoch = 98 | Loss = 34.368 | Loss2 = 0.538 | Accuracy = 72.188
# Val: Epoch = 98 | Loss 1.568 | Accuracy = 52.586
# Train: Epoch = 99 | Loss = 34.276 | Loss2 = 0.580 | Accuracy = 77.812
# Val: Epoch = 99 | Loss 1.591 | Accuracy = 52.586
# Train: Epoch = 100 | Loss = 34.396 | Loss2 = 0.558 | Accuracy = 73.438
# Val: Epoch = 100 | Loss 1.605 | Accuracy = 50.862
# Train: Epoch = 101 | Loss = 34.407 | Loss2 = 0.562 | Accuracy = 72.812
# Val: Epoch = 101 | Loss 1.611 | Accuracy = 50.862
# Train: Epoch = 102 | Loss = 34.458 | Loss2 = 0.553 | Accuracy = 71.875
# Val: Epoch = 102 | Loss 1.590 | Accuracy = 54.310
# Train: Epoch = 103 | Loss = 34.317 | Loss2 = 0.568 | Accuracy = 73.438
# Val: Epoch = 103 | Loss 1.582 | Accuracy = 53.448
# Train: Epoch = 104 | Loss = 34.274 | Loss2 = 0.565 | Accuracy = 79.688
# Val: Epoch = 104 | Loss 1.583 | Accuracy = 52.586
# Train: Epoch = 105 | Loss = 34.346 | Loss2 = 0.554 | Accuracy = 75.938
# Val: Epoch = 105 | Loss 1.578 | Accuracy = 51.724
# Train: Epoch = 106 | Loss = 34.322 | Loss2 = 0.576 | Accuracy = 74.688
# Val: Epoch = 106 | Loss 1.563 | Accuracy = 52.586
# Train: Epoch = 107 | Loss = 34.446 | Loss2 = 0.535 | Accuracy = 72.500
# Val: Epoch = 107 | Loss 1.545 | Accuracy = 52.586
# Train: Epoch = 108 | Loss = 34.355 | Loss2 = 0.574 | Accuracy = 75.938
# Val: Epoch = 108 | Loss 1.572 | Accuracy = 53.448
# Train: Epoch = 109 | Loss = 34.376 | Loss2 = 0.586 | Accuracy = 75.938
# Val: Epoch = 109 | Loss 1.572 | Accuracy = 52.586
# Train: Epoch = 110 | Loss = 34.316 | Loss2 = 0.582 | Accuracy = 73.750
# Val: Epoch = 110 | Loss 1.579 | Accuracy = 52.586
# Train: Epoch = 111 | Loss = 34.300 | Loss2 = 0.537 | Accuracy = 77.188
# Val: Epoch = 111 | Loss 1.569 | Accuracy = 51.724
# Train: Epoch = 112 | Loss = 34.298 | Loss2 = 0.565 | Accuracy = 75.625
# Val: Epoch = 112 | Loss 1.588 | Accuracy = 51.724
# Train: Epoch = 113 | Loss = 34.335 | Loss2 = 0.539 | Accuracy = 74.062
# Val: Epoch = 113 | Loss 1.554 | Accuracy = 52.586
# Train: Epoch = 114 | Loss = 34.280 | Loss2 = 0.552 | Accuracy = 77.500
# Val: Epoch = 114 | Loss 1.561 | Accuracy = 52.586
# Train: Epoch = 115 | Loss = 34.366 | Loss2 = 0.534 | Accuracy = 75.625
# Val: Epoch = 115 | Loss 1.581 | Accuracy = 52.586
# Train: Epoch = 116 | Loss = 34.222 | Loss2 = 0.540 | Accuracy = 77.812
# Val: Epoch = 116 | Loss 1.609 | Accuracy = 51.724
# Train: Epoch = 117 | Loss = 34.318 | Loss2 = 0.575 | Accuracy = 77.812
# Val: Epoch = 117 | Loss 1.589 | Accuracy = 52.586
# Train: Epoch = 118 | Loss = 34.305 | Loss2 = 0.548 | Accuracy = 76.562
# Val: Epoch = 118 | Loss 1.588 | Accuracy = 51.724
# Train: Epoch = 119 | Loss = 34.176 | Loss2 = 0.548 | Accuracy = 80.312
# Val: Epoch = 119 | Loss 1.576 | Accuracy = 53.448
# Train: Epoch = 120 | Loss = 34.328 | Loss2 = 0.557 | Accuracy = 77.500
# Val: Epoch = 120 | Loss 1.573 | Accuracy = 52.586
# Train: Epoch = 121 | Loss = 34.318 | Loss2 = 0.556 | Accuracy = 76.875
# Val: Epoch = 121 | Loss 1.599 | Accuracy = 51.724
# Train: Epoch = 122 | Loss = 34.344 | Loss2 = 0.561 | Accuracy = 73.125
# Val: Epoch = 122 | Loss 1.564 | Accuracy = 52.586
# Train: Epoch = 123 | Loss = 34.272 | Loss2 = 0.537 | Accuracy = 78.125
# Val: Epoch = 123 | Loss 1.610 | Accuracy = 52.586
# Train: Epoch = 124 | Loss = 34.348 | Loss2 = 0.582 | Accuracy = 75.312
# Val: Epoch = 124 | Loss 1.623 | Accuracy = 52.586
# Train: Epoch = 125 | Loss = 34.275 | Loss2 = 0.552 | Accuracy = 76.875
# Val: Epoch = 125 | Loss 1.614 | Accuracy = 53.448
# Train: Epoch = 126 | Loss = 34.226 | Loss2 = 0.562 | Accuracy = 77.188
# Val: Epoch = 126 | Loss 1.634 | Accuracy = 53.448
# Train: Epoch = 127 | Loss = 34.328 | Loss2 = 0.577 | Accuracy = 72.188
# Val: Epoch = 127 | Loss 1.653 | Accuracy = 52.586
# Train: Epoch = 128 | Loss = 34.331 | Loss2 = 0.510 | Accuracy = 78.125
# Val: Epoch = 128 | Loss 1.633 | Accuracy = 53.448
# Train: Epoch = 129 | Loss = 34.334 | Loss2 = 0.553 | Accuracy = 75.000
# Val: Epoch = 129 | Loss 1.603 | Accuracy = 53.448
# Train: Epoch = 130 | Loss = 34.253 | Loss2 = 0.590 | Accuracy = 78.438
# Val: Epoch = 130 | Loss 1.595 | Accuracy = 52.586
# Train: Epoch = 131 | Loss = 34.397 | Loss2 = 0.557 | Accuracy = 71.875
# Val: Epoch = 131 | Loss 1.633 | Accuracy = 52.586
# Train: Epoch = 132 | Loss = 34.224 | Loss2 = 0.578 | Accuracy = 79.062
# Val: Epoch = 132 | Loss 1.621 | Accuracy = 53.448
# Train: Epoch = 133 | Loss = 34.330 | Loss2 = 0.578 | Accuracy = 77.500
# Val: Epoch = 133 | Loss 1.597 | Accuracy = 53.448
# Train: Epoch = 134 | Loss = 34.261 | Loss2 = 0.595 | Accuracy = 76.562
# Val: Epoch = 134 | Loss 1.591 | Accuracy = 53.448
# Train: Epoch = 135 | Loss = 34.354 | Loss2 = 0.571 | Accuracy = 77.188
# Val: Epoch = 135 | Loss 1.570 | Accuracy = 55.172
# Train: Epoch = 136 | Loss = 34.318 | Loss2 = 0.549 | Accuracy = 76.875
# Val: Epoch = 136 | Loss 1.568 | Accuracy = 55.172
# Train: Epoch = 137 | Loss = 34.382 | Loss2 = 0.560 | Accuracy = 74.375
# Val: Epoch = 137 | Loss 1.550 | Accuracy = 56.034
# Train: Epoch = 138 | Loss = 34.329 | Loss2 = 0.580 | Accuracy = 77.188
# Val: Epoch = 138 | Loss 1.567 | Accuracy = 55.172
# Train: Epoch = 139 | Loss = 34.248 | Loss2 = 0.555 | Accuracy = 80.938
# Val: Epoch = 139 | Loss 1.566 | Accuracy = 55.172
# Train: Epoch = 140 | Loss = 34.297 | Loss2 = 0.557 | Accuracy = 78.125
# Val: Epoch = 140 | Loss 1.581 | Accuracy = 52.586
# Train: Epoch = 141 | Loss = 34.264 | Loss2 = 0.556 | Accuracy = 78.125
# Val: Epoch = 141 | Loss 1.557 | Accuracy = 54.310
# Train: Epoch = 142 | Loss = 34.264 | Loss2 = 0.558 | Accuracy = 77.188
# Val: Epoch = 142 | Loss 1.570 | Accuracy = 52.586
# Train: Epoch = 143 | Loss = 34.292 | Loss2 = 0.551 | Accuracy = 78.438
# Val: Epoch = 143 | Loss 1.594 | Accuracy = 53.448
# Train: Epoch = 144 | Loss = 34.169 | Loss2 = 0.503 | Accuracy = 80.625
# Val: Epoch = 144 | Loss 1.566 | Accuracy = 53.448
# Train: Epoch = 145 | Loss = 34.218 | Loss2 = 0.575 | Accuracy = 76.562
# Val: Epoch = 145 | Loss 1.549 | Accuracy = 53.448
# Train: Epoch = 146 | Loss = 34.255 | Loss2 = 0.551 | Accuracy = 77.500
# Val: Epoch = 146 | Loss 1.555 | Accuracy = 53.448
# Train: Epoch = 147 | Loss = 34.293 | Loss2 = 0.578 | Accuracy = 76.250
# Val: Epoch = 147 | Loss 1.542 | Accuracy = 53.448
# Train: Epoch = 148 | Loss = 34.306 | Loss2 = 0.566 | Accuracy = 77.812
# Val: Epoch = 148 | Loss 1.518 | Accuracy = 52.586
# Train: Epoch = 149 | Loss = 34.269 | Loss2 = 0.509 | Accuracy = 75.312
# Val: Epoch = 149 | Loss 1.555 | Accuracy = 51.724
# Train: Epoch = 150 | Loss = 34.299 | Loss2 = 0.533 | Accuracy = 74.375
# Val: Epoch = 150 | Loss 1.552 | Accuracy = 53.448

# %% [markdown]
# # Stage 2 specific setup

# %%
STAGE = 2

LR = 0.0001            # The initial Learning Rate
MOMENTUM = 0.9       # Hyperparameter for SGD, keep this at 0.9 when using SGD
WEIGHT_DECAY = 4e-5  # Regularization, you can keep this at the default

NUM_EPOCHS = 150      # Total number of training epochs (iterations over dataset)
STEP_SIZE = [30, 80] # How many epochs before decreasing learning rate (if using a step-down policy)
GAMMA = 0.2          # Multiplicative factor for learning rate step-down
MEM_SIZE = 512
SEQ_LEN = 7
ALPHA = 0.5

parameters = {
    'DEVICE': DEVICE,
    'NUM_CLASSES': NUM_CLASSES,
    'BATCH_SIZE': BATCH_SIZE,
    'LR': LR,
    'MOMENTUM': MOMENTUM,
    'WEIGHT_DECAY': WEIGHT_DECAY,
    'NUM_EPOCHS': NUM_EPOCHS,
    'STEP_SIZE': STEP_SIZE,
    'GAMMA': GAMMA,
    'MEM_SIZE': MEM_SIZE,
    'SEQ_LEN': SEQ_LEN
}

# %%
# Prepare Pytorch train/test Datasets
train_dataset = GTEA61(DATA_DIR, split='train', transform=spatial_transform,
                       seq_len=SEQ_LEN, mmaps = True, mmaps_transform = spatial_transform_mmaps, static_frames = True)
test_dataset = GTEA61(DATA_DIR, split='test', transform=spatial_transform_val,
                      seq_len=SEQ_LEN)

# Check dataset sizes
print('Train Dataset: {}'.format(len(train_dataset)))
print('Test Dataset: {}'.format(len(test_dataset)))
# Out:
# Train Dataset: 341
# Test Dataset: 116

# %%
# Dataloaders iterate over pytorch datasets and transparently provide useful functions (e.g. parallelization and shuffling)
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=4, drop_last=True)
val_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=4)

# %% [markdown]
# # Prepare Stage 2

# %%
best_old_stage = generate_model_checkpoint_name(stage=1, n_frames=SEQ_LEN, ms_block = True, \
                                                optional = '_2neur_DS__run01')
stage1_dict = os.path.join(model_folder, best_old_stage)
validate = True

model = attention_model_ms(num_classes=NUM_CLASSES, mem_size=MEM_SIZE)
model.load_state_dict(torch.load(stage1_dict))

model.train(False)

for params in model.parameters():
    params.requires_grad = False

layers_on_off = [
    model.resNet.layer4[0].conv1,
    model.resNet.layer4[0].conv2,
    model.resNet.layer4[1].conv1,
    model.resNet.layer4[1].conv2,
    model.resNet.layer4[2].conv1,
    model.resNet.layer4[2].conv2,
    model.resNet.fc,
    model.msBlock
]

layers_to_train = layers_on_off + [
    model.lstm_cell,
    model.classifier,
    model.classifier_SD
]

for layer in layers_to_train:
    for params in layer.parameters():
        params.requires_grad = True

for layer in layers_to_train:
    layer.train(True)

model.to(DEVICE)

loss_fn = nn.CrossEntropyLoss()
loss_fn_sum = nn.CrossEntropyLoss(reduction = 'sum')

trainable_params = [p for p in model.parameters() if p.requires_grad]
optimizer_fn = torch.optim.Adam(trainable_params, lr=LR, weight_decay=WEIGHT_DECAY, eps=1e-4)

optim_scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer_fn, milestones=STEP_SIZE, gamma=GAMMA)

# %% [markdown]
# # Stage 2

# %%
RUN = "_run02"

train_iter = 0
val_iter = 0
min_accuracy = 0

trainSamples = len(train_dataset) - (len(train_dataset) % BATCH_SIZE)
val_samples = len(test_dataset)

iterPerEpoch = len(train_loader)
val_steps = len(val_loader)

cudnn.benchmark
torch.autograd.set_detect_anomaly(True)
train_log, val_log = generate_log_filenames(STAGE, SEQ_LEN, ms_block = True, \
                                            optional = '_2neur_DS_alpha_' + RUN)
model_checkpoint = generate_model_checkpoint_name(STAGE, SEQ_LEN, ms_block = True, \
                                                  optional = '_2neur_DS_alpha_' + RUN)

train_log_file = os.path.join(model_folder, train_log)
val_log_file = os.path.join(model_folder, val_log)
train_logger_2 = Logger(**parameters)
val_logger_2 = Logger(**parameters)

for epoch in range(NUM_EPOCHS):

    epoch_loss = 0
    epoch_loss2 = 0
    numCorrTrain = 0
    
    for layer in layers_to_train:
        layer.train(True)
    
    for i, (inputs, inputs_DS, mmaps, targets) in enumerate(train_loader):

        mmaps = mmaps.permute(1, 0, 2)

        train_iter += 1

        optimizer_fn.zero_grad()

        inputVariable = inputs.permute(1, 0, 2, 3, 4).to(DEVICE)
        inputVariable_DS = inputs_DS.permute(1, 0, 2, 3, 4).to(DEVICE)
        labelVariable = targets.to(DEVICE)

        output_label, _, output_label_mmaps = model(inputVariable, mmaps = True)

        output_label_mmaps = output_label_mmaps.view(SEQ_LEN*BATCH_SIZE*MMAP_LENGTH, 2).to(DEVICE)
        mmaps = torch.flatten(mmaps).long().to(DEVICE)

        loss = loss_fn_sum(output_label_mmaps, mmaps)/(BATCH_SIZE * SEQ_LEN) + loss_fn(output_label, labelVariable)
        loss.backward()

        for layer in layers_on_off:
            for params in layer.parameters():
                params.requires_grad = False

        output_label_ds1, _ = model(inputVariable, static_frames = True)
        output_label_ds2, _ = model(inputVariable_DS, static_frames = True)
        
        gt_ds1 = torch.zeros(BATCH_SIZE).long().to(DEVICE)
        gt_ds2 = torch.ones(BATCH_SIZE).long().to(DEVICE)

        loss2 = ALPHA * (loss_fn(output_label_ds1, gt_ds1) + loss_fn(output_label_ds2, gt_ds2))

        loss2.backward()

        for layer in layers_on_off:
            for params in layer.parameters():
                params.requires_grad = True

        optimizer_fn.step()
        
        _, predicted = torch.max(output_label.data, 1)
        numCorrTrain += torch.sum(predicted == labelVariable.data).data.item()
        step_loss = loss.data.item()
        step_loss2 = loss2.data.item()
        epoch_loss += step_loss
        epoch_loss2 += step_loss2
        train_logger_2.add_step_data(train_iter, numCorrTrain, step_loss)

        
    avg_loss = epoch_loss/iterPerEpoch
    avg_loss2 = epoch_loss2/iterPerEpoch
    trainAccuracy = (numCorrTrain / trainSamples) * 100
    train_logger_2.add_epoch_data(epoch+1, trainAccuracy, avg_loss)
    
    print('Train: Epoch = {} | Loss = {:.3f} | Loss2 = {:.3f} | Accuracy = {:.3f}'.format(epoch+1, avg_loss, avg_loss2, trainAccuracy))

    if validate is not None:

        if (epoch+1) % 1 == 0:

            model.train(False)
            val_loss_epoch = 0
            numCorr = 0

            for j, (inputs, targets) in enumerate(val_loader):

                val_iter += 1

                inputVariable = inputs.permute(1, 0, 2, 3, 4).to(DEVICE)
                labelVariable = targets.to(DEVICE)
                
                output_label, _ = model(inputVariable)

                val_loss = loss_fn(output_label, labelVariable)
                val_loss_step = val_loss.data.item()
                val_loss_epoch += val_loss_step

                _, predicted = torch.max(output_label.data, 1)

                numCorr += torch.sum(predicted == labelVariable.data).data.item()
                val_logger_2.add_step_data(val_iter, numCorr, val_loss_step)

            val_accuracy = (numCorr / val_samples) * 100
            avg_val_loss = val_loss_epoch / val_steps

            print('Val: Epoch = {} | Loss {:.3f} | Accuracy = {:.3f}'.format(epoch + 1, avg_val_loss, val_accuracy))
            
            val_logger_2.add_epoch_data(epoch+1, val_accuracy, avg_val_loss)
            
            if val_accuracy > min_accuracy:
                print("[||| NEW BEST on val |||]")
                save_path_model = os.path.join(model_folder, model_checkpoint)
                torch.save(model.state_dict(), save_path_model)
                min_accuracy = val_accuracy
            
    optim_scheduler.step()

    train_logger_2.save(train_log_file)
    val_logger_2.save(val_log_file)
# Out:
# Train: Epoch = 1 | Loss = 35.907 | Loss2 = 0.856 | Accuracy = 35.938
# Val: Epoch = 1 | Loss 2.798 | Accuracy = 31.897
# [||| NEW BEST on val |||]
# Train: Epoch = 2 | Loss = 35.651 | Loss2 = 0.790 | Accuracy = 42.500
# Val: Epoch = 2 | Loss 2.363 | Accuracy = 33.621
# [||| NEW BEST on val |||]
# Train: Epoch = 3 | Loss = 35.557 | Loss2 = 0.763 | Accuracy = 42.500
# Val: Epoch = 3 | Loss 2.259 | Accuracy = 39.655
# [||| NEW BEST on val |||]
# Train: Epoch = 4 | Loss = 35.441 | Loss2 = 0.752 | Accuracy = 45.312
# Val: Epoch = 4 | Loss 2.543 | Accuracy = 36.207
# Train: Epoch = 5 | Loss = 35.535 | Loss2 = 0.747 | Accuracy = 40.312
# Val: Epoch = 5 | Loss 2.564 | Accuracy = 37.931
# Train: Epoch = 6 | Loss = 35.384 | Loss2 = 0.710 | Accuracy = 45.312
# Val: Epoch = 6 | Loss 2.243 | Accuracy = 37.931
# Train: Epoch = 7 | Loss = 35.302 | Loss2 = 0.731 | Accuracy = 44.062
# Val: Epoch = 7 | Loss 2.385 | Accuracy = 37.069
# Train: Epoch = 8 | Loss = 35.405 | Loss2 = 0.731 | Accuracy = 43.125
# Val: Epoch = 8 | Loss 2.322 | Accuracy = 40.517
# [||| NEW BEST on val |||]
# Train: Epoch = 9 | Loss = 35.176 | Loss2 = 0.702 | Accuracy = 52.812
# Val: Epoch = 9 | Loss 2.237 | Accuracy = 40.517
# Train: Epoch = 10 | Loss = 35.304 | Loss2 = 0.717 | Accuracy = 49.688
# Val: Epoch = 10 | Loss 2.202 | Accuracy = 38.793
# Train: Epoch = 11 | Loss = 35.243 | Loss2 = 0.694 | Accuracy = 53.125
# Val: Epoch = 11 | Loss 1.902 | Accuracy = 42.241
# [||| NEW BEST on val |||]
# Train: Epoch = 12 | Loss = 35.215 | Loss2 = 0.666 | Accuracy = 50.313
# Val: Epoch = 12 | Loss 1.938 | Accuracy = 47.414
# [||| NEW BEST on val |||]
# Train: Epoch = 13 | Loss = 35.188 | Loss2 = 0.688 | Accuracy = 51.875
# Val: Epoch = 13 | Loss 2.116 | Accuracy = 43.103
# Train: Epoch = 14 | Loss = 35.219 | Loss2 = 0.692 | Accuracy = 51.562
# Val: Epoch = 14 | Loss 1.949 | Accuracy = 51.724
# [||| NEW BEST on val |||]
# Train: Epoch = 15 | Loss = 35.155 | Loss2 = 0.710 | Accuracy = 51.250
# Val: Epoch = 15 | Loss 1.869 | Accuracy = 48.276
# Train: Epoch = 16 | Loss = 35.104 | Loss2 = 0.648 | Accuracy = 54.375
# Val: Epoch = 16 | Loss 1.910 | Accuracy = 44.828
# Train: Epoch = 17 | Loss = 35.010 | Loss2 = 0.676 | Accuracy = 56.250
# Val: Epoch = 17 | Loss 1.782 | Accuracy = 51.724
# Train: Epoch = 18 | Loss = 34.953 | Loss2 = 0.658 | Accuracy = 57.812
# Val: Epoch = 18 | Loss 2.066 | Accuracy = 41.379
# Train: Epoch = 19 | Loss = 35.134 | Loss2 = 0.660 | Accuracy = 53.438
# Val: Epoch = 19 | Loss 1.843 | Accuracy = 45.690
# Train: Epoch = 20 | Loss = 35.030 | Loss2 = 0.632 | Accuracy = 55.937
# Val: Epoch = 20 | Loss 2.014 | Accuracy = 44.828
# Train: Epoch = 21 | Loss = 35.027 | Loss2 = 0.647 | Accuracy = 56.250
# Val: Epoch = 21 | Loss 1.887 | Accuracy = 46.552
# Train: Epoch = 22 | Loss = 34.947 | Loss2 = 0.639 | Accuracy = 56.563
# Val: Epoch = 22 | Loss 1.852 | Accuracy = 43.966
# Train: Epoch = 23 | Loss = 35.045 | Loss2 = 0.622 | Accuracy = 57.188
# Val: Epoch = 23 | Loss 2.026 | Accuracy = 43.103
# Train: Epoch = 24 | Loss = 34.947 | Loss2 = 0.640 | Accuracy = 57.188
# Val: Epoch = 24 | Loss 1.937 | Accuracy = 44.828
# Train: Epoch = 25 | Loss = 35.025 | Loss2 = 0.592 | Accuracy = 55.000
# Val: Epoch = 25 | Loss 1.817 | Accuracy = 47.414
# Train: Epoch = 26 | Loss = 34.953 | Loss2 = 0.609 | Accuracy = 56.875
# Val: Epoch = 26 | Loss 1.827 | Accuracy = 45.690
# Train: Epoch = 27 | Loss = 34.927 | Loss2 = 0.614 | Accuracy = 55.312
# Val: Epoch = 27 | Loss 1.647 | Accuracy = 46.552
# Train: Epoch = 28 | Loss = 34.969 | Loss2 = 0.605 | Accuracy = 58.750
# Val: Epoch = 28 | Loss 1.804 | Accuracy = 44.828
# Train: Epoch = 29 | Loss = 34.874 | Loss2 = 0.617 | Accuracy = 56.250
# Val: Epoch = 29 | Loss 1.883 | Accuracy = 46.552
# Train: Epoch = 30 | Loss = 34.882 | Loss2 = 0.616 | Accuracy = 58.750
# Val: Epoch = 30 | Loss 1.979 | Accuracy = 43.966
# Train: Epoch = 31 | Loss = 34.865 | Loss2 = 0.612 | Accuracy = 58.750
# Val: Epoch = 31 | Loss 1.788 | Accuracy = 45.690
# Train: Epoch = 32 | Loss = 34.633 | Loss2 = 0.617 | Accuracy = 67.188
# Val: Epoch = 32 | Loss 1.672 | Accuracy = 46.552
# Train: Epoch = 33 | Loss = 34.789 | Loss2 = 0.618 | Accuracy = 61.875
# Val: Epoch = 33 | Loss 1.669 | Accuracy = 46.552
# Train: Epoch = 34 | Loss = 34.632 | Loss2 = 0.619 | Accuracy = 65.938
# Val: Epoch = 34 | Loss 1.681 | Accuracy = 43.103
# Train: Epoch = 35 | Loss = 34.655 | Loss2 = 0.587 | Accuracy = 63.438
# Val: Epoch = 35 | Loss 1.618 | Accuracy = 47.414
# Train: Epoch = 36 | Loss = 34.567 | Loss2 = 0.577 | Accuracy = 68.438
# Val: Epoch = 36 | Loss 1.643 | Accuracy = 47.414
# Train: Epoch = 37 | Loss = 34.693 | Loss2 = 0.617 | Accuracy = 66.875
# Val: Epoch = 37 | Loss 1.625 | Accuracy = 47.414
# Train: Epoch = 38 | Loss = 34.669 | Loss2 = 0.608 | Accuracy = 62.187
# Val: Epoch = 38 | Loss 1.670 | Accuracy = 50.000
# Train: Epoch = 39 | Loss = 34.613 | Loss2 = 0.560 | Accuracy = 68.125
# Val: Epoch = 39 | Loss 1.698 | Accuracy = 49.138
# Train: Epoch = 40 | Loss = 34.646 | Loss2 = 0.628 | Accuracy = 64.062
# Val: Epoch = 40 | Loss 1.673 | Accuracy = 44.828
# Train: Epoch = 41 | Loss = 34.693 | Loss2 = 0.591 | Accuracy = 65.000
# Val: Epoch = 41 | Loss 1.680 | Accuracy = 50.000
# Train: Epoch = 42 | Loss = 34.605 | Loss2 = 0.603 | Accuracy = 69.688
# Val: Epoch = 42 | Loss 1.685 | Accuracy = 51.724
# Train: Epoch = 43 | Loss = 34.641 | Loss2 = 0.595 | Accuracy = 68.125
# Val: Epoch = 43 | Loss 1.713 | Accuracy = 49.138
# Train: Epoch = 44 | Loss = 34.721 | Loss2 = 0.604 | Accuracy = 61.250
# Val: Epoch = 44 | Loss 1.760 | Accuracy = 46.552
# Train: Epoch = 45 | Loss = 34.661 | Loss2 = 0.592 | Accuracy = 64.062
# Val: Epoch = 45 | Loss 1.764 | Accuracy = 52.586
# [||| NEW BEST on val |||]
# Train: Epoch = 46 | Loss = 34.543 | Loss2 = 0.596 | Accuracy = 72.812
# Val: Epoch = 46 | Loss 1.702 | Accuracy = 51.724
# Train: Epoch = 47 | Loss = 34.563 | Loss2 = 0.605 | Accuracy = 68.438
# Val: Epoch = 47 | Loss 1.660 | Accuracy = 50.000
# Train: Epoch = 48 | Loss = 34.692 | Loss2 = 0.588 | Accuracy = 64.688
# Val: Epoch = 48 | Loss 1.618 | Accuracy = 52.586
# Train: Epoch = 49 | Loss = 34.537 | Loss2 = 0.608 | Accuracy = 69.062
# Val: Epoch = 49 | Loss 1.645 | Accuracy = 52.586
# Train: Epoch = 50 | Loss = 34.536 | Loss2 = 0.590 | Accuracy = 68.438
# Val: Epoch = 50 | Loss 1.671 | Accuracy = 53.448
# [||| NEW BEST on val |||]
# Train: Epoch = 51 | Loss = 34.525 | Loss2 = 0.598 | Accuracy = 69.688
# Val: Epoch = 51 | Loss 1.704 | Accuracy = 50.862
# Train: Epoch = 52 | Loss = 34.523 | Loss2 = 0.610 | Accuracy = 68.438
# Val: Epoch = 52 | Loss 1.688 | Accuracy = 52.586
# Train: Epoch = 53 | Loss = 34.589 | Loss2 = 0.572 | Accuracy = 65.625
# Val: Epoch = 53 | Loss 1.647 | Accuracy = 50.862
# Train: Epoch = 54 | Loss = 34.600 | Loss2 = 0.582 | Accuracy = 69.062
# Val: Epoch = 54 | Loss 1.705 | Accuracy = 50.862
# Train: Epoch = 55 | Loss = 34.501 | Loss2 = 0.577 | Accuracy = 71.875
# Val: Epoch = 55 | Loss 1.654 | Accuracy = 46.552
# Train: Epoch = 56 | Loss = 34.552 | Loss2 = 0.582 | Accuracy = 66.875
# Val: Epoch = 56 | Loss 1.706 | Accuracy = 50.862
# Train: Epoch = 57 | Loss = 34.590 | Loss2 = 0.614 | Accuracy = 69.062
# Val: Epoch = 57 | Loss 1.739 | Accuracy = 49.138
# Train: Epoch = 58 | Loss = 34.470 | Loss2 = 0.575 | Accuracy = 73.438
# Val: Epoch = 58 | Loss 1.728 | Accuracy = 46.552
# Train: Epoch = 59 | Loss = 34.517 | Loss2 = 0.590 | Accuracy = 68.438
# Val: Epoch = 59 | Loss 1.725 | Accuracy = 50.000
# Train: Epoch = 60 | Loss = 34.707 | Loss2 = 0.556 | Accuracy = 63.125
# Val: Epoch = 60 | Loss 1.829 | Accuracy = 45.690
# Train: Epoch = 61 | Loss = 34.489 | Loss2 = 0.587 | Accuracy = 69.375
# Val: Epoch = 61 | Loss 1.697 | Accuracy = 49.138
# Train: Epoch = 62 | Loss = 34.486 | Loss2 = 0.601 | Accuracy = 68.125
# Val: Epoch = 62 | Loss 1.764 | Accuracy = 48.276
# Train: Epoch = 63 | Loss = 34.515 | Loss2 = 0.590 | Accuracy = 68.125
# Val: Epoch = 63 | Loss 1.697 | Accuracy = 50.000
# Train: Epoch = 64 | Loss = 34.363 | Loss2 = 0.586 | Accuracy = 75.938
# Val: Epoch = 64 | Loss 1.836 | Accuracy = 49.138
# Train: Epoch = 65 | Loss = 34.463 | Loss2 = 0.561 | Accuracy = 73.125
# Val: Epoch = 65 | Loss 1.738 | Accuracy = 47.414
# Train: Epoch = 66 | Loss = 34.507 | Loss2 = 0.590 | Accuracy = 70.312
# Val: Epoch = 66 | Loss 1.718 | Accuracy = 49.138
# Train: Epoch = 67 | Loss = 34.485 | Loss2 = 0.599 | Accuracy = 70.312
# Val: Epoch = 67 | Loss 1.751 | Accuracy = 50.862
# Train: Epoch = 68 | Loss = 34.601 | Loss2 = 0.559 | Accuracy = 69.375
# Val: Epoch = 68 | Loss 1.781 | Accuracy = 49.138
# Train: Epoch = 69 | Loss = 34.453 | Loss2 = 0.583 | Accuracy = 70.000
# Val: Epoch = 69 | Loss 1.754 | Accuracy = 50.000
# Train: Epoch = 70 | Loss = 34.532 | Loss2 = 0.567 | Accuracy = 70.625
# Val: Epoch = 70 | Loss 1.767 | Accuracy = 48.276
# Train: Epoch = 71 | Loss = 34.451 | Loss2 = 0.585 | Accuracy = 71.250
# Val: Epoch = 71 | Loss 1.734 | Accuracy = 48.276
# Train: Epoch = 72 | Loss = 34.462 | Loss2 = 0.597 | Accuracy = 71.250
# Val: Epoch = 72 | Loss 1.764 | Accuracy = 45.690
# Train: Epoch = 73 | Loss = 34.410 | Loss2 = 0.572 | Accuracy = 71.250
# Val: Epoch = 73 | Loss 1.793 | Accuracy = 49.138
# Train: Epoch = 74 | Loss = 34.429 | Loss2 = 0.550 | Accuracy = 75.000
# Val: Epoch = 74 | Loss 1.875 | Accuracy = 47.414
# Train: Epoch = 75 | Loss = 34.408 | Loss2 = 0.580 | Accuracy = 73.750
# Val: Epoch = 75 | Loss 1.834 | Accuracy = 45.690
# Train: Epoch = 76 | Loss = 34.429 | Loss2 = 0.568 | Accuracy = 72.812
# Val: Epoch = 76 | Loss 1.728 | Accuracy = 50.862
# Train: Epoch = 77 | Loss = 34.454 | Loss2 = 0.579 | Accuracy = 71.562
# Val: Epoch = 77 | Loss 1.776 | Accuracy = 47.414
# Train: Epoch = 78 | Loss = 34.365 | Loss2 = 0.560 | Accuracy = 75.938
# Val: Epoch = 78 | Loss 1.901 | Accuracy = 45.690
# Train: Epoch = 79 | Loss = 34.398 | Loss2 = 0.542 | Accuracy = 73.125
# Val: Epoch = 79 | Loss 1.757 | Accuracy = 46.552
# Train: Epoch = 80 | Loss = 34.525 | Loss2 = 0.547 | Accuracy = 68.125
# Val: Epoch = 80 | Loss 1.704 | Accuracy = 49.138
# Train: Epoch = 81 | Loss = 34.394 | Loss2 = 0.556 | Accuracy = 75.000
# Val: Epoch = 81 | Loss 1.708 | Accuracy = 47.414
# Train: Epoch = 82 | Loss = 34.470 | Loss2 = 0.573 | Accuracy = 72.188
# Val: Epoch = 82 | Loss 1.724 | Accuracy = 47.414
# Train: Epoch = 83 | Loss = 34.413 | Loss2 = 0.582 | Accuracy = 73.438
# Val: Epoch = 83 | Loss 1.727 | Accuracy = 48.276
# Train: Epoch = 84 | Loss = 34.341 | Loss2 = 0.561 | Accuracy = 74.688
# Val: Epoch = 84 | Loss 1.721 | Accuracy = 47.414
# Train: Epoch = 85 | Loss = 34.281 | Loss2 = 0.550 | Accuracy = 75.000
# Val: Epoch = 85 | Loss 1.724 | Accuracy = 47.414
# Train: Epoch = 86 | Loss = 34.370 | Loss2 = 0.591 | Accuracy = 73.750
# Val: Epoch = 86 | Loss 1.703 | Accuracy = 47.414
# Train: Epoch = 87 | Loss = 34.435 | Loss2 = 0.555 | Accuracy = 70.625
# Val: Epoch = 87 | Loss 1.720 | Accuracy = 47.414
# Train: Epoch = 88 | Loss = 34.310 | Loss2 = 0.563 | Accuracy = 77.188
# Val: Epoch = 88 | Loss 1.692 | Accuracy = 48.276
# Train: Epoch = 89 | Loss = 34.409 | Loss2 = 0.544 | Accuracy = 70.625
# Val: Epoch = 89 | Loss 1.697 | Accuracy = 49.138
# Train: Epoch = 90 | Loss = 34.346 | Loss2 = 0.529 | Accuracy = 75.625
# Val: Epoch = 90 | Loss 1.690 | Accuracy = 49.138
# Train: Epoch = 91 | Loss = 34.423 | Loss2 = 0.550 | Accuracy = 72.500
# Val: Epoch = 91 | Loss 1.685 | Accuracy = 49.138
# Train: Epoch = 92 | Loss = 34.391 | Loss2 = 0.525 | Accuracy = 71.875
# Val: Epoch = 92 | Loss 1.732 | Accuracy = 47.414
# Train: Epoch = 93 | Loss = 34.293 | Loss2 = 0.564 | Accuracy = 75.000
# Val: Epoch = 93 | Loss 1.737 | Accuracy = 47.414
# Train: Epoch = 94 | Loss = 34.401 | Loss2 = 0.576 | Accuracy = 72.500
# Val: Epoch = 94 | Loss 1.730 | Accuracy = 47.414
# Train: Epoch = 95 | Loss = 34.392 | Loss2 = 0.566 | Accuracy = 74.375
# Val: Epoch = 95 | Loss 1.701 | Accuracy = 48.276
# Train: Epoch = 96 | Loss = 34.336 | Loss2 = 0.540 | Accuracy = 73.750
# Val: Epoch = 96 | Loss 1.701 | Accuracy = 50.000
# Train: Epoch = 97 | Loss = 34.339 | Loss2 = 0.549 | Accuracy = 74.375
# Val: Epoch = 97 | Loss 1.632 | Accuracy = 50.862
# Train: Epoch = 98 | Loss = 34.466 | Loss2 = 0.546 | Accuracy = 71.250
# Val: Epoch = 98 | Loss 1.734 | Accuracy = 49.138
# Train: Epoch = 99 | Loss = 34.327 | Loss2 = 0.577 | Accuracy = 75.312
# Val: Epoch = 99 | Loss 1.776 | Accuracy = 48.276
# Train: Epoch = 100 | Loss = 34.467 | Loss2 = 0.549 | Accuracy = 71.875
# Val: Epoch = 100 | Loss 1.797 | Accuracy = 46.552
# Train: Epoch = 101 | Loss = 34.443 | Loss2 = 0.548 | Accuracy = 70.000
# Val: Epoch = 101 | Loss 1.684 | Accuracy = 50.000
# Train: Epoch = 102 | Loss = 34.373 | Loss2 = 0.551 | Accuracy = 78.438
# Val: Epoch = 102 | Loss 1.665 | Accuracy = 50.000
# Train: Epoch = 103 | Loss = 34.341 | Loss2 = 0.537 | Accuracy = 75.625
# Val: Epoch = 103 | Loss 1.655 | Accuracy = 50.000
# Train: Epoch = 104 | Loss = 34.372 | Loss2 = 0.595 | Accuracy = 74.062
# Val: Epoch = 104 | Loss 1.639 | Accuracy = 50.862
# Train: Epoch = 105 | Loss = 34.383 | Loss2 = 0.552 | Accuracy = 73.750
# Val: Epoch = 105 | Loss 1.649 | Accuracy = 50.862
# Train: Epoch = 106 | Loss = 34.343 | Loss2 = 0.515 | Accuracy = 73.750
# Val: Epoch = 106 | Loss 1.648 | Accuracy = 50.862
# Train: Epoch = 107 | Loss = 34.308 | Loss2 = 0.550 | Accuracy = 75.625
# Val: Epoch = 107 | Loss 1.694 | Accuracy = 49.138
# Train: Epoch = 108 | Loss = 34.381 | Loss2 = 0.558 | Accuracy = 73.438
# Val: Epoch = 108 | Loss 1.679 | Accuracy = 49.138
# Train: Epoch = 109 | Loss = 34.376 | Loss2 = 0.549 | Accuracy = 71.875
# Val: Epoch = 109 | Loss 1.661 | Accuracy = 50.862
# Train: Epoch = 110 | Loss = 34.329 | Loss2 = 0.571 | Accuracy = 74.688
# Val: Epoch = 110 | Loss 1.638 | Accuracy = 50.862
# Train: Epoch = 111 | Loss = 34.282 | Loss2 = 0.523 | Accuracy = 75.938
# Val: Epoch = 111 | Loss 1.643 | Accuracy = 50.862
# Train: Epoch = 112 | Loss = 34.462 | Loss2 = 0.549 | Accuracy = 71.562
# Val: Epoch = 112 | Loss 1.644 | Accuracy = 50.000
# Train: Epoch = 113 | Loss = 34.274 | Loss2 = 0.537 | Accuracy = 79.062
# Val: Epoch = 113 | Loss 1.652 | Accuracy = 49.138
# Train: Epoch = 114 | Loss = 34.298 | Loss2 = 0.560 | Accuracy = 76.875
# Val: Epoch = 114 | Loss 1.665 | Accuracy = 49.138
# Train: Epoch = 115 | Loss = 34.365 | Loss2 = 0.539 | Accuracy = 72.188
# Val: Epoch = 115 | Loss 1.693 | Accuracy = 48.276
# Train: Epoch = 116 | Loss = 34.335 | Loss2 = 0.573 | Accuracy = 75.312
# Val: Epoch = 116 | Loss 1.689 | Accuracy = 50.862
# Train: Epoch = 117 | Loss = 34.364 | Loss2 = 0.574 | Accuracy = 74.375
# Val: Epoch = 117 | Loss 1.657 | Accuracy = 50.862
# Train: Epoch = 118 | Loss = 34.261 | Loss2 = 0.543 | Accuracy = 76.875
# Val: Epoch = 118 | Loss 1.658 | Accuracy = 49.138
# Train: Epoch = 119 | Loss = 34.349 | Loss2 = 0.539 | Accuracy = 74.688
# Val: Epoch = 119 | Loss 1.654 | Accuracy = 50.000
# Train: Epoch = 120 | Loss = 34.379 | Loss2 = 0.557 | Accuracy = 75.312
# Val: Epoch = 120 | Loss 1.635 | Accuracy = 50.862
# Train: Epoch = 121 | Loss = 34.205 | Loss2 = 0.528 | Accuracy = 79.688
# Val: Epoch = 121 | Loss 1.661 | Accuracy = 49.138
# Train: Epoch = 122 | Loss = 34.288 | Loss2 = 0.538 | Accuracy = 78.125
# Val: Epoch = 122 | Loss 1.632 | Accuracy = 50.000
# Train: Epoch = 123 | Loss = 34.410 | Loss2 = 0.557 | Accuracy = 74.062
# Val: Epoch = 123 | Loss 1.611 | Accuracy = 51.724
# Train: Epoch = 124 | Loss = 34.351 | Loss2 = 0.543 | Accuracy = 73.750
# Val: Epoch = 124 | Loss 1.641 | Accuracy = 50.862
# Train: Epoch = 125 | Loss = 34.353 | Loss2 = 0.572 | Accuracy = 75.312
# Val: Epoch = 125 | Loss 1.655 | Accuracy = 50.000
# Train: Epoch = 126 | Loss = 34.311 | Loss2 = 0.546 | Accuracy = 77.188
# Val: Epoch = 126 | Loss 1.656 | Accuracy = 47.414
# Train: Epoch = 127 | Loss = 34.235 | Loss2 = 0.564 | Accuracy = 78.438
# Val: Epoch = 127 | Loss 1.658 | Accuracy = 49.138
# Train: Epoch = 128 | Loss = 34.297 | Loss2 = 0.567 | Accuracy = 77.188
# Val: Epoch = 128 | Loss 1.660 | Accuracy = 50.000
# Train: Epoch = 129 | Loss = 34.286 | Loss2 = 0.584 | Accuracy = 76.875
# Val: Epoch = 129 | Loss 1.656 | Accuracy = 50.000
# Train: Epoch = 130 | Loss = 34.361 | Loss2 = 0.563 | Accuracy = 76.250
# Val: Epoch = 130 | Loss 1.652 | Accuracy = 50.000
# Train: Epoch = 131 | Loss = 34.308 | Loss2 = 0.572 | Accuracy = 75.000
# Val: Epoch = 131 | Loss 1.648 | Accuracy = 49.138
# Train: Epoch = 132 | Loss = 34.281 | Loss2 = 0.551 | Accuracy = 75.312
# Val: Epoch = 132 | Loss 1.643 | Accuracy = 49.138
# Train: Epoch = 133 | Loss = 34.322 | Loss2 = 0.541 | Accuracy = 74.375
# Val: Epoch = 133 | Loss 1.643 | Accuracy = 50.000
# Train: Epoch = 134 | Loss = 34.221 | Loss2 = 0.538 | Accuracy = 76.250
# Val: Epoch = 134 | Loss 1.637 | Accuracy = 49.138
# Train: Epoch = 135 | Loss = 34.234 | Loss2 = 0.537 | Accuracy = 78.125
# Val: Epoch = 135 | Loss 1.605 | Accuracy = 52.586
# Train: Epoch = 136 | Loss = 34.323 | Loss2 = 0.538 | Accuracy = 73.750
# Val: Epoch = 136 | Loss 1.656 | Accuracy = 50.862
# Train: Epoch = 137 | Loss = 34.239 | Loss2 = 0.590 | Accuracy = 75.312
# Val: Epoch = 137 | Loss 1.678 | Accuracy = 48.276
# Train: Epoch = 138 | Loss = 34.299 | Loss2 = 0.554 | Accuracy = 76.562
# Val: Epoch = 138 | Loss 1.702 | Accuracy = 48.276
# Train: Epoch = 139 | Loss = 34.283 | Loss2 = 0.559 | Accuracy = 77.500
# Val: Epoch = 139 | Loss 1.698 | Accuracy = 49.138
# Train: Epoch = 140 | Loss = 34.208 | Loss2 = 0.542 | Accuracy = 78.438
# Val: Epoch = 140 | Loss 1.682 | Accuracy = 50.000
# Train: Epoch = 141 | Loss = 34.249 | Loss2 = 0.562 | Accuracy = 77.188
# Val: Epoch = 141 | Loss 1.668 | Accuracy = 50.000
# Train: Epoch = 142 | Loss = 34.286 | Loss2 = 0.553 | Accuracy = 75.938
# Val: Epoch = 142 | Loss 1.659 | Accuracy = 50.000
# Train: Epoch = 143 | Loss = 34.326 | Loss2 = 0.552 | Accuracy = 74.375
# Val: Epoch = 143 | Loss 1.670 | Accuracy = 50.000
# Train: Epoch = 144 | Loss = 34.301 | Loss2 = 0.568 | Accuracy = 77.188
# Val: Epoch = 144 | Loss 1.674 | Accuracy = 49.138
# Train: Epoch = 145 | Loss = 34.269 | Loss2 = 0.571 | Accuracy = 78.438
# Val: Epoch = 145 | Loss 1.644 | Accuracy = 50.000
# Train: Epoch = 146 | Loss = 34.344 | Loss2 = 0.538 | Accuracy = 73.438
# Val: Epoch = 146 | Loss 1.606 | Accuracy = 50.862
# Train: Epoch = 147 | Loss = 34.235 | Loss2 = 0.527 | Accuracy = 80.000
# Val: Epoch = 147 | Loss 1.622 | Accuracy = 49.138
# Train: Epoch = 148 | Loss = 34.288 | Loss2 = 0.540 | Accuracy = 76.562
# Val: Epoch = 148 | Loss 1.635 | Accuracy = 49.138
# Train: Epoch = 149 | Loss = 34.338 | Loss2 = 0.564 | Accuracy = 76.875
# Val: Epoch = 149 | Loss 1.642 | Accuracy = 50.000
# Train: Epoch = 150 | Loss = 34.262 | Loss2 = 0.575 | Accuracy = 78.438
# Val: Epoch = 150 | Loss 1.640 | Accuracy = 51.724

# %% [markdown]
# # Stage 2 specific setup

# %%
STAGE = 2

LR = 0.0001            # The initial Learning Rate
MOMENTUM = 0.9       # Hyperparameter for SGD, keep this at 0.9 when using SGD
WEIGHT_DECAY = 4e-5  # Regularization, you can keep this at the default

NUM_EPOCHS = 150      # Total number of training epochs (iterations over dataset)
STEP_SIZE = [30, 80] # How many epochs before decreasing learning rate (if using a step-down policy)
GAMMA = 0.2          # Multiplicative factor for learning rate step-down
MEM_SIZE = 512
SEQ_LEN = 7
ALPHA = 0.1

parameters = {
    'DEVICE': DEVICE,
    'NUM_CLASSES': NUM_CLASSES,
    'BATCH_SIZE': BATCH_SIZE,
    'LR': LR,
    'MOMENTUM': MOMENTUM,
    'WEIGHT_DECAY': WEIGHT_DECAY,
    'NUM_EPOCHS': NUM_EPOCHS,
    'STEP_SIZE': STEP_SIZE,
    'GAMMA': GAMMA,
    'MEM_SIZE': MEM_SIZE,
    'SEQ_LEN': SEQ_LEN,
    'ALPHA': ALPHA
}

# %%
# Prepare Pytorch train/test Datasets
train_dataset = GTEA61(DATA_DIR, split='train', transform=spatial_transform,
                       seq_len=SEQ_LEN, mmaps = True, mmaps_transform = spatial_transform_mmaps, static_frames = True)
test_dataset = GTEA61(DATA_DIR, split='test', transform=spatial_transform_val,
                      seq_len=SEQ_LEN)

# Check dataset sizes
print('Train Dataset: {}'.format(len(train_dataset)))
print('Test Dataset: {}'.format(len(test_dataset)))
# Out:
# Train Dataset: 341
# Test Dataset: 116

# %%
# Dataloaders iterate over pytorch datasets and transparently provide useful functions (e.g. parallelization and shuffling)
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=4, drop_last=True)
val_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=4)

# %% [markdown]
# # Prepare Stage 2

# %%
best_old_stage = generate_model_checkpoint_name(stage=1, n_frames=SEQ_LEN, ms_block = True, \
                                                optional = '_2neur_DS__run01')
stage1_dict = os.path.join(model_folder, best_old_stage)
validate = True

model = attention_model_ms(num_classes=NUM_CLASSES, mem_size=MEM_SIZE)
model.load_state_dict(torch.load(stage1_dict))

model.train(False)

for params in model.parameters():
    params.requires_grad = False

layers_on_off = [
    model.resNet.layer4[0].conv1,
    model.resNet.layer4[0].conv2,
    model.resNet.layer4[1].conv1,
    model.resNet.layer4[1].conv2,
    model.resNet.layer4[2].conv1,
    model.resNet.layer4[2].conv2,
    model.resNet.fc,
    model.msBlock
]

layers_to_train = layers_on_off + [
    model.lstm_cell,
    model.classifier,
    model.classifier_SD
]

for layer in layers_to_train:
    for params in layer.parameters():
        params.requires_grad = True

for layer in layers_to_train:
    layer.train(True)

model.to(DEVICE)

loss_fn = nn.CrossEntropyLoss()
loss_fn_sum = nn.CrossEntropyLoss(reduction = 'sum')

trainable_params = [p for p in model.parameters() if p.requires_grad]
optimizer_fn = torch.optim.Adam(trainable_params, lr=LR, weight_decay=WEIGHT_DECAY, eps=1e-4)

optim_scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer_fn, milestones=STEP_SIZE, gamma=GAMMA)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# HBox(children=(FloatProgress(value=0.0, max=87306240.0), HTML(value='')))

# %% [markdown]
# # Stage 2

# %%
# RUN = "_run05_a0.1"

train_iter = 0
val_iter = 0
min_accuracy = 0

trainSamples = len(train_dataset) - (len(train_dataset) % BATCH_SIZE)
val_samples = len(test_dataset)

iterPerEpoch = len(train_loader)
val_steps = len(val_loader)

cudnn.benchmark
torch.autograd.set_detect_anomaly(True)
train_log, val_log = generate_log_filenames(STAGE, SEQ_LEN, ms_block = True, \
                                            optional = '_dsloss')
model_checkpoint = generate_model_checkpoint_name(STAGE, SEQ_LEN, ms_block = True, \
                                                  optional = '_dsloss')

train_log_file = os.path.join(model_folder, train_log)
val_log_file = os.path.join(model_folder, val_log)
train_logger_2 = Logger(**parameters)
val_logger_2 = Logger(**parameters)

for epoch in range(NUM_EPOCHS):

    epoch_loss1 = 0
    epoch_loss2 = 0
    numCorrTrain = 0
    
    for layer in layers_to_train:
        layer.train(True)
    
    for i, (inputs, inputs_DS, mmaps, targets) in enumerate(train_loader):

        mmaps = mmaps.permute(1, 0, 2)

        train_iter += 1

        optimizer_fn.zero_grad()

        inputVariable = inputs.permute(1, 0, 2, 3, 4).to(DEVICE)
        inputVariable_DS = inputs_DS.permute(1, 0, 2, 3, 4).to(DEVICE)
        labelVariable = targets.to(DEVICE)

        output_label, _, output_label_mmaps = model(inputVariable, mmaps = True)

        output_label_mmaps = output_label_mmaps.view(SEQ_LEN*BATCH_SIZE*MMAP_LENGTH, 2).to(DEVICE)
        mmaps = torch.flatten(mmaps).long().to(DEVICE)

        loss1 = loss_fn(output_label, labelVariable)
        loss = loss_fn_sum(output_label_mmaps, mmaps)/(BATCH_SIZE * SEQ_LEN) + loss1
        loss.backward()

        for layer in layers_on_off:
            for params in layer.parameters():
                params.requires_grad = False

        output_label_ds1, _ = model(inputVariable, static_frames = True)
        output_label_ds2, _ = model(inputVariable_DS, static_frames = True)
        
        gt_ds1 = torch.zeros(BATCH_SIZE).long().to(DEVICE)
        gt_ds2 = torch.ones(BATCH_SIZE).long().to(DEVICE)

        loss2 = ALPHA * (loss_fn(output_label_ds1, gt_ds1) + loss_fn(output_label_ds2, gt_ds2))

        loss2.backward()

        for layer in layers_on_off:
            for params in layer.parameters():
                params.requires_grad = True

        optimizer_fn.step()
        
        _, predicted = torch.max(output_label.data, 1)
        numCorrTrain += torch.sum(predicted == labelVariable.data).data.item()
        step_loss1 = loss1.data.item()
        step_loss2 = loss2.data.item()
        epoch_loss1 += step_loss1
        epoch_loss2 += step_loss2
        # train_logger_2.add_step_data(train_iter, numCorrTrain, step_loss1, step_loss2)

        
    avg_loss1 = epoch_loss1/iterPerEpoch
    avg_loss2 = epoch_loss2/iterPerEpoch
    trainAccuracy = (numCorrTrain / trainSamples) * 100
    train_logger_2.add_epoch_data(epoch+1, trainAccuracy, avg_loss1, avg_loss2)
    
    print('Train: Epoch = {} | Loss = {:.3f} | Loss2 = {:.3f} | Accuracy = {:.3f}'.format(epoch+1, avg_loss1, avg_loss2, trainAccuracy))

    if validate is not None:

        if (epoch+1) % 1 == 0:

            model.train(False)
            val_loss_epoch = 0
            numCorr = 0

            for j, (inputs, targets) in enumerate(val_loader):

                val_iter += 1

                inputVariable = inputs.permute(1, 0, 2, 3, 4).to(DEVICE)
                labelVariable = targets.to(DEVICE)
                
                output_label, _ = model(inputVariable)

                val_loss = loss_fn(output_label, labelVariable)
                val_loss_step = val_loss.data.item()
                val_loss_epoch += val_loss_step

                _, predicted = torch.max(output_label.data, 1)

                numCorr += torch.sum(predicted == labelVariable.data).data.item()
                val_logger_2.add_step_data(val_iter, numCorr, val_loss_step)

            val_accuracy = (numCorr / val_samples) * 100
            avg_val_loss = val_loss_epoch / val_steps

            print('Val: Epoch = {} | Loss {:.3f} | Accuracy = {:.3f}'.format(epoch + 1, avg_val_loss, val_accuracy))
            
            val_logger_2.add_epoch_data(epoch+1, val_accuracy, avg_val_loss)
            
            if val_accuracy > min_accuracy:
                print("[||| NEW BEST on val |||]")
                save_path_model = os.path.join(model_folder, model_checkpoint)
                torch.save(model.state_dict(), save_path_model)
                min_accuracy = val_accuracy
            
    optim_scheduler.step()

    train_logger_2.save(train_log_file)
    val_logger_2.save(val_log_file)
# Out:
# Train: Epoch = 1 | Loss = 2.216 | Loss2 = 0.155 | Accuracy = 35.312
# Val: Epoch = 1 | Loss 2.283 | Accuracy = 35.345
# [||| NEW BEST on val |||]
# Train: Epoch = 2 | Loss = 2.054 | Loss2 = 0.159 | Accuracy = 42.500
# Val: Epoch = 2 | Loss 2.341 | Accuracy = 37.931
# [||| NEW BEST on val |||]
# Train: Epoch = 3 | Loss = 1.892 | Loss2 = 0.154 | Accuracy = 41.875
# Val: Epoch = 3 | Loss 2.404 | Accuracy = 35.345
# Train: Epoch = 4 | Loss = 1.948 | Loss2 = 0.151 | Accuracy = 43.125
# Val: Epoch = 4 | Loss 2.089 | Accuracy = 43.103
# [||| NEW BEST on val |||]
# Train: Epoch = 5 | Loss = 1.890 | Loss2 = 0.155 | Accuracy = 47.812
# Val: Epoch = 5 | Loss 2.052 | Accuracy = 41.379
# Train: Epoch = 6 | Loss = 1.788 | Loss2 = 0.153 | Accuracy = 47.500
# Val: Epoch = 6 | Loss 2.105 | Accuracy = 44.828
# [||| NEW BEST on val |||]
# Train: Epoch = 7 | Loss = 1.801 | Loss2 = 0.149 | Accuracy = 50.313
# Val: Epoch = 7 | Loss 2.241 | Accuracy = 41.379
# Train: Epoch = 8 | Loss = 1.838 | Loss2 = 0.154 | Accuracy = 44.375
# Val: Epoch = 8 | Loss 2.232 | Accuracy = 42.241
# Train: Epoch = 9 | Loss = 1.748 | Loss2 = 0.151 | Accuracy = 51.250
# Val: Epoch = 9 | Loss 1.913 | Accuracy = 43.966
# Train: Epoch = 10 | Loss = 1.771 | Loss2 = 0.151 | Accuracy = 47.500
# Val: Epoch = 10 | Loss 2.172 | Accuracy = 41.379
# Train: Epoch = 11 | Loss = 1.727 | Loss2 = 0.147 | Accuracy = 53.438
# Val: Epoch = 11 | Loss 2.010 | Accuracy = 43.966
# Train: Epoch = 12 | Loss = 1.795 | Loss2 = 0.146 | Accuracy = 46.562
# Val: Epoch = 12 | Loss 1.927 | Accuracy = 48.276
# [||| NEW BEST on val |||]
# Train: Epoch = 13 | Loss = 1.614 | Loss2 = 0.153 | Accuracy = 49.375
# Val: Epoch = 13 | Loss 2.109 | Accuracy = 38.793
# Train: Epoch = 14 | Loss = 1.654 | Loss2 = 0.141 | Accuracy = 48.438
# Val: Epoch = 14 | Loss 1.959 | Accuracy = 44.828
# Train: Epoch = 15 | Loss = 1.669 | Loss2 = 0.147 | Accuracy = 52.188
# Val: Epoch = 15 | Loss 1.856 | Accuracy = 43.966
# Train: Epoch = 16 | Loss = 1.570 | Loss2 = 0.151 | Accuracy = 56.250
# Val: Epoch = 16 | Loss 1.679 | Accuracy = 52.586
# [||| NEW BEST on val |||]
# Train: Epoch = 17 | Loss = 1.593 | Loss2 = 0.142 | Accuracy = 54.688
# Val: Epoch = 17 | Loss 1.852 | Accuracy = 48.276
# Train: Epoch = 18 | Loss = 1.564 | Loss2 = 0.143 | Accuracy = 54.375
# Val: Epoch = 18 | Loss 1.976 | Accuracy = 43.966
# Train: Epoch = 19 | Loss = 1.582 | Loss2 = 0.145 | Accuracy = 52.812
# Val: Epoch = 19 | Loss 2.062 | Accuracy = 43.103
# Train: Epoch = 20 | Loss = 1.659 | Loss2 = 0.141 | Accuracy = 53.438
# Val: Epoch = 20 | Loss 1.839 | Accuracy = 50.862
# Train: Epoch = 21 | Loss = 1.634 | Loss2 = 0.139 | Accuracy = 50.938
# Val: Epoch = 21 | Loss 1.761 | Accuracy = 50.000
# Train: Epoch = 22 | Loss = 1.436 | Loss2 = 0.146 | Accuracy = 58.438
# Val: Epoch = 22 | Loss 1.906 | Accuracy = 51.724
# Train: Epoch = 23 | Loss = 1.535 | Loss2 = 0.141 | Accuracy = 56.563
# Val: Epoch = 23 | Loss 1.994 | Accuracy = 50.862
# Train: Epoch = 24 | Loss = 1.637 | Loss2 = 0.144 | Accuracy = 52.188
# Val: Epoch = 24 | Loss 2.111 | Accuracy = 43.103
# Train: Epoch = 25 | Loss = 1.674 | Loss2 = 0.142 | Accuracy = 51.562
# Val: Epoch = 25 | Loss 1.692 | Accuracy = 50.000
# Train: Epoch = 26 | Loss = 1.640 | Loss2 = 0.143 | Accuracy = 51.875
# Val: Epoch = 26 | Loss 1.973 | Accuracy = 48.276
# Train: Epoch = 27 | Loss = 1.486 | Loss2 = 0.140 | Accuracy = 60.000
# Val: Epoch = 27 | Loss 1.780 | Accuracy = 50.862
# Train: Epoch = 28 | Loss = 1.303 | Loss2 = 0.142 | Accuracy = 60.312
# Val: Epoch = 28 | Loss 1.654 | Accuracy = 51.724
# Train: Epoch = 29 | Loss = 1.411 | Loss2 = 0.138 | Accuracy = 56.563
# Val: Epoch = 29 | Loss 1.926 | Accuracy = 48.276
# Train: Epoch = 30 | Loss = 1.276 | Loss2 = 0.134 | Accuracy = 61.562
# Val: Epoch = 30 | Loss 1.967 | Accuracy = 48.276
# Train: Epoch = 31 | Loss = 1.348 | Loss2 = 0.142 | Accuracy = 60.000
# Val: Epoch = 31 | Loss 1.798 | Accuracy = 54.310
# [||| NEW BEST on val |||]
# Train: Epoch = 32 | Loss = 1.336 | Loss2 = 0.144 | Accuracy = 58.438
# Val: Epoch = 32 | Loss 1.685 | Accuracy = 53.448
# Train: Epoch = 33 | Loss = 1.298 | Loss2 = 0.146 | Accuracy = 61.562
# Val: Epoch = 33 | Loss 1.664 | Accuracy = 56.034
# [||| NEW BEST on val |||]
# Train: Epoch = 34 | Loss = 1.308 | Loss2 = 0.141 | Accuracy = 64.375
# Val: Epoch = 34 | Loss 1.703 | Accuracy = 51.724
# Train: Epoch = 35 | Loss = 1.214 | Loss2 = 0.142 | Accuracy = 63.750
# Val: Epoch = 35 | Loss 1.738 | Accuracy = 52.586
# Train: Epoch = 36 | Loss = 1.126 | Loss2 = 0.145 | Accuracy = 66.875
# Val: Epoch = 36 | Loss 1.671 | Accuracy = 52.586
# Train: Epoch = 37 | Loss = 1.144 | Loss2 = 0.146 | Accuracy = 65.938
# Val: Epoch = 37 | Loss 1.636 | Accuracy = 57.759
# [||| NEW BEST on val |||]
# Train: Epoch = 38 | Loss = 1.225 | Loss2 = 0.143 | Accuracy = 64.062
# Val: Epoch = 38 | Loss 1.665 | Accuracy = 54.310
# Train: Epoch = 39 | Loss = 1.144 | Loss2 = 0.142 | Accuracy = 62.813
# Val: Epoch = 39 | Loss 1.700 | Accuracy = 51.724
# Train: Epoch = 40 | Loss = 1.293 | Loss2 = 0.149 | Accuracy = 61.875
# Val: Epoch = 40 | Loss 1.769 | Accuracy = 51.724
# Train: Epoch = 41 | Loss = 1.217 | Loss2 = 0.143 | Accuracy = 64.062
# Val: Epoch = 41 | Loss 1.680 | Accuracy = 52.586
# Train: Epoch = 42 | Loss = 1.130 | Loss2 = 0.149 | Accuracy = 65.312
# Val: Epoch = 42 | Loss 1.636 | Accuracy = 54.310
# Train: Epoch = 43 | Loss = 1.306 | Loss2 = 0.144 | Accuracy = 60.625
# Val: Epoch = 43 | Loss 1.708 | Accuracy = 53.448
# Train: Epoch = 44 | Loss = 1.084 | Loss2 = 0.140 | Accuracy = 66.250
# Val: Epoch = 44 | Loss 1.705 | Accuracy = 53.448
# Train: Epoch = 45 | Loss = 1.218 | Loss2 = 0.142 | Accuracy = 60.000
# Val: Epoch = 45 | Loss 1.809 | Accuracy = 50.000
# Train: Epoch = 46 | Loss = 1.058 | Loss2 = 0.146 | Accuracy = 70.000
# Val: Epoch = 46 | Loss 1.654 | Accuracy = 53.448
# Train: Epoch = 47 | Loss = 1.202 | Loss2 = 0.141 | Accuracy = 65.938
# Val: Epoch = 47 | Loss 1.769 | Accuracy = 51.724
# Train: Epoch = 48 | Loss = 1.234 | Loss2 = 0.149 | Accuracy = 62.187
# Val: Epoch = 48 | Loss 1.685 | Accuracy = 52.586
# Train: Epoch = 49 | Loss = 1.099 | Loss2 = 0.143 | Accuracy = 66.875
# Val: Epoch = 49 | Loss 1.596 | Accuracy = 58.621
# [||| NEW BEST on val |||]
# Train: Epoch = 50 | Loss = 1.064 | Loss2 = 0.143 | Accuracy = 71.875
# Val: Epoch = 50 | Loss 1.679 | Accuracy = 54.310
# Train: Epoch = 51 | Loss = 1.062 | Loss2 = 0.140 | Accuracy = 69.062
# Val: Epoch = 51 | Loss 1.682 | Accuracy = 51.724
# Train: Epoch = 52 | Loss = 1.150 | Loss2 = 0.146 | Accuracy = 67.188
# Val: Epoch = 52 | Loss 1.773 | Accuracy = 53.448
# Train: Epoch = 53 | Loss = 1.046 | Loss2 = 0.141 | Accuracy = 68.750
# Val: Epoch = 53 | Loss 1.734 | Accuracy = 49.138
# Train: Epoch = 54 | Loss = 1.047 | Loss2 = 0.147 | Accuracy = 70.000
# Val: Epoch = 54 | Loss 1.647 | Accuracy = 52.586
# Train: Epoch = 55 | Loss = 1.058 | Loss2 = 0.139 | Accuracy = 67.812
# Val: Epoch = 55 | Loss 1.643 | Accuracy = 51.724
# Train: Epoch = 56 | Loss = 1.134 | Loss2 = 0.141 | Accuracy = 67.812
# Val: Epoch = 56 | Loss 1.748 | Accuracy = 52.586
# Train: Epoch = 57 | Loss = 1.059 | Loss2 = 0.146 | Accuracy = 70.312
# Val: Epoch = 57 | Loss 1.748 | Accuracy = 51.724
# Train: Epoch = 58 | Loss = 1.074 | Loss2 = 0.139 | Accuracy = 67.812
# Val: Epoch = 58 | Loss 1.749 | Accuracy = 50.862
# Train: Epoch = 59 | Loss = 1.072 | Loss2 = 0.142 | Accuracy = 69.688
# Val: Epoch = 59 | Loss 1.785 | Accuracy = 50.000
# Train: Epoch = 60 | Loss = 1.012 | Loss2 = 0.137 | Accuracy = 73.438
# Val: Epoch = 60 | Loss 1.786 | Accuracy = 51.724
# Train: Epoch = 61 | Loss = 0.985 | Loss2 = 0.146 | Accuracy = 70.625
# Val: Epoch = 61 | Loss 1.732 | Accuracy = 54.310
# Train: Epoch = 62 | Loss = 1.074 | Loss2 = 0.146 | Accuracy = 69.062
# Val: Epoch = 62 | Loss 1.779 | Accuracy = 54.310
# Train: Epoch = 63 | Loss = 0.999 | Loss2 = 0.144 | Accuracy = 69.062
# Val: Epoch = 63 | Loss 1.732 | Accuracy = 51.724
# Train: Epoch = 64 | Loss = 1.095 | Loss2 = 0.138 | Accuracy = 69.062
# Val: Epoch = 64 | Loss 1.606 | Accuracy = 59.483
# [||| NEW BEST on val |||]
# Train: Epoch = 65 | Loss = 0.958 | Loss2 = 0.140 | Accuracy = 72.188
# Val: Epoch = 65 | Loss 1.632 | Accuracy = 58.621
# Train: Epoch = 66 | Loss = 0.882 | Loss2 = 0.140 | Accuracy = 74.375
# Val: Epoch = 66 | Loss 1.610 | Accuracy = 58.621
# Train: Epoch = 67 | Loss = 0.999 | Loss2 = 0.147 | Accuracy = 73.125
# Val: Epoch = 67 | Loss 1.613 | Accuracy = 58.621
# Train: Epoch = 68 | Loss = 0.967 | Loss2 = 0.142 | Accuracy = 73.750
# Val: Epoch = 68 | Loss 1.669 | Accuracy = 58.621
# Train: Epoch = 69 | Loss = 1.004 | Loss2 = 0.145 | Accuracy = 70.312
# Val: Epoch = 69 | Loss 1.723 | Accuracy = 56.897
# Train: Epoch = 70 | Loss = 0.992 | Loss2 = 0.147 | Accuracy = 70.312
# Val: Epoch = 70 | Loss 1.837 | Accuracy = 53.448
# Train: Epoch = 71 | Loss = 0.940 | Loss2 = 0.141 | Accuracy = 72.188
# Val: Epoch = 71 | Loss 1.663 | Accuracy = 56.897
# Train: Epoch = 72 | Loss = 1.005 | Loss2 = 0.149 | Accuracy = 70.000
# Val: Epoch = 72 | Loss 1.732 | Accuracy = 56.897
# Train: Epoch = 73 | Loss = 1.045 | Loss2 = 0.140 | Accuracy = 67.188
# Val: Epoch = 73 | Loss 1.583 | Accuracy = 60.345
# [||| NEW BEST on val |||]
# Train: Epoch = 74 | Loss = 0.965 | Loss2 = 0.143 | Accuracy = 72.500
# Val: Epoch = 74 | Loss 1.659 | Accuracy = 56.897
# Train: Epoch = 75 | Loss = 0.916 | Loss2 = 0.147 | Accuracy = 75.000
# Val: Epoch = 75 | Loss 1.688 | Accuracy = 55.172
# Train: Epoch = 76 | Loss = 0.959 | Loss2 = 0.141 | Accuracy = 70.938
# Val: Epoch = 76 | Loss 1.657 | Accuracy = 54.310
# Train: Epoch = 77 | Loss = 0.890 | Loss2 = 0.143 | Accuracy = 72.188
# Val: Epoch = 77 | Loss 1.821 | Accuracy = 51.724
# Train: Epoch = 78 | Loss = 0.881 | Loss2 = 0.147 | Accuracy = 74.688
# Val: Epoch = 78 | Loss 1.639 | Accuracy = 56.034
# Train: Epoch = 79 | Loss = 0.924 | Loss2 = 0.142 | Accuracy = 73.438
# Val: Epoch = 79 | Loss 1.752 | Accuracy = 53.448
# Train: Epoch = 80 | Loss = 0.993 | Loss2 = 0.143 | Accuracy = 72.188
# Val: Epoch = 80 | Loss 1.654 | Accuracy = 54.310
# Train: Epoch = 81 | Loss = 0.869 | Loss2 = 0.143 | Accuracy = 74.062
# Val: Epoch = 81 | Loss 1.672 | Accuracy = 53.448
# Train: Epoch = 82 | Loss = 0.920 | Loss2 = 0.143 | Accuracy = 70.625
# Val: Epoch = 82 | Loss 1.705 | Accuracy = 53.448
# Train: Epoch = 83 | Loss = 0.930 | Loss2 = 0.139 | Accuracy = 71.250
# Val: Epoch = 83 | Loss 1.672 | Accuracy = 55.172
# Train: Epoch = 84 | Loss = 0.892 | Loss2 = 0.146 | Accuracy = 73.750
# Val: Epoch = 84 | Loss 1.649 | Accuracy = 55.172
# Train: Epoch = 85 | Loss = 0.963 | Loss2 = 0.142 | Accuracy = 72.500
# Val: Epoch = 85 | Loss 1.653 | Accuracy = 56.034
# Train: Epoch = 86 | Loss = 0.839 | Loss2 = 0.145 | Accuracy = 73.438
# Val: Epoch = 86 | Loss 1.663 | Accuracy = 55.172
# Train: Epoch = 87 | Loss = 0.905 | Loss2 = 0.144 | Accuracy = 72.812
# Val: Epoch = 87 | Loss 1.658 | Accuracy = 54.310
# Train: Epoch = 88 | Loss = 0.919 | Loss2 = 0.138 | Accuracy = 72.812
# Val: Epoch = 88 | Loss 1.682 | Accuracy = 53.448
# Train: Epoch = 89 | Loss = 0.868 | Loss2 = 0.143 | Accuracy = 72.188
# Val: Epoch = 89 | Loss 1.670 | Accuracy = 51.724
# Train: Epoch = 90 | Loss = 0.857 | Loss2 = 0.145 | Accuracy = 74.375
# Val: Epoch = 90 | Loss 1.670 | Accuracy = 51.724
# Train: Epoch = 91 | Loss = 1.005 | Loss2 = 0.139 | Accuracy = 68.750
# Val: Epoch = 91 | Loss 1.648 | Accuracy = 55.172
# Train: Epoch = 92 | Loss = 0.876 | Loss2 = 0.135 | Accuracy = 75.312
# Val: Epoch = 92 | Loss 1.646 | Accuracy = 55.172
# Train: Epoch = 93 | Loss = 0.929 | Loss2 = 0.145 | Accuracy = 71.562
# Val: Epoch = 93 | Loss 1.630 | Accuracy = 56.034
# Train: Epoch = 94 | Loss = 0.771 | Loss2 = 0.142 | Accuracy = 75.312
# Val: Epoch = 94 | Loss 1.638 | Accuracy = 54.310
# Train: Epoch = 95 | Loss = 0.999 | Loss2 = 0.138 | Accuracy = 73.438
# Val: Epoch = 95 | Loss 1.666 | Accuracy = 53.448
# Train: Epoch = 96 | Loss = 0.868 | Loss2 = 0.138 | Accuracy = 73.750
# Val: Epoch = 96 | Loss 1.682 | Accuracy = 53.448
# Train: Epoch = 97 | Loss = 0.818 | Loss2 = 0.144 | Accuracy = 74.062
# Val: Epoch = 97 | Loss 1.707 | Accuracy = 54.310
# Train: Epoch = 98 | Loss = 0.915 | Loss2 = 0.135 | Accuracy = 73.125
# Val: Epoch = 98 | Loss 1.666 | Accuracy = 54.310
# Train: Epoch = 99 | Loss = 0.775 | Loss2 = 0.142 | Accuracy = 75.312
# Val: Epoch = 99 | Loss 1.639 | Accuracy = 54.310
# Train: Epoch = 100 | Loss = 0.850 | Loss2 = 0.139 | Accuracy = 77.500
# Val: Epoch = 100 | Loss 1.623 | Accuracy = 53.448
# Train: Epoch = 101 | Loss = 0.914 | Loss2 = 0.141 | Accuracy = 72.812
# Val: Epoch = 101 | Loss 1.601 | Accuracy = 55.172
# Train: Epoch = 102 | Loss = 0.830 | Loss2 = 0.136 | Accuracy = 76.562
# Val: Epoch = 102 | Loss 1.618 | Accuracy = 55.172
# Train: Epoch = 103 | Loss = 0.952 | Loss2 = 0.140 | Accuracy = 71.562
# Val: Epoch = 103 | Loss 1.621 | Accuracy = 54.310
# Train: Epoch = 104 | Loss = 0.818 | Loss2 = 0.136 | Accuracy = 76.250
# Val: Epoch = 104 | Loss 1.616 | Accuracy = 55.172
# Train: Epoch = 105 | Loss = 0.829 | Loss2 = 0.138 | Accuracy = 77.188
# Val: Epoch = 105 | Loss 1.627 | Accuracy = 53.448
# Train: Epoch = 106 | Loss = 1.010 | Loss2 = 0.146 | Accuracy = 72.500
# Val: Epoch = 106 | Loss 1.635 | Accuracy = 54.310
# Train: Epoch = 107 | Loss = 0.770 | Loss2 = 0.139 | Accuracy = 76.562
# Val: Epoch = 107 | Loss 1.624 | Accuracy = 55.172
# Train: Epoch = 108 | Loss = 0.918 | Loss2 = 0.138 | Accuracy = 72.812
# Val: Epoch = 108 | Loss 1.634 | Accuracy = 54.310
# Train: Epoch = 109 | Loss = 0.790 | Loss2 = 0.142 | Accuracy = 76.250
# Val: Epoch = 109 | Loss 1.639 | Accuracy = 51.724
# Train: Epoch = 110 | Loss = 0.864 | Loss2 = 0.146 | Accuracy = 74.688
# Val: Epoch = 110 | Loss 1.637 | Accuracy = 52.586
# Train: Epoch = 111 | Loss = 0.816 | Loss2 = 0.143 | Accuracy = 76.562
# Val: Epoch = 111 | Loss 1.626 | Accuracy = 53.448
# Train: Epoch = 112 | Loss = 0.817 | Loss2 = 0.147 | Accuracy = 75.000
# Val: Epoch = 112 | Loss 1.627 | Accuracy = 56.034
# Train: Epoch = 113 | Loss = 0.858 | Loss2 = 0.140 | Accuracy = 73.438
# Val: Epoch = 113 | Loss 1.635 | Accuracy = 56.034
# Train: Epoch = 114 | Loss = 0.900 | Loss2 = 0.142 | Accuracy = 76.562
# Val: Epoch = 114 | Loss 1.640 | Accuracy = 54.310
# Train: Epoch = 115 | Loss = 0.805 | Loss2 = 0.143 | Accuracy = 75.312
# Val: Epoch = 115 | Loss 1.656 | Accuracy = 54.310
# Train: Epoch = 116 | Loss = 0.819 | Loss2 = 0.143 | Accuracy = 78.750
# Val: Epoch = 116 | Loss 1.640 | Accuracy = 56.034
# Train: Epoch = 117 | Loss = 0.824 | Loss2 = 0.141 | Accuracy = 76.250
# Val: Epoch = 117 | Loss 1.589 | Accuracy = 57.759
# Train: Epoch = 118 | Loss = 0.743 | Loss2 = 0.141 | Accuracy = 79.688
# Val: Epoch = 118 | Loss 1.601 | Accuracy = 56.034
# Train: Epoch = 119 | Loss = 0.874 | Loss2 = 0.140 | Accuracy = 73.750
# Val: Epoch = 119 | Loss 1.640 | Accuracy = 53.448
# Train: Epoch = 120 | Loss = 0.912 | Loss2 = 0.148 | Accuracy = 73.125
# Val: Epoch = 120 | Loss 1.656 | Accuracy = 54.310
# Train: Epoch = 121 | Loss = 0.824 | Loss2 = 0.148 | Accuracy = 77.812
# Val: Epoch = 121 | Loss 1.653 | Accuracy = 54.310
# Train: Epoch = 122 | Loss = 0.848 | Loss2 = 0.141 | Accuracy = 77.500
# Val: Epoch = 122 | Loss 1.662 | Accuracy = 54.310
# Train: Epoch = 123 | Loss = 0.842 | Loss2 = 0.143 | Accuracy = 76.250
# Val: Epoch = 123 | Loss 1.664 | Accuracy = 53.448
# Train: Epoch = 124 | Loss = 0.842 | Loss2 = 0.141 | Accuracy = 74.062
# Val: Epoch = 124 | Loss 1.645 | Accuracy = 55.172
# Train: Epoch = 125 | Loss = 0.831 | Loss2 = 0.143 | Accuracy = 76.250
# Val: Epoch = 125 | Loss 1.635 | Accuracy = 54.310
# Train: Epoch = 126 | Loss = 0.848 | Loss2 = 0.140 | Accuracy = 74.375
# Val: Epoch = 126 | Loss 1.632 | Accuracy = 54.310
# Train: Epoch = 127 | Loss = 0.897 | Loss2 = 0.138 | Accuracy = 71.562
# Val: Epoch = 127 | Loss 1.634 | Accuracy = 54.310
# Train: Epoch = 128 | Loss = 0.803 | Loss2 = 0.140 | Accuracy = 75.312
# Val: Epoch = 128 | Loss 1.622 | Accuracy = 54.310
# Train: Epoch = 129 | Loss = 0.771 | Loss2 = 0.145 | Accuracy = 76.875
# Val: Epoch = 129 | Loss 1.639 | Accuracy = 52.586
# Train: Epoch = 130 | Loss = 0.881 | Loss2 = 0.140 | Accuracy = 76.250
# Val: Epoch = 130 | Loss 1.648 | Accuracy = 53.448
# Train: Epoch = 131 | Loss = 0.812 | Loss2 = 0.137 | Accuracy = 75.625
# Val: Epoch = 131 | Loss 1.641 | Accuracy = 54.310
# Train: Epoch = 132 | Loss = 0.885 | Loss2 = 0.138 | Accuracy = 74.062
# Val: Epoch = 132 | Loss 1.636 | Accuracy = 54.310
# Train: Epoch = 133 | Loss = 0.895 | Loss2 = 0.146 | Accuracy = 73.438
# Val: Epoch = 133 | Loss 1.673 | Accuracy = 54.310
# Train: Epoch = 134 | Loss = 0.841 | Loss2 = 0.133 | Accuracy = 76.875
# Val: Epoch = 134 | Loss 1.710 | Accuracy = 52.586
# Train: Epoch = 135 | Loss = 0.757 | Loss2 = 0.147 | Accuracy = 76.562
# Val: Epoch = 135 | Loss 1.727 | Accuracy = 54.310
# Train: Epoch = 136 | Loss = 0.666 | Loss2 = 0.133 | Accuracy = 80.938
# Val: Epoch = 136 | Loss 1.680 | Accuracy = 54.310
# Train: Epoch = 137 | Loss = 0.796 | Loss2 = 0.135 | Accuracy = 74.688
# Val: Epoch = 137 | Loss 1.654 | Accuracy = 54.310
# Train: Epoch = 138 | Loss = 0.832 | Loss2 = 0.143 | Accuracy = 79.062
# Val: Epoch = 138 | Loss 1.679 | Accuracy = 53.448
# Train: Epoch = 139 | Loss = 0.792 | Loss2 = 0.143 | Accuracy = 73.125
# Val: Epoch = 139 | Loss 1.661 | Accuracy = 54.310
# Train: Epoch = 140 | Loss = 0.767 | Loss2 = 0.139 | Accuracy = 78.438
# Val: Epoch = 140 | Loss 1.637 | Accuracy = 55.172
# Train: Epoch = 141 | Loss = 0.777 | Loss2 = 0.138 | Accuracy = 77.188
# Val: Epoch = 141 | Loss 1.653 | Accuracy = 54.310
# Train: Epoch = 142 | Loss = 0.767 | Loss2 = 0.147 | Accuracy = 80.312
# Val: Epoch = 142 | Loss 1.660 | Accuracy = 54.310
# Train: Epoch = 143 | Loss = 0.707 | Loss2 = 0.135 | Accuracy = 77.188
# Val: Epoch = 143 | Loss 1.647 | Accuracy = 54.310
# Train: Epoch = 144 | Loss = 0.830 | Loss2 = 0.140 | Accuracy = 76.562
# Val: Epoch = 144 | Loss 1.665 | Accuracy = 54.310
# Train: Epoch = 145 | Loss = 0.881 | Loss2 = 0.135 | Accuracy = 74.375
# Val: Epoch = 145 | Loss 1.684 | Accuracy = 54.310
# Train: Epoch = 146 | Loss = 0.762 | Loss2 = 0.145 | Accuracy = 76.875
# Val: Epoch = 146 | Loss 1.634 | Accuracy = 55.172
# Train: Epoch = 147 | Loss = 0.863 | Loss2 = 0.142 | Accuracy = 74.062
# Val: Epoch = 147 | Loss 1.640 | Accuracy = 56.034
# Train: Epoch = 148 | Loss = 0.806 | Loss2 = 0.138 | Accuracy = 76.250
# Val: Epoch = 148 | Loss 1.652 | Accuracy = 55.172
# Train: Epoch = 149 | Loss = 0.898 | Loss2 = 0.142 | Accuracy = 71.875
# Val: Epoch = 149 | Loss 1.664 | Accuracy = 54.310
# Train: Epoch = 150 | Loss = 0.824 | Loss2 = 0.133 | Accuracy = 75.312
# Val: Epoch = 150 | Loss 1.688 | Accuracy = 53.448

# %%
RUN = "_run06_a0.1"

train_iter = 0
val_iter = 0
min_accuracy = 0

trainSamples = len(train_dataset) - (len(train_dataset) % BATCH_SIZE)
val_samples = len(test_dataset)

iterPerEpoch = len(train_loader)
val_steps = len(val_loader)

cudnn.benchmark
torch.autograd.set_detect_anomaly(True)
train_log, val_log = generate_log_filenames(STAGE, SEQ_LEN, ms_block = True, \
                                            optional = '_2neur_DS_alpha_' + RUN)
model_checkpoint = generate_model_checkpoint_name(STAGE, SEQ_LEN, ms_block = True, \
                                                  optional = '_2neur_DS_alpha_' + RUN)

train_log_file = os.path.join(model_folder, train_log)
val_log_file = os.path.join(model_folder, val_log)
train_logger_2 = Logger(**parameters)
val_logger_2 = Logger(**parameters)

for epoch in range(NUM_EPOCHS):

    epoch_loss = 0
    epoch_loss2 = 0
    numCorrTrain = 0
    
    for layer in layers_to_train:
        layer.train(True)
    
    for i, (inputs, inputs_DS, mmaps, targets) in enumerate(train_loader):

        mmaps = mmaps.permute(1, 0, 2)

        train_iter += 1

        optimizer_fn.zero_grad()

        inputVariable = inputs.permute(1, 0, 2, 3, 4).to(DEVICE)
        inputVariable_DS = inputs_DS.permute(1, 0, 2, 3, 4).to(DEVICE)
        labelVariable = targets.to(DEVICE)

        output_label, _, output_label_mmaps = model(inputVariable, mmaps = True)

        output_label_mmaps = output_label_mmaps.view(SEQ_LEN*BATCH_SIZE*MMAP_LENGTH, 2).to(DEVICE)
        mmaps = torch.flatten(mmaps).long().to(DEVICE)

        loss = loss_fn_sum(output_label_mmaps, mmaps)/(BATCH_SIZE * SEQ_LEN) + loss_fn(output_label, labelVariable)
        loss.backward()

        for layer in layers_on_off:
            for params in layer.parameters():
                params.requires_grad = False

        output_label_ds1, _ = model(inputVariable, static_frames = True)
        output_label_ds2, _ = model(inputVariable_DS, static_frames = True)
        
        gt_ds1 = torch.zeros(BATCH_SIZE).long().to(DEVICE)
        gt_ds2 = torch.ones(BATCH_SIZE).long().to(DEVICE)

        loss2 = ALPHA * (loss_fn(output_label_ds1, gt_ds1) + loss_fn(output_label_ds2, gt_ds2))

        loss2.backward()

        for layer in layers_on_off:
            for params in layer.parameters():
                params.requires_grad = True

        optimizer_fn.step()
        
        _, predicted = torch.max(output_label.data, 1)
        numCorrTrain += torch.sum(predicted == labelVariable.data).data.item()
        step_loss = loss.data.item()
        step_loss2 = loss2.data.item()
        epoch_loss += step_loss
        epoch_loss2 += step_loss2
        train_logger_2.add_step_data(train_iter, numCorrTrain, step_loss)

        
    avg_loss = epoch_loss/iterPerEpoch
    avg_loss2 = epoch_loss2/iterPerEpoch
    trainAccuracy = (numCorrTrain / trainSamples) * 100
    train_logger_2.add_epoch_data(epoch+1, trainAccuracy, avg_loss)
    
    print('Train: Epoch = {} | Loss = {:.3f} | Loss2 = {:.3f} | Accuracy = {:.3f}'.format(epoch+1, avg_loss, avg_loss2, trainAccuracy))

    if validate is not None:

        if (epoch+1) % 1 == 0:

            model.train(False)
            val_loss_epoch = 0
            numCorr = 0

            for j, (inputs, targets) in enumerate(val_loader):

                val_iter += 1

                inputVariable = inputs.permute(1, 0, 2, 3, 4).to(DEVICE)
                labelVariable = targets.to(DEVICE)
                
                output_label, _ = model(inputVariable)

                val_loss = loss_fn(output_label, labelVariable)
                val_loss_step = val_loss.data.item()
                val_loss_epoch += val_loss_step

                _, predicted = torch.max(output_label.data, 1)

                numCorr += torch.sum(predicted == labelVariable.data).data.item()
                val_logger_2.add_step_data(val_iter, numCorr, val_loss_step)

            val_accuracy = (numCorr / val_samples) * 100
            avg_val_loss = val_loss_epoch / val_steps

            print('Val: Epoch = {} | Loss {:.3f} | Accuracy = {:.3f}'.format(epoch + 1, avg_val_loss, val_accuracy))
            
            val_logger_2.add_epoch_data(epoch+1, val_accuracy, avg_val_loss)
            
            if val_accuracy > min_accuracy:
                print("[||| NEW BEST on val |||]")
                save_path_model = os.path.join(model_folder, model_checkpoint)
                torch.save(model.state_dict(), save_path_model)
                min_accuracy = val_accuracy
            
    optim_scheduler.step()

    train_logger_2.save(train_log_file)
    val_logger_2.save(val_log_file)
# Out:
# Train: Epoch = 1 | Loss = 34.050 | Loss2 = 0.145 | Accuracy = 86.250
# Val: Epoch = 1 | Loss 1.509 | Accuracy = 62.069
# [||| NEW BEST on val |||]
# Train: Epoch = 2 | Loss = 34.105 | Loss2 = 0.140 | Accuracy = 80.938
# Val: Epoch = 2 | Loss 1.516 | Accuracy = 61.207
# Train: Epoch = 3 | Loss = 34.112 | Loss2 = 0.140 | Accuracy = 81.250
# Val: Epoch = 3 | Loss 1.506 | Accuracy = 63.793
# [||| NEW BEST on val |||]
# Train: Epoch = 4 | Loss = 34.064 | Loss2 = 0.137 | Accuracy = 82.812
# Val: Epoch = 4 | Loss 1.487 | Accuracy = 62.931
# Train: Epoch = 5 | Loss = 34.042 | Loss2 = 0.144 | Accuracy = 81.250
# Val: Epoch = 5 | Loss 1.517 | Accuracy = 63.793
# Train: Epoch = 6 | Loss = 34.127 | Loss2 = 0.138 | Accuracy = 81.875
# Val: Epoch = 6 | Loss 1.554 | Accuracy = 59.483
# Train: Epoch = 7 | Loss = 34.148 | Loss2 = 0.141 | Accuracy = 80.000
# Val: Epoch = 7 | Loss 1.567 | Accuracy = 59.483
# Train: Epoch = 8 | Loss = 34.008 | Loss2 = 0.143 | Accuracy = 84.375
# Val: Epoch = 8 | Loss 1.546 | Accuracy = 60.345
# Train: Epoch = 9 | Loss = 34.072 | Loss2 = 0.142 | Accuracy = 82.500
# Val: Epoch = 9 | Loss 1.548 | Accuracy = 61.207
# Train: Epoch = 10 | Loss = 34.111 | Loss2 = 0.139 | Accuracy = 82.188
# Val: Epoch = 10 | Loss 1.561 | Accuracy = 60.345
# Train: Epoch = 11 | Loss = 34.165 | Loss2 = 0.142 | Accuracy = 80.938
# Val: Epoch = 11 | Loss 1.574 | Accuracy = 61.207
# Train: Epoch = 12 | Loss = 34.130 | Loss2 = 0.147 | Accuracy = 80.938
# Val: Epoch = 12 | Loss 1.537 | Accuracy = 59.483
# Train: Epoch = 13 | Loss = 34.074 | Loss2 = 0.145 | Accuracy = 81.562
# Val: Epoch = 13 | Loss 1.526 | Accuracy = 61.207
# Train: Epoch = 14 | Loss = 34.076 | Loss2 = 0.141 | Accuracy = 81.250
# Val: Epoch = 14 | Loss 1.561 | Accuracy = 59.483
# Train: Epoch = 15 | Loss = 34.009 | Loss2 = 0.138 | Accuracy = 82.812
# Val: Epoch = 15 | Loss 1.567 | Accuracy = 60.345
# Train: Epoch = 16 | Loss = 34.091 | Loss2 = 0.140 | Accuracy = 83.125
# Val: Epoch = 16 | Loss 1.555 | Accuracy = 59.483
# Train: Epoch = 17 | Loss = 34.067 | Loss2 = 0.142 | Accuracy = 83.125
# Val: Epoch = 17 | Loss 1.549 | Accuracy = 59.483
# Train: Epoch = 18 | Loss = 34.039 | Loss2 = 0.139 | Accuracy = 83.750
# Val: Epoch = 18 | Loss 1.534 | Accuracy = 60.345
# Train: Epoch = 19 | Loss = 34.056 | Loss2 = 0.145 | Accuracy = 84.062
# Val: Epoch = 19 | Loss 1.542 | Accuracy = 60.345
# Train: Epoch = 20 | Loss = 33.989 | Loss2 = 0.140 | Accuracy = 85.938
# Val: Epoch = 20 | Loss 1.547 | Accuracy = 60.345
# Train: Epoch = 21 | Loss = 34.043 | Loss2 = 0.140 | Accuracy = 84.688
# Val: Epoch = 21 | Loss 1.536 | Accuracy = 60.345
# Train: Epoch = 22 | Loss = 34.061 | Loss2 = 0.148 | Accuracy = 84.062
# Val: Epoch = 22 | Loss 1.536 | Accuracy = 58.621
# Train: Epoch = 23 | Loss = 34.033 | Loss2 = 0.139 | Accuracy = 83.438
# Val: Epoch = 23 | Loss 1.542 | Accuracy = 57.759
# Train: Epoch = 24 | Loss = 34.145 | Loss2 = 0.142 | Accuracy = 79.062
# Val: Epoch = 24 | Loss 1.548 | Accuracy = 59.483
# Train: Epoch = 25 | Loss = 34.091 | Loss2 = 0.136 | Accuracy = 83.125
# Val: Epoch = 25 | Loss 1.546 | Accuracy = 58.621
# Train: Epoch = 26 | Loss = 34.012 | Loss2 = 0.144 | Accuracy = 84.062
# Val: Epoch = 26 | Loss 1.548 | Accuracy = 57.759
# Train: Epoch = 27 | Loss = 34.136 | Loss2 = 0.145 | Accuracy = 81.250
# Val: Epoch = 27 | Loss 1.576 | Accuracy = 59.483
# Train: Epoch = 28 | Loss = 34.051 | Loss2 = 0.141 | Accuracy = 85.000
# Val: Epoch = 28 | Loss 1.584 | Accuracy = 59.483
# Train: Epoch = 29 | Loss = 34.007 | Loss2 = 0.143 | Accuracy = 84.688
# Val: Epoch = 29 | Loss 1.547 | Accuracy = 58.621
# Train: Epoch = 30 | Loss = 34.052 | Loss2 = 0.142 | Accuracy = 81.875
# Val: Epoch = 30 | Loss 1.517 | Accuracy = 59.483
# Train: Epoch = 31 | Loss = 34.103 | Loss2 = 0.137 | Accuracy = 82.500
# Val: Epoch = 31 | Loss 1.541 | Accuracy = 61.207
# Train: Epoch = 32 | Loss = 34.021 | Loss2 = 0.147 | Accuracy = 84.688
# Val: Epoch = 32 | Loss 1.550 | Accuracy = 62.069
# Train: Epoch = 33 | Loss = 33.982 | Loss2 = 0.145 | Accuracy = 86.250
# Val: Epoch = 33 | Loss 1.542 | Accuracy = 62.931
# Train: Epoch = 34 | Loss = 34.103 | Loss2 = 0.149 | Accuracy = 80.938
# Val: Epoch = 34 | Loss 1.521 | Accuracy = 64.655
# [||| NEW BEST on val |||]
# Train: Epoch = 35 | Loss = 34.032 | Loss2 = 0.138 | Accuracy = 84.688
# Val: Epoch = 35 | Loss 1.548 | Accuracy = 61.207
# Train: Epoch = 36 | Loss = 33.997 | Loss2 = 0.135 | Accuracy = 84.688
# Val: Epoch = 36 | Loss 1.570 | Accuracy = 61.207
# Train: Epoch = 37 | Loss = 34.060 | Loss2 = 0.144 | Accuracy = 83.438
# Val: Epoch = 37 | Loss 1.579 | Accuracy = 59.483
# Train: Epoch = 38 | Loss = 34.047 | Loss2 = 0.142 | Accuracy = 83.125
# Val: Epoch = 38 | Loss 1.560 | Accuracy = 58.621
# Train: Epoch = 39 | Loss = 34.083 | Loss2 = 0.141 | Accuracy = 82.188
# Val: Epoch = 39 | Loss 1.562 | Accuracy = 59.483
# Train: Epoch = 40 | Loss = 34.067 | Loss2 = 0.144 | Accuracy = 82.812
# Val: Epoch = 40 | Loss 1.584 | Accuracy = 59.483
# Train: Epoch = 41 | Loss = 34.056 | Loss2 = 0.140 | Accuracy = 85.000
# Val: Epoch = 41 | Loss 1.566 | Accuracy = 61.207
# Train: Epoch = 42 | Loss = 34.075 | Loss2 = 0.139 | Accuracy = 84.688
# Val: Epoch = 42 | Loss 1.576 | Accuracy = 60.345
# Train: Epoch = 43 | Loss = 34.080 | Loss2 = 0.139 | Accuracy = 81.562
# Val: Epoch = 43 | Loss 1.536 | Accuracy = 60.345
# Train: Epoch = 44 | Loss = 33.964 | Loss2 = 0.143 | Accuracy = 85.938
# Val: Epoch = 44 | Loss 1.543 | Accuracy = 59.483
# Train: Epoch = 45 | Loss = 34.046 | Loss2 = 0.133 | Accuracy = 82.500
# Val: Epoch = 45 | Loss 1.563 | Accuracy = 58.621
# Train: Epoch = 46 | Loss = 33.954 | Loss2 = 0.143 | Accuracy = 88.750
# Val: Epoch = 46 | Loss 1.560 | Accuracy = 58.621
# Train: Epoch = 47 | Loss = 34.019 | Loss2 = 0.147 | Accuracy = 86.562
# Val: Epoch = 47 | Loss 1.565 | Accuracy = 58.621
# Train: Epoch = 48 | Loss = 33.998 | Loss2 = 0.143 | Accuracy = 84.688
# Val: Epoch = 48 | Loss 1.571 | Accuracy = 59.483
# Train: Epoch = 49 | Loss = 34.024 | Loss2 = 0.148 | Accuracy = 84.062
# Val: Epoch = 49 | Loss 1.563 | Accuracy = 61.207
# Train: Epoch = 50 | Loss = 34.033 | Loss2 = 0.138 | Accuracy = 83.125
# Val: Epoch = 50 | Loss 1.549 | Accuracy = 59.483
# Train: Epoch = 51 | Loss = 33.984 | Loss2 = 0.140 | Accuracy = 85.312
# Val: Epoch = 51 | Loss 1.543 | Accuracy = 61.207
# Train: Epoch = 52 | Loss = 33.948 | Loss2 = 0.145 | Accuracy = 84.688
# Val: Epoch = 52 | Loss 1.564 | Accuracy = 62.069
# Train: Epoch = 53 | Loss = 33.996 | Loss2 = 0.151 | Accuracy = 86.250
# Val: Epoch = 53 | Loss 1.580 | Accuracy = 60.345
# Train: Epoch = 54 | Loss = 34.061 | Loss2 = 0.139 | Accuracy = 84.375
# Val: Epoch = 54 | Loss 1.545 | Accuracy = 59.483
# Train: Epoch = 55 | Loss = 34.047 | Loss2 = 0.146 | Accuracy = 83.125
# Val: Epoch = 55 | Loss 1.529 | Accuracy = 62.931
# Train: Epoch = 56 | Loss = 34.072 | Loss2 = 0.138 | Accuracy = 81.250
# Val: Epoch = 56 | Loss 1.534 | Accuracy = 62.069
# Train: Epoch = 57 | Loss = 34.095 | Loss2 = 0.143 | Accuracy = 81.875
# Val: Epoch = 57 | Loss 1.542 | Accuracy = 62.069
# Train: Epoch = 58 | Loss = 34.032 | Loss2 = 0.139 | Accuracy = 82.500
# Val: Epoch = 58 | Loss 1.527 | Accuracy = 61.207
# Train: Epoch = 59 | Loss = 34.042 | Loss2 = 0.136 | Accuracy = 83.438
# Val: Epoch = 59 | Loss 1.583 | Accuracy = 59.483
# Train: Epoch = 60 | Loss = 34.020 | Loss2 = 0.136 | Accuracy = 85.938
# Val: Epoch = 60 | Loss 1.578 | Accuracy = 59.483
# Train: Epoch = 61 | Loss = 34.016 | Loss2 = 0.141 | Accuracy = 85.312
# Val: Epoch = 61 | Loss 1.583 | Accuracy = 58.621
# Train: Epoch = 62 | Loss = 33.949 | Loss2 = 0.140 | Accuracy = 87.500
# Val: Epoch = 62 | Loss 1.565 | Accuracy = 58.621
# Train: Epoch = 63 | Loss = 33.959 | Loss2 = 0.136 | Accuracy = 86.562
# Val: Epoch = 63 | Loss 1.554 | Accuracy = 59.483
# Train: Epoch = 64 | Loss = 33.994 | Loss2 = 0.149 | Accuracy = 85.938
# Val: Epoch = 64 | Loss 1.583 | Accuracy = 60.345
# Train: Epoch = 65 | Loss = 34.061 | Loss2 = 0.138 | Accuracy = 83.438
# Val: Epoch = 65 | Loss 1.616 | Accuracy = 60.345
# Train: Epoch = 66 | Loss = 33.933 | Loss2 = 0.141 | Accuracy = 87.812
# Val: Epoch = 66 | Loss 1.589 | Accuracy = 62.931
# Train: Epoch = 67 | Loss = 34.011 | Loss2 = 0.139 | Accuracy = 83.750
# Val: Epoch = 67 | Loss 1.580 | Accuracy = 61.207
# Train: Epoch = 68 | Loss = 34.073 | Loss2 = 0.137 | Accuracy = 81.875
# Val: Epoch = 68 | Loss 1.608 | Accuracy = 58.621
# Train: Epoch = 69 | Loss = 34.017 | Loss2 = 0.134 | Accuracy = 83.438
# Val: Epoch = 69 | Loss 1.567 | Accuracy = 59.483
# Train: Epoch = 70 | Loss = 33.970 | Loss2 = 0.138 | Accuracy = 85.000
# Val: Epoch = 70 | Loss 1.550 | Accuracy = 59.483
# Train: Epoch = 71 | Loss = 33.969 | Loss2 = 0.137 | Accuracy = 85.312
# Val: Epoch = 71 | Loss 1.572 | Accuracy = 58.621
# Train: Epoch = 72 | Loss = 33.924 | Loss2 = 0.140 | Accuracy = 87.188
# Val: Epoch = 72 | Loss 1.602 | Accuracy = 61.207
# Train: Epoch = 73 | Loss = 34.064 | Loss2 = 0.141 | Accuracy = 86.250
# Val: Epoch = 73 | Loss 1.598 | Accuracy = 61.207
# Train: Epoch = 74 | Loss = 33.978 | Loss2 = 0.142 | Accuracy = 84.375
# Val: Epoch = 74 | Loss 1.579 | Accuracy = 62.069
# Train: Epoch = 75 | Loss = 34.026 | Loss2 = 0.142 | Accuracy = 84.062
# Val: Epoch = 75 | Loss 1.588 | Accuracy = 59.483
# Train: Epoch = 76 | Loss = 34.060 | Loss2 = 0.147 | Accuracy = 81.875
# Val: Epoch = 76 | Loss 1.571 | Accuracy = 60.345
# Train: Epoch = 77 | Loss = 33.990 | Loss2 = 0.143 | Accuracy = 85.625
# Val: Epoch = 77 | Loss 1.558 | Accuracy = 60.345
# Train: Epoch = 78 | Loss = 34.009 | Loss2 = 0.141 | Accuracy = 83.750
# Val: Epoch = 78 | Loss 1.553 | Accuracy = 61.207
# Train: Epoch = 79 | Loss = 33.992 | Loss2 = 0.147 | Accuracy = 83.438
# Val: Epoch = 79 | Loss 1.567 | Accuracy = 62.069
# Train: Epoch = 80 | Loss = 33.988 | Loss2 = 0.147 | Accuracy = 85.625
# Val: Epoch = 80 | Loss 1.575 | Accuracy = 61.207
# Train: Epoch = 81 | Loss = 34.002 | Loss2 = 0.144 | Accuracy = 84.688
# Val: Epoch = 81 | Loss 1.551 | Accuracy = 59.483
# Train: Epoch = 82 | Loss = 33.965 | Loss2 = 0.139 | Accuracy = 86.250
# Val: Epoch = 82 | Loss 1.538 | Accuracy = 60.345
# Train: Epoch = 83 | Loss = 33.934 | Loss2 = 0.138 | Accuracy = 88.125
# Val: Epoch = 83 | Loss 1.561 | Accuracy = 61.207
# Train: Epoch = 84 | Loss = 33.952 | Loss2 = 0.138 | Accuracy = 86.250
# Val: Epoch = 84 | Loss 1.585 | Accuracy = 57.759
# Train: Epoch = 85 | Loss = 33.979 | Loss2 = 0.148 | Accuracy = 86.875
# Val: Epoch = 85 | Loss 1.565 | Accuracy = 59.483
# Train: Epoch = 86 | Loss = 34.035 | Loss2 = 0.145 | Accuracy = 84.062
# Val: Epoch = 86 | Loss 1.567 | Accuracy = 60.345
# Train: Epoch = 87 | Loss = 34.035 | Loss2 = 0.140 | Accuracy = 85.000
# Val: Epoch = 87 | Loss 1.618 | Accuracy = 58.621
# Train: Epoch = 88 | Loss = 34.003 | Loss2 = 0.140 | Accuracy = 85.000
# Val: Epoch = 88 | Loss 1.611 | Accuracy = 60.345
# Train: Epoch = 89 | Loss = 34.053 | Loss2 = 0.143 | Accuracy = 83.438
# Val: Epoch = 89 | Loss 1.599 | Accuracy = 60.345
# Train: Epoch = 90 | Loss = 33.945 | Loss2 = 0.143 | Accuracy = 86.250
# Val: Epoch = 90 | Loss 1.590 | Accuracy = 56.897
# Train: Epoch = 91 | Loss = 34.010 | Loss2 = 0.144 | Accuracy = 87.188
# Val: Epoch = 91 | Loss 1.597 | Accuracy = 58.621
# Train: Epoch = 92 | Loss = 34.020 | Loss2 = 0.142 | Accuracy = 84.375
# Val: Epoch = 92 | Loss 1.601 | Accuracy = 59.483
# Train: Epoch = 93 | Loss = 34.004 | Loss2 = 0.138 | Accuracy = 84.688
# Val: Epoch = 93 | Loss 1.600 | Accuracy = 58.621
# Train: Epoch = 94 | Loss = 33.978 | Loss2 = 0.139 | Accuracy = 85.938
# Val: Epoch = 94 | Loss 1.607 | Accuracy = 59.483
# Train: Epoch = 95 | Loss = 33.986 | Loss2 = 0.144 | Accuracy = 85.625
# Val: Epoch = 95 | Loss 1.621 | Accuracy = 58.621
# Train: Epoch = 96 | Loss = 33.971 | Loss2 = 0.140 | Accuracy = 85.938
# Val: Epoch = 96 | Loss 1.574 | Accuracy = 59.483
# Train: Epoch = 97 | Loss = 34.007 | Loss2 = 0.136 | Accuracy = 87.188
# Val: Epoch = 97 | Loss 1.573 | Accuracy = 59.483
# Train: Epoch = 98 | Loss = 34.065 | Loss2 = 0.145 | Accuracy = 82.812
# Val: Epoch = 98 | Loss 1.559 | Accuracy = 60.345
# Train: Epoch = 99 | Loss = 34.015 | Loss2 = 0.145 | Accuracy = 82.812
# Val: Epoch = 99 | Loss 1.549 | Accuracy = 60.345
# Train: Epoch = 100 | Loss = 33.938 | Loss2 = 0.137 | Accuracy = 88.438
# Val: Epoch = 100 | Loss 1.567 | Accuracy = 59.483
# Train: Epoch = 101 | Loss = 34.028 | Loss2 = 0.141 | Accuracy = 85.938
# Val: Epoch = 101 | Loss 1.578 | Accuracy = 60.345
# Train: Epoch = 102 | Loss = 33.989 | Loss2 = 0.147 | Accuracy = 84.375
# Val: Epoch = 102 | Loss 1.612 | Accuracy = 59.483
# Train: Epoch = 103 | Loss = 33.977 | Loss2 = 0.141 | Accuracy = 84.688
# Val: Epoch = 103 | Loss 1.579 | Accuracy = 59.483
# Train: Epoch = 104 | Loss = 33.959 | Loss2 = 0.139 | Accuracy = 86.875
# Val: Epoch = 104 | Loss 1.553 | Accuracy = 61.207
# Train: Epoch = 105 | Loss = 33.957 | Loss2 = 0.140 | Accuracy = 88.750
# Val: Epoch = 105 | Loss 1.574 | Accuracy = 62.069
# Train: Epoch = 106 | Loss = 34.011 | Loss2 = 0.138 | Accuracy = 84.688
# Val: Epoch = 106 | Loss 1.577 | Accuracy = 60.345
# Train: Epoch = 107 | Loss = 33.961 | Loss2 = 0.137 | Accuracy = 87.812
# Val: Epoch = 107 | Loss 1.597 | Accuracy = 60.345
# Train: Epoch = 108 | Loss = 33.999 | Loss2 = 0.129 | Accuracy = 85.938
# Val: Epoch = 108 | Loss 1.610 | Accuracy = 60.345
# Train: Epoch = 109 | Loss = 34.042 | Loss2 = 0.139 | Accuracy = 80.625
# Val: Epoch = 109 | Loss 1.637 | Accuracy = 59.483
# Train: Epoch = 110 | Loss = 33.941 | Loss2 = 0.139 | Accuracy = 86.875
# Val: Epoch = 110 | Loss 1.600 | Accuracy = 60.345
# Train: Epoch = 111 | Loss = 34.027 | Loss2 = 0.142 | Accuracy = 85.625
# Val: Epoch = 111 | Loss 1.598 | Accuracy = 59.483
# Train: Epoch = 112 | Loss = 34.037 | Loss2 = 0.143 | Accuracy = 83.125
# Val: Epoch = 112 | Loss 1.579 | Accuracy = 58.621
# Train: Epoch = 113 | Loss = 33.914 | Loss2 = 0.144 | Accuracy = 89.062
# Val: Epoch = 113 | Loss 1.598 | Accuracy = 58.621
# Train: Epoch = 114 | Loss = 34.023 | Loss2 = 0.139 | Accuracy = 84.062
# Val: Epoch = 114 | Loss 1.580 | Accuracy = 61.207
# Train: Epoch = 115 | Loss = 33.949 | Loss2 = 0.142 | Accuracy = 88.125
# Val: Epoch = 115 | Loss 1.574 | Accuracy = 62.931
# Train: Epoch = 116 | Loss = 34.004 | Loss2 = 0.136 | Accuracy = 83.125
# Val: Epoch = 116 | Loss 1.623 | Accuracy = 60.345
# Train: Epoch = 117 | Loss = 33.928 | Loss2 = 0.138 | Accuracy = 85.000
# Val: Epoch = 117 | Loss 1.612 | Accuracy = 59.483
# Train: Epoch = 118 | Loss = 33.916 | Loss2 = 0.141 | Accuracy = 87.812
# Val: Epoch = 118 | Loss 1.626 | Accuracy = 58.621
# Train: Epoch = 119 | Loss = 33.967 | Loss2 = 0.141 | Accuracy = 87.188
# Val: Epoch = 119 | Loss 1.596 | Accuracy = 57.759
# Train: Epoch = 120 | Loss = 33.964 | Loss2 = 0.145 | Accuracy = 88.750
# Val: Epoch = 120 | Loss 1.566 | Accuracy = 57.759
# Train: Epoch = 121 | Loss = 33.935 | Loss2 = 0.139 | Accuracy = 86.250
# Val: Epoch = 121 | Loss 1.561 | Accuracy = 59.483
# Train: Epoch = 122 | Loss = 33.976 | Loss2 = 0.147 | Accuracy = 87.812
# Val: Epoch = 122 | Loss 1.602 | Accuracy = 58.621
# Train: Epoch = 123 | Loss = 34.000 | Loss2 = 0.139 | Accuracy = 84.375
# Val: Epoch = 123 | Loss 1.627 | Accuracy = 58.621
# Train: Epoch = 124 | Loss = 33.954 | Loss2 = 0.147 | Accuracy = 84.062
# Val: Epoch = 124 | Loss 1.634 | Accuracy = 58.621
# Train: Epoch = 125 | Loss = 33.960 | Loss2 = 0.142 | Accuracy = 85.000
# Val: Epoch = 125 | Loss 1.620 | Accuracy = 58.621
# Train: Epoch = 126 | Loss = 33.865 | Loss2 = 0.136 | Accuracy = 90.000
# Val: Epoch = 126 | Loss 1.598 | Accuracy = 58.621
# Train: Epoch = 127 | Loss = 33.974 | Loss2 = 0.144 | Accuracy = 88.438
# Val: Epoch = 127 | Loss 1.618 | Accuracy = 58.621
# Train: Epoch = 128 | Loss = 33.881 | Loss2 = 0.144 | Accuracy = 89.688
# Val: Epoch = 128 | Loss 1.659 | Accuracy = 57.759
# Train: Epoch = 129 | Loss = 34.027 | Loss2 = 0.148 | Accuracy = 84.688
# Val: Epoch = 129 | Loss 1.647 | Accuracy = 56.034
# Train: Epoch = 130 | Loss = 33.971 | Loss2 = 0.143 | Accuracy = 85.938
# Val: Epoch = 130 | Loss 1.600 | Accuracy = 59.483
# Train: Epoch = 131 | Loss = 33.926 | Loss2 = 0.138 | Accuracy = 87.812
# Val: Epoch = 131 | Loss 1.583 | Accuracy = 58.621
# Train: Epoch = 132 | Loss = 33.969 | Loss2 = 0.145 | Accuracy = 82.500
# Val: Epoch = 132 | Loss 1.589 | Accuracy = 60.345
# Train: Epoch = 133 | Loss = 33.930 | Loss2 = 0.146 | Accuracy = 86.562
# Val: Epoch = 133 | Loss 1.604 | Accuracy = 58.621
# Train: Epoch = 134 | Loss = 33.947 | Loss2 = 0.144 | Accuracy = 86.562
# Val: Epoch = 134 | Loss 1.612 | Accuracy = 59.483
# Train: Epoch = 135 | Loss = 33.916 | Loss2 = 0.140 | Accuracy = 88.125
# Val: Epoch = 135 | Loss 1.614 | Accuracy = 56.897
# Train: Epoch = 136 | Loss = 33.999 | Loss2 = 0.135 | Accuracy = 86.250
# Val: Epoch = 136 | Loss 1.603 | Accuracy = 59.483
# Train: Epoch = 137 | Loss = 33.955 | Loss2 = 0.141 | Accuracy = 87.812
# Val: Epoch = 137 | Loss 1.588 | Accuracy = 58.621
# Train: Epoch = 138 | Loss = 33.973 | Loss2 = 0.132 | Accuracy = 86.250
# Val: Epoch = 138 | Loss 1.580 | Accuracy = 58.621
# Train: Epoch = 139 | Loss = 33.991 | Loss2 = 0.143 | Accuracy = 83.750
# Val: Epoch = 139 | Loss 1.589 | Accuracy = 58.621
# Train: Epoch = 140 | Loss = 33.924 | Loss2 = 0.145 | Accuracy = 88.438
# Val: Epoch = 140 | Loss 1.580 | Accuracy = 59.483
# Train: Epoch = 141 | Loss = 33.943 | Loss2 = 0.146 | Accuracy = 87.500
# Val: Epoch = 141 | Loss 1.578 | Accuracy = 60.345
# Train: Epoch = 142 | Loss = 33.958 | Loss2 = 0.139 | Accuracy = 87.500
# Val: Epoch = 142 | Loss 1.600 | Accuracy = 56.034
# Train: Epoch = 143 | Loss = 33.974 | Loss2 = 0.149 | Accuracy = 86.562
# Val: Epoch = 143 | Loss 1.592 | Accuracy = 59.483
# Train: Epoch = 144 | Loss = 33.909 | Loss2 = 0.135 | Accuracy = 89.688
# Val: Epoch = 144 | Loss 1.576 | Accuracy = 60.345
# Train: Epoch = 145 | Loss = 33.940 | Loss2 = 0.143 | Accuracy = 85.938
# Val: Epoch = 145 | Loss 1.595 | Accuracy = 60.345
# Train: Epoch = 146 | Loss = 33.947 | Loss2 = 0.139 | Accuracy = 87.188
# Val: Epoch = 146 | Loss 1.621 | Accuracy = 59.483
# Train: Epoch = 147 | Loss = 33.912 | Loss2 = 0.145 | Accuracy = 86.250
# Val: Epoch = 147 | Loss 1.625 | Accuracy = 60.345
# Train: Epoch = 148 | Loss = 33.934 | Loss2 = 0.146 | Accuracy = 86.875
# Val: Epoch = 148 | Loss 1.609 | Accuracy = 60.345
# Train: Epoch = 149 | Loss = 33.938 | Loss2 = 0.145 | Accuracy = 87.812
# Val: Epoch = 149 | Loss 1.572 | Accuracy = 59.483
# Train: Epoch = 150 | Loss = 33.934 | Loss2 = 0.135 | Accuracy = 87.812
# Val: Epoch = 150 | Loss 1.568 | Accuracy = 62.069
